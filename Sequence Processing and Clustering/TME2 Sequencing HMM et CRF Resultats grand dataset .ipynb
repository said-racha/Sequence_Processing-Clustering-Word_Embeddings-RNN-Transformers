# %% [markdown]
# # Sequence Processing with HMMs and CRFs
#
# **The goal of this practical is to study sequence models in NLP.**
#
# We will work on Part-Of-Speech (POS) and optionally on chunking (gathering different groups in sentences). The datasets are from [CONLL 2000](https://www.clips.uantwerpen.be/conll2000/chunking/):
# - **Small corpus:** chtrain/chtest to understand the tools and models
# - **Larger corpus:** train/test to collect reliable experimental results
#
#
# # 1) HMMS

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from collections import Counter

# %%
# Loading POS/Chunking data
def load(filename):
    listeDoc = list()
    with open(filename, "r") as f:
        doc = list()
        for ligne in f:
            if len(ligne) < 2: # fin de doc
                listeDoc.append(doc)
                doc = list()
                continue
            mots = ligne.replace("\n","").split(" ")
            doc.append((mots[0],mots[1])) # Change mots[1] -> mots[2] for chuncking
    return listeDoc

# %%
# =============== loding ============
# small corpus => ideal for first tests
# filename = "../ressources/conll2000/chtrain.txt" 
# filenameT = "../ressources/conll2000/chtest.txt" 

# Larger corpus => To valide perf.
filename = "./ressources/conll2000/train.txt" 
filenameT = "./ressources/conll2000/test.txt" 

alldocs = load(filename)
alldocsT = load(filenameT)

print(len(alldocs)," docs read")
print(len(alldocsT)," docs (T) read")
# Out:
# 8936  docs read
# 2012  docs (T) read

# %%
print(alldocs[0])
print(alldocsT[0])
# Out:
# [('Confidence', 'NN'), ('in', 'IN'), ('the', 'DT'), ('pound', 'NN'), ('is', 'VBZ'), ('widely', 'RB'), ('expected', 'VBN'), ('to', 'TO'), ('take', 'VB'), ('another', 'DT'), ('sharp', 'JJ'), ('dive', 'NN'), ('if', 'IN'), ('trade', 'NN'), ('figures', 'NNS'), ('for', 'IN'), ('September', 'NNP'), (',', ','), ('due', 'JJ'), ('for', 'IN'), ('release', 'NN'), ('tomorrow', 'NN'), (',', ','), ('fail', 'VB'), ('to', 'TO'), ('show', 'VB'), ('a', 'DT'), ('substantial', 'JJ'), ('improvement', 'NN'), ('from', 'IN'), ('July', 'NNP'), ('and', 'CC'), ('August', 'NNP'), ("'s", 'POS'), ('near-record', 'JJ'), ('deficits', 'NNS'), ('.', '.')]
# [('Rockwell', 'NNP'), ('International', 'NNP'), ('Corp.', 'NNP'), ("'s", 'POS'), ('Tulsa', 'NNP'), ('unit', 'NN'), ('said', 'VBD'), ('it', 'PRP'), ('signed', 'VBD'), ('a', 'DT'), ('tentative', 'JJ'), ('agreement', 'NN'), ('extending', 'VBG'), ('its', 'PRP$'), ('contract', 'NN'), ('with', 'IN'), ('Boeing', 'NNP'), ('Co.', 'NNP'), ('to', 'TO'), ('provide', 'VB'), ('structural', 'JJ'), ('parts', 'NNS'), ('for', 'IN'), ('Boeing', 'NNP'), ("'s", 'POS'), ('747', 'CD'), ('jetliners', 'NNS'), ('.', '.')]

# %% [markdown]
# ## Building a baseline POS model (without sequence)
#
# We will build a simple dictionary ```word => PoS label``` without taking into account any sequence information. We will compare the sequence models to this baseline.
#
# The dataset is a list a tuples with ```(word, POS)```. **Build a simple dictionary mapping each word to its PoS tag in the train set**

# %%
# Dictionary building 
def get_dico(alldocs):
    dicoTrain = dict()

    for document in alldocs:
        for couple in document:
            if(couple[0] not in dicoTrain.keys()):
                dicoTrain[couple[0]]=[couple[1]]
            else:
                list_pos = dicoTrain.get(couple[0])
                list_pos.append(couple[1])
                dicoTrain[couple[0]]=list_pos
    return dicoTrain
dicoTrain= get_dico(alldocs)        
print(len(dicoTrain), "mots")
print(dicoTrain)
# Out:
# 19122 mots
# {'Confidence': ['NN'], 'in': ['IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'NN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'NN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'RB', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'RB', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'RB', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN', 'IN' ...

# %%
def get_elt_majoritaire(dico):
    all_pos=[]
    for key, value in dico.items():
        for elem in value:
            all_pos.append(elem)
            

    compteur = Counter(all_pos)
    elt_majoritaire = max(compteur, key=compteur.get)
    #print(set(all_pos))
    
    return elt_majoritaire

pos_maj = get_elt_majoritaire(dicoTrain)
pos_maj
# Out:
# 'NN'

# %%
def get_dico_uniquePos(dicoTrain) :   
    dicoTrain_uniquePos=dict()
    for k,v in dicoTrain.items():
        #rechercher l'element majoritaire parmi les pos du mot
        compteur = Counter(v)
        pos_majoritaire = max(compteur, key=compteur.get)
        dicoTrain_uniquePos[k]=pos_majoritaire
    return dicoTrain_uniquePos

dicoTrain_uniquePos=get_dico_uniquePos(dicoTrain)
dicoTrain_uniquePos
# Out:
# {'Confidence': 'NN',
#  'in': 'IN',
#  'the': 'DT',
#  'pound': 'NN',
#  'is': 'VBZ',
#  'widely': 'RB',
#  'expected': 'VBN',
#  'to': 'TO',
#  'take': 'VB',
#  'another': 'DT',
#  'sharp': 'JJ',
#  'dive': 'NN',
#  'if': 'IN',
#  'trade': 'NN',
#  'figures': 'NNS',
#  'for': 'IN',
#  'September': 'NNP',
#  ',': ',',
#  'due': 'JJ',
#  'release': 'NN',
#  'tomorrow': 'NN',
#  'fail': 'VB',
#  'show': 'VB',
#  'a': 'DT',
#  'substantial': 'JJ',
#  'improvement': 'NN',
#  'from': 'IN',
#  'July': 'NNP',
#  'and': 'CC',
#  'August': 'NNP',
#  "'s": 'POS',
#  'near-record': 'JJ',
#  'deficits': 'NNS',
#  '.': '.',
#  'Chancellor': 'NNP',
#  'of': 'IN',
#  'Exchequer': 'NNP',
#  'Nigel': 'NNP',
#  'Lawson': 'NNP',
#  'restated': 'VBN',
#  'commitment': 'NN',
#  'firm': 'NN',
#  'monetary': 'JJ',
#  'policy': 'NN',
#  'has': 'VBZ',
#  'helped': 'VBD',
#  'prevent': 'VB',
#  'freefall': 'NN',
#  'sterling': 'NN',
#  'over': 'IN',
#  'past': 'JJ',
#  'week': 'NN',
#  'But': 'CC',
#  'analysts': 'NNS',
#  'reckon': 'VBP',
#  'underlying': 'VBG',
#  'support': 'NN',
#  'been': 'VBN',
#  'eroded': 'VBN',
#  'by': 'IN',
#  'chancellor': 'NN',
#  'failure': 'NN',
#  'announce': 'VB',
#  'any': 'DT',
#  'new': 'JJ',
#  'measures': 'NNS',
#  'his': 'PRP$',
#  'Mansion': 'NNP',
#  'House': 'NNP',
#  'speech': 'NN',
#  'last': 'JJ',
#  'Thursday': 'NNP',
#  'This': 'DT',
#  'increased': 'VBN',
#  'risk': 'NN',
#  'government': 'NN',
#  'being': 'VBG',
#  'forced': 'VBN',
#  'increase': 'NN',
#  'base': 'NN',
#  'rates': 'NNS',
#  '16': 'CD',
#  '%': 'NN',
#  'their': 'PRP$',
#  'current': 'JJ',
#  '15': 'CD',
#  'level': 'NN',
#  'defend': 'VB',
#  'economists': 'NNS',
#  'foreign': 'JJ',
#  'exchange': 'NN',
#  'market': 'NN',
#  'say': 'VBP',
#  '``': '``',
#  'The': 'DT',
#  'risks': 'NNS',
#  'bad': 'JJ',
#  'figure': 'NN',
#  'are': 'VBP',
#  'very': 'RB',
#  'heavily': 'RB',
#  'on': 'IN',
#  'down': 'RB',
#  'side': 'NN',
#  "''": "''",
#  'said': 'VBD',
#  'Chris': 'NNP',
#  'Dillow': 'NNP',
#  'senior': 'JJ',
#  'U.K.': 'NNP',
#  'economist': 'NN',
#  'at': 'IN',
#  'Nomura': 'NNP',
#  'Research': 'NNP',
#  'Institute': 'NNP',
#  'If': 'IN',
#  'there': 'EX',
#  'number': 'NN',
#  'could': 'MD',
#  'be': 'VB',
#  'an': 'DT',
#  'awful': 'JJ',
#  'lot': 'NN',
#  'pressure': 'NN',
#  'noted': 'VBD',
#  'Simon': 'NNP',
#  'Briscoe': 'NNP',
#  'Midland': 'NNP',
#  'Montagu': 'NNP',
#  'unit': 'NN',
#  'Bank': 'NNP',
#  'PLC': 'NNP',
#  'Forecasts': 'NNS',
#  'range': 'NN',
#  'but': 'CC',
#  'few': 'JJ',
#  'expect': 'VBP',
#  'data': 'NNS',
#  'marked': 'VBD',
#  '#': '#',
#  '2': 'CD',
#  'billion': 'CD',
#  '-LRB-': '(',
#  '$': '$',
#  '3.2': 'CD',
#  '-RRB-': ')',
#  'deficit': 'NN',
#  'account': 'NN',
#  'reported': 'VBD',
#  '2.2': 'CD',
#  'gap': 'NN',
#  'registered': 'VBN',
#  'topped': 'VBD',
#  'only': 'RB',
#  '2.3': 'CD',
#  'October': 'NNP',
#  '1988': 'CD',
#  'Sanjay': 'NNP',
#  'Joshi': 'NNP',
#  'European': 'JJ',
#  'Baring': 'NNP',
#  'Brothers': 'NNP',
#  '&': 'CC',
#  'Co.': 'NNP',
#  'no': 'DT',
#  'sign': 'NN',
#  'that': 'IN',
#  'Britain': 'NNP',
#  'manufacturing': 'NN',
#  'industry': 'NN',
#  'transforming': 'VBG',
#  'itself': 'PRP',
#  'boost': 'VB',
#  'exports': 'NNS',
#  'At': 'IN',
#  'same': 'JJ',
#  'time': 'NN',
#  'he': 'PRP',
#  'remains': 'VBZ',
#  'fairly': 'RB',
#  'pessimistic': 'JJ',
#  'about': 'IN',
#  'outlook': 'NN',
#  'imports': 'NNS',
#  'given': 'VBN',
#  'continued': 'VBD',
#  'high': 'JJ',
#  'consumer': 'NN',
#  'capital': 'NN',
#  'goods': 'NNS',
#  'inflows': 'NNS',
#  'He': 'PRP',
#  'reckons': 'VBZ',
#  'will': 'MD',
#  'narrow': 'JJ',
#  '1.8': 'CD',
#  'However': 'RB',
#  'Mr.': 'NNP',
#  'believes': 'VBZ',
#  'reduction': 'NN',
#  'raw': 'JJ',
#  'material': 'NN',
#  'stockbuilding': 'VBG',
#  'lead': 'NN',
#  'drop': 'NN',
#  'Combined': 'VBN',
#  'with': 'IN',
#  'least': 'JJS',
#  'some': 'DT',
#  'rebound': 'NN',
#  'after': 'IN',
#  'unexpected': 'JJ',
#  'decline': 'NN',
#  'as': 'IN',
#  'little': 'JJ',
#  '1.3': 'CD',
#  'who': 'WP',
#  'also': 'RB',
#  'forecasts': 'NNS',
#  'warns': 'VBZ',
#  'even': 'RB',
#  'bullish': 'JJ',
#  'currency': 'NN',
#  'wo': 'MD',
#  "n't": 'RB',
#  'advance': 'NN',
#  'much': 'JJ',
#  'because': 'IN',
#  'investors': 'NNS',
#  'want': 'VBP',
#  'see': 'VB',
#  'further': 'JJ',
#  'evidence': 'NN',
#  'turnaround': 'NN',
#  'before': 'IN',
#  'adjusting': 'VBG',
#  'positions': 'NNS',
#  'Nevertheless': 'RB',
#  'No': 'DT',
#  'one': 'CD',
#  'go': 'VB',
#  'into': 'IN',
#  'without': 'IN',
#  'flat': 'JJ',
#  'position': 'NN',
#  'Meanwhile': 'RB',
#  'overall': 'JJ',
#  'economy': 'NN',
#  'clouded': 'VBN',
#  'In': 'IN',
#  'warned': 'VBD',
#  'slowdown': 'NN',
#  'can': 'MD',
#  'impact': 'NN',
#  'rise': 'NN',
#  'interest': 'NN',
#  'earlier': 'RBR',
#  'this': 'DT',
#  'month': 'NN',
#  'takes': 'VBZ',
#  'effect': 'NN',
#  'highest': 'JJS',
#  'eight': 'CD',
#  'years': 'NNS',
#  'expenditure': 'NN',
#  'released': 'VBN',
#  'Friday': 'NNP',
#  'do': 'VBP',
#  'suggest': 'VBP',
#  'slowing': 'VBG',
#  'quickly': 'RB',
#  'spending': 'NN',
#  'rose': 'VBD',
#  '0.1': 'CD',
#  'third': 'JJ',
#  'quarter': 'NN',
#  'second': 'JJ',
#  'was': 'VBD',
#  'up': 'IN',
#  '3.8': 'CD',
#  'year': 'NN',
#  'ago': 'RB',
#  'compares': 'VBZ',
#  '1.6': 'CD',
#  'first': 'JJ',
#  '5.4': 'CD',
#  'still': 'RB',
#  'quite': 'RB',
#  'strong': 'JJ',
#  'suggestions': 'NNS',
#  'went': 'VBD',
#  'services': 'NNS',
#  'rather': 'RB',
#  'than': 'IN',
#  'should': 'MD',
#  'reduce': 'VB',
#  'fears': 'NNS',
#  'more': 'JJR',
#  'import': 'NN',
#  'rises': 'NNS',
#  'Certainly': 'RB',
#  'made': 'VBN',
#  'it': 'PRP',
#  'clear': 'JJ',
#  'prepared': 'VBN',
#  'again': 'RB',
#  'necessary': 'JJ',
#  'both': 'DT',
#  'ensure': 'VB',
#  'does': 'VBZ',
#  'place': 'NN',
#  'reminded': 'VBD',
#  'audience': 'NN',
#  'not': 'RB',
#  'allow': 'VB',
#  'rigor': 'NN',
#  'undermined': 'VBN',
#  'rate': 'NN',
#  'weakness': 'NN',
#  'Analysts': 'NNS',
#  'agree': 'VBP',
#  'holding': 'VBG',
#  'moment': 'NN',
#  'other': 'JJ',
#  'promise': 'NN',
#  'pushed': 'VBN',
#  'higher': 'JJR',
#  'And': 'CC',
#  'they': 'PRP',
#  'warn': 'VBP',
#  'popularity': 'NN',
#  'swiftly': 'RB',
#  'make': 'VB',
#  'sound': 'NN',
#  'hollow': 'JJ',
#  'Sterling': 'NNP',
#  'already': 'RB',
#  'showing': 'VBG',
#  'signs': 'NNS',
#  'lack': 'NN',
#  'confidence': 'NN',
#  'trading': 'NN',
#  'declined': 'VBD',
#  '1.5890': 'CD',
#  '2.9495': 'CD',
#  'marks': 'NNS',
#  '1.5940': 'CD',
#  '2.9429': 'CD',
#  'late': 'JJ',
#  'Economists': 'NNS',
#  'suggested': 'VBD',
#  'falls': 'VBZ',
#  'below': 'IN',
#  '2.90': 'CD',
#  'halt': 'VB',
#  'balance': 'NN',
#  'unchanged': 'JJ',
#  'Market': 'NNP',
#  'Activity': 'NN',
#  'dollar': 'NN',
#  'posted': 'VBD',
#  'gains': 'NNS',
#  'quiet': 'JJ',
#  'concerns': 'NNS',
#  'equities': 'NNS',
#  'abated': 'VBN',
#  'Foreign': 'NNP',
#  'dealers': 'NNS',
#  'begun': 'VBN',
#  'distance': 'NN',
#  'volatile': 'JJ',
#  'stock': 'NN',
#  'which': 'WDT',
#  'preoccupied': 'VBN',
#  'since': 'IN',
#  'Oct.': 'NNP',
#  '13': 'CD',
#  'when': 'WRB',
#  'Dow': 'NNP',
#  'Jones': 'NNP',
#  'Industrial': 'NNP',
#  'Average': 'NNP',
#  'plunged': 'VBD',
#  '190': 'CD',
#  'points': 'NNS',
#  'Currency': 'NN',
#  'predict': 'VBP',
#  'coming': 'VBG',
#  'shift': 'NN',
#  'its': 'PRP$',
#  'focus': 'NN',
#  'back': 'RB',
#  'economic': 'JJ',
#  'fundamentals': 'NNS',
#  'keeping': 'VBG',
#  'close': 'VB',
#  'eye': 'NN',
#  'out': 'IN',
#  'easing': 'NN',
#  'U.S.': 'NNP',
#  'Federal': 'NNP',
#  'Reserve': 'NNP',
#  'Late': 'RB',
#  'New': 'NNP',
#  'York': 'NNP',
#  'day': 'NN',
#  'quoted': 'VBN',
#  '1.8578': 'CD',
#  '1.8470': 'CD',
#  'changing': 'VBG',
#  'hands': 'NNS',
#  '142.43': 'CD',
#  'yen': 'NN',
#  '141.70': 'CD',
#  'Tokyo': 'NNP',
#  'Monday': 'NNP',
#  'opened': 'VBD',
#  '141.95': 'CD',
#  '141.35': 'CD',
#  'On': 'IN',
#  'Commodity': 'NNP',
#  'Exchange': 'NNP',
#  'gold': 'NN',
#  'delivery': 'NN',
#  'settled': 'VBD',
#  '367.30': 'CD',
#  'ounce': 'NN',
#  '20': 'CD',
#  'cents': 'NNS',
#  'Estimated': 'VBN',
#  'volume': 'NN',
#  'light': 'NN',
#  '2.4': 'CD',
#  'million': 'CD',
#  'ounces': 'NNS',
#  'early': 'JJ',
#  'Hong': 'NNP',
#  'Kong': 'NNP',
#  '366.50': 'CD',
#  'East': 'NNP',
#  'Rock': 'NNP',
#  'Partners': 'NNPS',
#  'Limited': 'NNP',
#  'Partnership': 'NNP',
#  'proposed': 'VBN',
#  'acquire': 'VB',
#  'A.P.': 'NNP',
#  'Green': 'NNP',
#  'Industries': 'NNP',
#  'Inc.': 'NNP',
#  '40': 'CD',
#  'share': 'NN',
#  '19': 'CD',
#  'letter': 'NN',
#  'board': 'NN',
#  'offer': 'NN',
#  'subject': 'NN',
#  'signing': 'NN',
#  'merger': 'NN',
#  'agreement': 'NN',
#  'later': 'RB',
#  '31': 'CD',
#  'attached': 'VBN',
#  'filing': 'NN',
#  'Securities': 'NNP',
#  'Commission': 'NNP',
#  'approval': 'NN',
#  'contingent': 'JJ',
#  'upon': 'IN',
#  'obtaining': 'VBG',
#  'satisfactory': 'JJ',
#  'financing': 'NN',
#  'An': 'DT',
#  'official': 'NN',
#  'comment': 'VB',
#  '40-a-share': 'JJ',
#  'proposal': 'NN',
#  'values': 'NNS',
#  'company': 'NN',
#  '106.6': 'CD',
#  'currently': 'RB',
#  '2,664,098': 'CD',
#  'shares': 'NNS',
#  'outstanding': 'JJ',
#  'Its': 'PRP$',
#  'closed': 'VBD',
#  '38': 'CD',
#  '1.875': 'CD',
#  'national': 'JJ',
#  'over-the-counter': 'JJ',
#  'Mexico': 'NNP',
#  'Mo.': 'NNP',
#  'maker': 'NN',
#  'refractory': 'JJ',
#  'products': 'NNS',
#  'boosted': 'VBD',
#  'stake': 'NN',
#  '8.7': 'CD',
#  'It': 'PRP',
#  'now': 'RB',
#  'holds': 'VBZ',
#  '233,000': 'CD',
#  'common': 'JJ',
#  'including': 'VBG',
#  '30,000': 'CD',
#  'bought': 'VBD',
#  '35.50': 'CD',
#  '36.50': 'CD',
#  'York-based': 'JJ',
#  'John': 'NNP',
#  'Kuhns': 'NNP',
#  'Robert': 'NNP',
#  'MacDonald': 'NNP',
#  'control': 'NN',
#  'sole': 'JJ',
#  'general': 'JJ',
#  'partner': 'NN',
#  'L.P': 'NNP',
#  'limited': 'JJ',
#  'partnership': 'NN',
#  'Westwood': 'NNP',
#  'Brick': 'NNP',
#  'Lime': 'NNP',
#  'indirect': 'JJ',
#  'subsidiary': 'NN',
#  'Group': 'NNP',
#  'Inc': 'NNP',
#  'Both': 'DT',
#  'based': 'VBN',
#  'Boston': 'NNP',
#  'Freight': 'NN',
#  'declining': 'VBG',
#  'most': 'RBS',
#  'decade': 'NN',
#  'competition': 'NN',
#  'spurred': 'VBN',
#  'deregulation': 'NN',
#  'bottoming': 'VBG',
#  'turning': 'VBG',
#  'upward': 'RB',
#  'threatening': 'VBG',
#  'fuel': 'NN',
#  'inflation': 'NN',
#  'Trucking': 'NNP',
#  'shipping': 'VBG',
#  'air-freight': 'NN',
#  'companies': 'NNS',
#  'have': 'VBP',
#  'announced': 'VBD',
#  'increases': 'NNS',
#  'scheduled': 'VBN',
#  'fall': 'NN',
#  'or': 'CC',
#  'next': 'JJ',
#  'reflecting': 'VBG',
#  'costs': 'NNS',
#  'tightened': 'VBD',
#  'demand': 'NN',
#  'freight': 'NN',
#  'transport': 'NN',
#  'Major': 'JJ',
#  'shippers': 'NNS',
#  'fast': 'RB',
#  'maybe': 'RB',
#  'faster': 'RBR',
#  'That': 'DT',
#  'big': 'JJ',
#  'change': 'NN',
#  'recent': 'JJ',
#  'haulage': 'NN',
#  'bright': 'JJ',
#  'spot': 'NN',
#  'productivity': 'NN',
#  'helping': 'VBG',
#  'restrain': 'VB',
#  'competitive': 'JJ',
#  'abroad': 'RB',
#  'Demand': 'NN',
#  'caught': 'VBN',
#  'supply': 'NN',
#  'certain': 'JJ',
#  'types': 'NNS',
#  'transportation': 'NN',
#  'starting': 'VBG',
#  'move': 'NN',
#  'slightly': 'RB',
#  'Clifford': 'NNP',
#  'Sayre': 'NNP',
#  'director': 'NN',
#  'logistics': 'NNS',
#  'Du': 'NNP',
#  'Pont': 'NNP',
#  'Co': 'NNP',
#  'Shippers': 'NNS',
#  'surveyed': 'VBN',
#  'recently': 'RB',
#  'Ohio': 'NNP',
#  'State': 'NNP',
#  'University': 'NNP',
#  'freight-transport': 'JJ',
#  'storage': 'NN',
#  'distribution': 'NN',
#  '4': 'CD',
#  'Only': 'RB',
#  '10': 'CD',
#  '250': 'CD',
#  'polled': 'VBN',
#  'decrease': 'VB',
#  'compared': 'VBN',
#  '30': 'CD',
#  'had': 'VBD',
#  'looked': 'VBN',
#  '1980': 'CD',
#  'we': 'PRP',
#  'such': 'JJ',
#  'dramatic': 'JJ',
#  'broad-based': 'JJ',
#  'upturn': 'NN',
#  'perceived': 'VBN',
#  'Bernard': 'NNP',
#  'LaLonde': 'NNP',
#  'professor': 'NN',
#  'Columbus': 'NNP',
#  'railroads': 'NNS',
#  'trucking': 'NN',
#  'began': 'VBD',
#  'enabled': 'VBD',
#  'bargain': 'NN',
#  'Carriers': 'NNP',
#  'use': 'NN',
#  'equipment': 'NN',
#  'efficiently': 'RB',
#  'leading': 'VBG',
#  'overcapacity': 'NN',
#  'were': 'VBD',
#  'eager': 'JJ',
#  'fill': 'VB',
#  'cut': 'VB',
#  '35': 'CD',
#  'annual': 'JJ',
#  'inter-city': 'JJ',
#  'truck': 'NN',
#  'rail': 'NN',
#  '150': 'CD',
#  '6.4': 'CD',
#  'gross': 'JJ',
#  'product': 'NN',
#  '8': 'CD',
#  'GNP': 'NNP',
#  '1981': 'CD',
#  'inefficiency': 'NN',
#  'squeezed': 'VBN',
#  'system': 'NN',
#  'rising': 'VBG',
#  'likely': 'JJ',
#  'reflected': 'VBD',
#  'directly': 'RB',
#  'saying': 'VBG',
#  '`': '``',
#  'party': 'NN',
#  "'": 'POS',
#  'able': 'JJ',
#  'look': 'VB',
#  'transportation-cost': 'JJ',
#  'savings': 'NNS',
#  'nine': 'CD',
#  'Transport': 'NNP',
#  'opportunity': 'NN',
#  'offsetting': 'VBG',
#  'cost': 'NN',
#  'segments': 'NNS',
#  'Delaney': 'NNP',
#  'consultant': 'NN',
#  'Arthur': 'NNP',
#  'D.': 'NNP',
#  'Little': 'NNP',
#  'Cambridge': 'NNP',
#  'Mass.': 'NNP',
#  'We': 'PRP',
#  "'ve": 'VBP',
#  'gotten': 'VBN',
#  'all': 'DT',
#  'benefits': 'NNS',
#  'freight-cost': 'JJ',
#  'reductions': 'NNS',
#  'Now': 'RB',
#  'real': 'JJ',
#  'freight-rate': 'JJ',
#  'carriers': 'NNS',
#  'replace': 'VB',
#  'pay': 'VB',
#  'labor': 'NN',
#  'You': 'PRP',
#  "'ll": 'MD',
#  'try': 'VB',
#  'recoup': 'VB',
#  'price': 'NN',
#  'cutting': 'VBG',
#  'occurred': 'VBD',
#  'previously': 'RB',
#  'Not': 'RB',
#  'everyone': 'NN',
#  'good': 'JJ',
#  'times': 'NNS',
#  'There': 'EX',
#  'Gerard': 'NNP',
#  'McCullough': 'NNP',
#  'lecturer': 'NN',
#  'Massachusetts': 'NNP',
#  'Technology': 'NNP',
#  'Less-than-truckload': 'JJ',
#  'carry': 'VB',
#  'several': 'JJ',
#  'each': 'DT',
#  'trailer': 'NN',
#  'discounted': 'VBD',
#  'away': 'RB',
#  '4.7': 'CD',
#  'implemented': 'VBN',
#  'April': 'NNP',
#  'competing': 'VBG',
#  'fiercely': 'RB',
#  'Railroad-rate': 'JJ',
#  'restrained': 'VBN',
#  'weakening': 'VBG',
#  'rail-traffic': 'JJ',
#  'levels': 'NNS',
#  'keen': 'JJ',
#  'trucks': 'NNS',
#  'Consolidated': 'NNP',
#  'Freightways': 'NNP',
#  'Menlo': 'NNP',
#  'Park': 'NNP',
#  'Calif.': 'NNP',
#  'less-than-truckload': 'JJ',
#  'carrier': 'NN',
#  'discounting': 'NN',
#  'stabilize': 'VB',
#  'plans': 'NNS',
#  'raise': 'VB',
#  '5.3': 'CD',
#  'two': 'CD',
#  'competitors': 'NNS',
#  'similar': 'JJ',
#  'Truckers': 'NNS',
#  'trying': 'VBG',
#  'send': 'VB',
#  'signals': 'NNS',
#  'need': 'VBP',
#  'stop': 'VB',
#  'bloodletting': 'NN',
#  'forget': 'VB',
#  'Michael': 'NNP',
#  'Lloyd': 'NNP',
#  'analyst': 'NN',
#  'Salomon': 'NNP',
#  'Bros': 'NNP',
#  'getting': 'VBG',
#  'feeling': 'NN',
#  'played': 'VBN',
#  'trucker': 'NN',
#  'off': 'IN',
#  'against': 'IN',
#  'Air-freight': 'NN',
#  'raised': 'VBD',
#  'going': 'VBG',
#  'across': 'IN',
#  'Pacific': 'NNP',
#  'Asia': 'NNP',
#  'Japan': 'NNP',
#  'Air': 'NNP',
#  'Lines': 'NNPS',
#  '25': 'CD',
#  'Such': 'JJ',
#  'total': 'JJ',
#  'slow': 'JJ',
#  'Richard': 'NNP',
#  'Connors': 'NNP',
#  'vice': 'NN',
#  'president': 'NN',
#  'Yusen': 'NNP',
#  'Sea': 'NNP',
#  'Service': 'NNP',
#  'U.S.A.': 'NNP',
#  'air-freight-forwarding': 'JJ',
#  'Nippon': 'NNP',
#  'Kaisha': 'NNP',
#  'Ship': 'NN',
#  'carrying': 'VBG',
#  'bulk': 'NN',
#  'commodities': 'NNS',
#  'oil': 'NN',
#  'grain': 'NN',
#  'coal': 'NN',
#  'iron': 'NN',
#  'ore': 'NN',
#  'couple': 'NN',
#  'Some': 'DT',
#  '3': 'CD',
#  'months': 'NNS',
#  'ship': 'NN',
#  'lines': 'NNS',
#  'containers': 'NNS',
#  'North': 'NNP',
#  'Atlantic': 'NNP',
#  'between': 'IN',
#  'Europe': 'NNP',
#  'hoping': 'VBG',
#  'partly': 'RB',
#  'restore': 'VB',
#  'operating': 'VBG',
#  'plan': 'NN',
#  'effective': 'JJ',
#  'MGM': 'NNP',
#  'Grand': 'NNP',
#  'filed': 'VBN',
#  'registration': 'NN',
#  'statement': 'NN',
#  'public': 'JJ',
#  'offering': 'NN',
#  'six': 'CD',
#  'Beverly': 'NNP',
#  'Hills': 'NNP',
#  'Calif.-based': 'JJ',
#  'would': 'MD',
#  '26.9': 'CD',
#  'hotel': 'NN',
#  'Gaming': 'NNP',
#  'Merrill': 'NNP',
#  'Lynch': 'NNP',
#  'Capital': 'NNP',
#  'Markets': 'NNPS',
#  'underwriters': 'NNS',
#  'Proceeds': 'NNS',
#  'sale': 'NN',
#  'used': 'VBN',
#  'remodeling': 'VBG',
#  'refurbishing': 'VBG',
#  'projects': 'NNS',
#  'well': 'RB',
#  'planned': 'VBN',
#  'hotel\\/casino': 'NN',
#  'theme': 'NN',
#  'park': 'NN',
#  'Bob': 'NNP',
#  'Stone': 'NNP',
#  'stewed': 'JJ',
#  'manager': 'NN',
#  'putting': 'VBG',
#  'him': 'PRP',
#  'probation': 'NN',
#  'insubordination': 'NN',
#  'thought': 'VBD',
#  'discipline': 'NN',
#  'unfair': 'JJ',
#  ';': ':',
#  'believed': 'VBN',
#  'wanted': 'VBD',
#  'get': 'VB',
#  'rid': 'JJ',
#  'personal': 'JJ',
#  'reasons': 'NNS',
#  'Unable': 'JJ',
#  'persuade': 'VB',
#  'decision': 'NN',
#  'court': 'NN',
#  'hearing': 'NN',
#  'entered': 'VBN',
#  'conference': 'NN',
#  'room': 'NN',
#  'building': 'NN',
#  'near': 'IN',
#  'where': 'WRB',
#  'worked': 'VBD',
#  'After': 'IN',
#  'three': 'CD',
#  'members': 'NNS',
#  'introduced': 'VBN',
#  'themselves': 'PRP',
#  'chairman': 'NN',
#  'panel': 'NN',
#  ':': ':',
#  'Go': 'VB',
#  'ahead': 'RB',
#  'tell': 'VB',
#  'us': 'PRP',
#  'what': 'WP',
#  'happened': 'VBD',
#  'may': 'MD',
#  'ask': 'VB',
#  'questions': 'NNS',
#  'you': 'PRP',
#  'along': 'IN',
#  'wait': 'VB',
#  'until': 'IN',
#  'end': 'NN',
#  'lawyers': 'NNS',
#  'tape': 'NN',
#  'recorders': 'NNS',
#  'present': 'JJ',
#  'extra': 'JJ',
#  'people': 'NNS',
#  'personnel': 'NNS',
#  'specialists': 'NNS',
#  'whom': 'WP',
#  'knew': 'VBD',
#  'case': 'NN',
#  'intimately': 'RB',
#  'help': 'VB',
#  'facts': 'NNS',
#  'needed': 'VBN',
#  'give': 'VB',
#  'full': 'JJ',
#  'picture': 'NN',
#  'Over': 'IN',
#  'cup': 'NN',
#  'coffee': 'NN',
#  'told': 'VBD',
#  'story': 'NN',
#  'talked': 'VBD',
#  'minutes': 'NNS',
#  'When': 'WRB',
#  'through': 'IN',
#  'asked': 'VBD',
#  'many': 'JJ',
#  'then': 'RB',
#  'like': 'IN',
#  'hear': 'VB',
#  'talk': 'VB',
#  'witnesses': 'NNS',
#  'promised': 'VBD',
#  'within': 'IN',
#  'weeks': 'NNS',
#  'fictional': 'JJ',
#  'name': 'NN',
#  'incident': 'NN',
#  'described': 'VBN',
#  'Northrop': 'NNP',
#  'Corp.': 'NNP',
#  'Los': 'NNP',
#  'Angeles': 'NNP',
#  'called': 'VBN',
#  'Management': 'NNP',
#  'Appeals': 'NNPS',
#  'Committee': 'NNP',
#  'just': 'RB',
#  'MAC': 'NNP',
#  'dozen': 'NN',
#  'cases': 'NNS',
#  'Alter': 'VB',
#  'details': 'NNS',
#  'example': 'NN',
#  'taking': 'VBG',
#  'today': 'NN',
#  'Express': 'NNP',
#  'Memphis': 'NNP',
#  'Defense': 'NNP',
#  'Underseas': 'NNP',
#  'Systems': 'NNP',
#  'divisions': 'NNS',
#  'Honeywell': 'NNP',
#  'Minneapolis': 'NNP',
#  'General': 'NNP',
#  'Electric': 'NNP',
#  'plant': 'NN',
#  'Columbia': 'NNP',
#  'Md.': 'NNP',
#  'These': 'DT',
#  'firms': 'NNS',
#  'pioneers': 'NNS',
#  'significant': 'JJ',
#  'trend': 'NN',
#  'corporate': 'JJ',
#  'world': 'NN',
#  'I': 'PRP',
#  'call': 'VB',
#  'process': 'NN',
#  'Although': 'IN',
#  'practiced': 'VBN',
#  '--': ':',
#  'perhaps': 'RB',
#  '60': 'CD',
#  'fastest': 'JJS',
#  'developing': 'VBG',
#  'trends': 'NNS',
#  'majority': 'NN',
#  'people-oriented': 'JJ',
#  'adopt': 'VB',
#  'Corporate': 'JJ',
#  'appeals': 'NNS',
#  'management': 'NN',
#  'variety': 'NN',
#  'reduces': 'VBZ',
#  'lawsuits': 'NNS',
#  'disgruntled': 'JJ',
#  'employees': 'NNS',
#  'ex-employees': 'NNS',
#  'means': 'VBZ',
#  'reduced': 'VBN',
#  'legal': 'JJ',
#  ...}

# %% [markdown]
# **Note: on the test set, there are unknown words...**. We will use the following simple strategy:
# ```
# # remplace
# dico[cle] # crashing with an unknown key
# # by
# dico.get(cle, DefaultValue)
# ```
# From a linguistic point of view, we can choose the default value as the majority PoS class, producing a stronger baseline.

# %%
def check_prediction(dicoTrain_uniquePos, alldocsT):
    cpt=0  

    for document in alldocsT:
        
        for k, v in document:
            if k in dicoTrain_uniquePos.keys():
                if v == dicoTrain_uniquePos[k]:
                    cpt +=1
                
            else:
                if v == pos_maj:
                    cpt +=1
                
    return cpt

def check_accuracy(dicoTrain_uniquePos, alldocsT):
    cpt = check_prediction(dicoTrain_uniquePos, alldocsT)
    nb = 0
    for doc in alldocsT:
        nb += len(doc)
    
    return cpt/nb

# %%
print(check_prediction(dicoTrain_uniquePos, alldocsT))
check_accuracy(dicoTrain_uniquePos, alldocsT)
# Out:
# 42944
# 0.9064313907592292

# %% [markdown]
# Check: 1433 good predictions in test over 1896
#
# (1527 with 'NN' as default PoS value)

# %% [markdown]
# ## HMMs
#
# Here is a code for training HMM parameters and running decoding using the Viterbi algorithm. You should apply it to our PoS task. **N.B.: you should undersand the ```eps``` parmaters**.

# %%
# allx: list of observation sequences 
# allq: list os state sequences 
# N: nb states
# K: nb observations

def learnHMM(allx, allq, N, K, initTo1=True):
    if initTo1:
        #eps permet d'initialiser la matrice, si elle n'est pas stationnaire, la convergence de la chaine de markov dépendra de ce paramètre
        eps = 1e-1 # You can play with this regularization parameter default 1e-3
        A = np.ones((N,N))*eps
        B = np.ones((N,K))*eps
        Pi = np.ones(N)*eps
    else:
        A = np.zeros((N,N))
        B = np.zeros((N,K))
        Pi = np.zeros(N)
    
    for x,q in zip(allx,allq):
        Pi[int(q[0])] += 1
        for i in range(len(q)-1):
            A[int(q[i]),int(q[i+1])] += 1
            B[int(q[i]),int(x[i])] += 1
        B[int(q[-1]),int(x[-1])] += 1 # last transition
    A = A/np.maximum(A.sum(1).reshape(N,1),1) # normalisation
    B = B/np.maximum(B.sum(1).reshape(N,1),1) # normalisation
    Pi = Pi/Pi.sum()
    return Pi , A, B

def viterbi(x,Pi,A,B):
    T = len(x)
    N = len(Pi)
    logA = np.log(A)
    logB = np.log(B)
    logdelta = np.zeros((N,T))
    psi = np.zeros((N,T), dtype=int)
    S = np.zeros(T)
    logdelta[:,0] = np.log(Pi) + logB[:,int(x[0])]
    #forward
    for t in range(1,T):
        logdelta[:,t] = (logdelta[:,t-1].reshape(N,1) + logA).max(0) + logB[:,int(x[t])]
        psi[:,t] = (logdelta[:,t-1].reshape(N,1) + logA).argmax(0)
    # backward
    logp = logdelta[:,-1].max()
    S[T-1] = logdelta[:,-1].argmax()
    for i in range(2,T+1):
        S[int(T-i)] = psi[int(S[int(T-i+1)]),int(T-i+1)]
    return S, logp #, delta, psi

# %% [markdown]
# ### Data encoding
#
# We will map each word to an index for traing the HMM (see code below):
# ```
#  The cat is in the garden => 1 2 3 4 1 5
# ```
# We have to understand the dictionary functionning to retrieve the words corresponding to indices.

# %%
# alldocs etant issu du chargement des données
# la mise en forme des données est fournie ici
# afin de produire des analyses qualitative, vous devez malgré tout comprendre le fonctionnement des dictionnaires

buf = [[m for m,pos in d ] for d in alldocs]
mots = []
[mots.extend(b) for b in buf]
mots = np.unique(np.array(mots))
nMots = len(mots)+1 # mot inconnu

mots2ind = dict(zip(mots,range(len(mots))))
mots2ind["UUUUUUUU"] = len(mots)

buf2 = [[pos for m,pos in d ] for d in alldocs]
cles = []
[cles.extend(b) for b in buf2]
cles = np.unique(np.array(cles))
cles2ind = dict(zip(cles,range(len(cles))))

nCles = len(cles)

print(nMots,nCles," in the dictionary")

# mise en forme des données
allx  = [[mots2ind[m] for m,pos in d] for d in alldocs]
allxT = [[mots2ind.setdefault(m,len(mots)) for m,pos in d] for d in alldocsT]

allq  = [[cles2ind[pos] for m,pos in d] for d in alldocs]
allqT = [[cles2ind.setdefault(pos,len(cles)) for m,pos in d] for d in alldocsT]
# Out:
# 19123 44  in the dictionary

# %%
# First doc:
print(allx[0])
print(allq[0])
# Out:
# [3068, 12557, 17919, 15074, 12916, 18921, 11125, 18064, 17758, 7826, 16693, 10436, 12470, 18146, 11397, 11597, 6398, 24, 10616, 11597, 15914, 18078, 24, 11229, 18064, 16777, 7393, 17545, 12552, 11752, 4554, 7798, 2331, 21, 14042, 10027, 31]
# [18, 13, 10, 18, 38, 26, 36, 31, 33, 10, 14, 18, 13, 18, 21, 13, 19, 5, 14, 13, 18, 18, 5, 33, 31, 33, 10, 14, 18, 13, 19, 8, 19, 23, 14, 21, 6]

# %% [markdown]
# ## You turn: apply HMMs to those data!

# %%
# HMM training 
Pi , A, B = learnHMM(allx, allq, nCles, nMots, initTo1=True)

# %%
viterbi(allxT[0], Pi, A, B)
# Out:
# (array([19., 19., 19., 23., 14., 18., 34., 24., 34., 10., 14., 18., 13.,
#         25., 18., 13., 19., 19., 31., 33., 14., 21., 13., 19., 23.,  9.,
#          9.,  6.]),
#  -210.8906283996945)

# %%
# HMM decoding and performances evaluation
def decoder(allxT, allqT, Pi, A, B):
    cpt=0
    n=0
    list_predict = []

    for i in range(len(allxT)):
        
        sequence_predite,_ = viterbi(allxT[i], Pi, A, B)
        list_predict.append(sequence_predite)
        
        for predicted,true in zip(sequence_predite,allqT[i]):
            n+=1
            if predicted == true:
                cpt +=1

    acc = cpt/n
    return list_predict, cpt, acc #le nombre de POS correctement identifiés par viterbi

list_predict, cpt, acc = decoder(allxT, allqT, Pi, A, B)

print("nb predictions correctes avec viterbi:", cpt)
print("précision de la prédiction avec viterbi:", acc)
# Out:
# nb predictions correctes avec viterbi: 44003
# précision de la prédiction avec viterbi: 0.9287840091183486

# %% [markdown]
# Check : 1564 in test

# %% [markdown]
# ### Qualitative Analyis:
#
# - With imshow on the parameters (ou d'un argsort), show what are the probable transition between labels.
# - Visualize the confusion matrices to understand what is challenging in this task
# - Find out examples that are corrected by Viterbi decoding

# %% [markdown]
# ### Matrice de transitions

# %%
#Matrice de transitions entre labels
plt.imshow(A)
plt.colorbar(label='proba de transition')

# %% [markdown]
# ### Matrice de confusion

# %%
# matrice de confusion

list_labels_uniques = [set(doc) for doc in allqT]

all_labels = set()
for labels in list_labels_uniques:
    all_labels.update(labels)


confusion = np.zeros((nCles+1,nCles+1))

for document_true, document_pred in zip(allqT, list_predict):
    for indice_pos_true, indice_pos_pred in zip(document_true, document_pred):
        confusion[indice_pos_true][indice_pos_pred.astype(int)] +=1

confusion
# Out:
# array([[  9.,   2.,   0., ...,   0.,   0.,   0.],
#        [  0., 384.,   0., ...,   0.,   0.,   0.],
#        [  0.,   0., 314., ...,   0.,   0.,   0.],
#        ...,
#        [  0.,   0.,   0., ...,  90.,   0.,   0.],
#        [  0.,   0.,   0., ...,   0., 323.,   0.],
#        [  0.,   0.,   0., ...,   0.,   0.,   0.]])

# %%
plt.imshow(confusion)
plt.colorbar()
plt.title(label='matrice de confusion')
plt.show()

# %% [markdown]
# ### Exemples corrigés par Viterbi

# %%
#Pour mapper chaque index au mot/label qui lui correspond
ind2mots =  {v: k for k, v in mots2ind.items()}
ind2cles = {v: k for k, v in cles2ind.items()}

# %%
def pos_corriges_viterbi(allxT, dicoTrain_uniquePos, Pi, A, B, ind2mots, ind2cles):
    erreurs_naif = []
    for i in range(len(allxT)):
            
        sequence_predite,_ = viterbi(allxT[i], Pi, A, B)
        j=0
        for predicted_pos_viterbi, true_pos in zip(sequence_predite,allqT[i]):
        
            
            #print((i,j))
            if predicted_pos_viterbi == true_pos:
                #print("entre")
                indice_mot = allxT[i][j]
                #recuperer le mot correspondant à l'indice_pos_pred
                mot = ind2mots[indice_mot]
                if mot in dicoTrain_uniquePos.keys():
                    predicted_pos_naif=dicoTrain_uniquePos[mot]
                    #print(predicted_pos_naif,true_pos )
                    indice_predicted_pos_naif =  cles2ind[predicted_pos_naif]

                    if indice_predicted_pos_naif != true_pos:
                        erreurs_naif.append((mot, predicted_pos_naif, ind2cles[true_pos]))
                else:

                    if cles2ind[pos_maj] !=true_pos:
                        erreurs_naif.append((mot, pos_maj, ind2cles[true_pos]))
            j +=1
    return erreurs_naif

erreurs_naif = pos_corriges_viterbi(allxT, dicoTrain_uniquePos, Pi, A, B, ind2mots, ind2cles)

erreurs_naif
# Out:
# [('Harlow', 'NN', 'NNP'),
#  ('supply', 'NN', 'VB'),
#  ('Harlow', 'NN', 'NNS'),
#  ('Harlow', 'NN', 'NNP'),
#  ('concern', 'NN', 'VBP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('accepted', 'VBN', 'VBD'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'CD'),
#  ('increased', 'VBN', 'VBD'),
#  ('that', 'IN', 'DT'),
#  ('Harlow', 'NN', 'VBG'),
#  ('continue', 'VB', 'VBP'),
#  ('Harlow', 'NN', 'CD'),
#  ('that', 'IN', 'WDT'),
#  ('Harlow', 'NN', 'CD'),
#  ('have', 'VBP', 'VB'),
#  ('gain', 'NN', 'VB'),
#  ('Harlow', 'NN', 'CD'),
#  ('that', 'IN', 'WDT'),
#  ('close', 'VB', 'NN'),
#  ('left', 'VBN', 'VBD'),
#  ('hired', 'VBN', 'VBD'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'JJ'),
#  ('Harlow', 'NN', 'VB'),
#  ('paid', 'VBN', 'VBD'),
#  ('Harlow', 'NN', 'CD'),
#  ('lure', 'NN', 'VB'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'CD'),
#  ('close', 'VB', 'NN'),
#  ('Harlow', 'NN', 'VB'),
#  ('Harlow', 'NN', 'JJ'),
#  ('Harlow', 'NN', 'VBN'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Products', 'NNPS', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('concern', 'NN', 'VBP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('step', 'NN', 'VB'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('act', 'NN', 'VB'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('bought', 'VBD', 'VBN'),
#  ('Harlow', 'NN', 'CD'),
#  ('that', 'IN', 'WDT'),
#  ('provide', 'VB', 'VBP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('lead', 'NN', 'VB'),
#  ('reduced', 'VBN', 'VBD'),
#  ('Harlow', 'NN', 'JJ'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'JJ'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('that', 'IN', 'WDT'),
#  ('Harlow', 'NN', 'JJ'),
#  ('more', 'JJR', 'RBR'),
#  ('increase', 'NN', 'VB'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'CD'),
#  ('that', 'IN', 'WDT'),
#  ('slowed', 'VBN', 'VBD'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'NNP'),
#  ('fuel', 'NN', 'VB'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'JJ'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'CD'),
#  ('estimate', 'NN', 'VBP'),
#  ('more', 'JJR', 'RBR'),
#  ('estimate', 'NN', 'VBP'),
#  ('estimated', 'VBN', 'VBD'),
#  ('say', 'VBP', 'VB'),
#  ('that', 'IN', 'WDT'),
#  ('Harlow', 'NN', 'NNP'),
#  ("'s", 'POS', 'VBZ'),
#  ("'s", 'POS', 'VBZ'),
#  ('Harlow', 'NN', 'NNP'),
#  ('focus', 'NN', 'VB'),
#  ('sold', 'VBN', 'VBD'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('that', 'IN', 'WDT'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'VBG'),
#  ('scrapped', 'VBN', 'VBD'),
#  ('Harlow', 'NN', 'NNS'),
#  ('Harlow', 'NN', 'VB'),
#  ('looked', 'VBN', 'VBD'),
#  ('Harlow', 'NN', 'JJ'),
#  ('looked', 'VBN', 'VBD'),
#  ('that', 'IN', 'WDT'),
#  ('do', 'VBP', 'VB'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'VBG'),
#  ('submitted', 'VBN', 'VBD'),
#  ('parking', 'NN', 'VBG'),
#  ('cross', 'VBP', 'NN'),
#  ('spot', 'NN', 'VB'),
#  ('Harlow', 'NN', 'VBD'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Rival', 'JJ', 'NNP'),
#  ('Harlow', 'NN', 'NNS'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'JJ'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('have', 'VBP', 'VB'),
#  ('Harlow', 'NN', 'NNS'),
#  ('Harlow', 'NN', 'VBN'),
#  ('Harlow', 'NN', 'JJ'),
#  ('bow', 'NN', 'VBP'),
#  ('Harlow', 'NN', 'JJ'),
#  ('Revenue', 'NN', 'NNP'),
#  ('plans', 'NNS', 'VBZ'),
#  ('Harlow', 'NN', 'JJ'),
#  ('guide', 'NN', 'VB'),
#  ('Harlow', 'NN', 'JJ'),
#  ('Harlow', 'NN', 'VB'),
#  ('base', 'NN', 'VBP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('have', 'VBP', 'VB'),
#  ('that', 'IN', 'WDT'),
#  ('let', 'VB', 'VBP'),
#  ('have', 'VBP', 'VB'),
#  ('have', 'VBP', 'VB'),
#  ('Harlow', 'NN', 'VBN'),
#  ('Harlow', 'NN', 'VBZ'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'VBG'),
#  ('turn', 'VB', 'NN'),
#  ('result', 'NN', 'VB'),
#  ('plans', 'NNS', 'VBZ'),
#  ('Harlow', 'NN', 'JJ'),
#  ('Harlow', 'NN', 'NNS'),
#  ('Harlow', 'NN', 'NNS'),
#  ('put', 'VB', 'VBN'),
#  ('Harlow', 'NN', 'VBZ'),
#  ('Harlow', 'NN', 'NNS'),
#  ('trusts', 'NNS', 'VBZ'),
#  ('Harlow', 'NN', 'VB'),
#  ('Harlow', 'NN', 'VBN'),
#  ('failed', 'VBD', 'VBN'),
#  ('Harlow', 'NN', 'JJ'),
#  ('that', 'IN', 'DT'),
#  ('American', 'NNP', 'JJ'),
#  ('Harlow', 'NN', 'VB'),
#  ('Harlow', 'NN', 'NNS'),
#  ('Harlow', 'NN', 'VBN'),
#  ('that', 'IN', 'DT'),
#  ('died', 'VBD', 'VBN'),
#  ('more', 'JJR', 'RBR'),
#  ('that', 'IN', 'DT'),
#  ('Harlow', 'NN', 'VBG'),
#  ('Harlow', 'NN', 'VBN'),
#  ('Harlow', 'NN', 'NNP'),
#  ('as', 'IN', 'RB'),
#  ('as', 'IN', 'RB'),
#  ('as', 'IN', 'RB'),
#  ('cost', 'NN', 'VB'),
#  ('Harlow', 'NN', 'NNP'),
#  ('have', 'VBP', 'VB'),
#  ('Harlow', 'NN', 'JJ'),
#  ('Harlow', 'NN', 'VBN'),
#  ('demand', 'NN', 'VB'),
#  ('Harlow', 'NN', 'VB'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('have', 'VBP', 'VB'),
#  ('fight', 'VB', 'NN'),
#  ('Harlow', 'NN', 'JJ'),
#  ('American', 'NNP', 'JJ'),
#  ('discovered', 'VBN', 'VBD'),
#  ('Harlow', 'NN', 'NNP'),
#  ('named', 'VBN', 'VBD'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('advance', 'NN', 'VB'),
#  ('observed', 'VBN', 'VBD'),
#  ('more', 'JJR', 'RBR'),
#  ('raised', 'VBD', 'VBN'),
#  ('Harlow', 'NN', 'NNS'),
#  ('considered', 'VBN', 'VBD'),
#  ('Harlow', 'NN', 'JJ'),
#  ('Harlow', 'NN', 'JJ'),
#  ('Harlow', 'NN', 'NNS'),
#  ('American', 'NNP', 'JJ'),
#  ('Major', 'JJ', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'VB'),
#  ('tracking', 'NN', 'VBG'),
#  ('Harlow', 'NN', 'NNS'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('pay', 'VB', 'NN'),
#  ('American', 'NNP', 'JJ'),
#  ('boost', 'VB', 'NN'),
#  ('building', 'NN', 'VBG'),
#  ('that', 'IN', 'WDT'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'JJ'),
#  ('needed', 'VBN', 'VBD'),
#  ('Harlow', 'NN', 'NNS'),
#  ('found', 'VBD', 'VBN'),
#  ('Harlow', 'NN', 'NNS'),
#  ('planning', 'NN', 'VBG'),
#  ('learned', 'VBD', 'VBN'),
#  ('Harlow', 'NN', 'NNS'),
#  ('distributed', 'VBN', 'VBD'),
#  ('Harlow', 'NN', 'JJ'),
#  ('Harlow', 'NN', 'NNP'),
#  ('ruled', 'VBD', 'VBN'),
#  ('control', 'NN', 'VB'),
#  ('play', 'VB', 'NN'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('monitor', 'VB', 'NN'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('order', 'NN', 'VB'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'JJ'),
#  ('American', 'NNP', 'JJ'),
#  ('copy', 'VB', 'NN'),
#  ('Harlow', 'NN', 'NNP'),
#  ('that', 'IN', 'DT'),
#  ('Harlow', 'NN', 'JJ'),
#  ('American', 'NNP', 'JJ'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'JJ'),
#  ('include', 'VBP', 'VB'),
#  ('that', 'IN', 'WDT'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Early', 'JJ', 'RB'),
#  ('Harlow', 'NN', 'JJ'),
#  ('caused', 'VBN', 'VBD'),
#  ('Harlow', 'NN', 'VBN'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'VB'),
#  ('Harlow', 'NN', 'NNP'),
#  ('act', 'NN', 'VB'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('American', 'NNP', 'JJ'),
#  ('caught', 'VBN', 'VBD'),
#  ('Harlow', 'NN', 'NNP'),
#  ('considered', 'VBN', 'VBD'),
#  ('get', 'VB', 'VBP'),
#  ('get', 'VB', 'VBP'),
#  ('Harlow', 'NN', 'VB'),
#  ('worry', 'VB', 'NN'),
#  ('sold', 'VBN', 'VBD'),
#  ('beginning', 'VBG', 'NN'),
#  ('cause', 'VB', 'NN'),
#  ('indicted', 'VBN', 'VBD'),
#  ('Harlow', 'NN', 'NNS'),
#  ('Harlow', 'NN', 'VB'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('though', 'IN', 'RB'),
#  ('made', 'VBN', 'VBD'),
#  ('Harlow', 'NN', 'NNP'),
#  ('arrest', 'NN', 'VB'),
#  ('Harlow', 'NN', 'JJ'),
#  ('American', 'NNP', 'JJ'),
#  ('Harlow', 'NN', 'NNP'),
#  ('read', 'VB', 'VBP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('dismissed', 'VBD', 'VBN'),
#  ('charge', 'NN', 'VB'),
#  ('Harlow', 'NN', 'VBN'),
#  ('told', 'VBD', 'VBN'),
#  ('told', 'VBD', 'VBN'),
#  ('Harlow', 'NN', 'NNP'),
#  ('handling', 'NN', 'VBG'),
#  ('Harlow', 'NN', 'VB'),
#  ('much', 'JJ', 'RB'),
#  ('told', 'VBD', 'VBN'),
#  ('Harlow', 'NN', 'NNP'),
#  ('have', 'VBP', 'VB'),
#  ('found', 'VBD', 'VBN'),
#  ('have', 'VBP', 'VB'),
#  ('stopped', 'VBD', 'VBN'),
#  ('Harlow', 'NN', 'JJ'),
#  ('Harlow', 'NN', 'JJ'),
#  ('military', 'JJ', 'NN'),
#  ('expanded', 'VBN', 'VBD'),
#  ('Harlow', 'NN', 'NNS'),
#  ('that', 'IN', 'WDT'),
#  ('Harlow', 'NN', 'VB'),
#  ('act', 'NN', 'VB'),
#  ('close', 'VB', 'NN'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('set', 'VBN', 'VB'),
#  ('help', 'VB', 'NN'),
#  ('cause', 'VB', 'NN'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('means', 'VBZ', 'NNS'),
#  ('have', 'VBP', 'VB'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('involve', 'VBP', 'VB'),
#  ('Harlow', 'NN', 'NNP'),
#  ('comment', 'VB', 'NN'),
#  ('offers', 'VBZ', 'NNS'),
#  ('Harlow', 'NN', 'VB'),
#  ('Harlow', 'NN', 'NNP'),
#  ('close', 'VB', 'NN'),
#  ('Harlow', 'NN', 'NNP'),
#  ('while', 'IN', 'NN'),
#  ('made', 'VBN', 'VBD'),
#  ('offered', 'VBN', 'VBD'),
#  ('Harlow', 'NN', 'VB'),
#  ('lift', 'NN', 'VB'),
#  ('told', 'VBD', 'VBN'),
#  ('Harlow', 'NN', 'VB'),
#  ('helped', 'VBD', 'VBN'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNS'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'VBD'),
#  ('Harlow', 'NN', 'NNP'),
#  ('turned', 'VBD', 'VBN'),
#  ('general', 'JJ', 'NN'),
#  ('told', 'VBD', 'VBN'),
#  ('allowed', 'VBN', 'VBD'),
#  ('gain', 'NN', 'VB'),
#  ('triggered', 'VBD', 'VBN'),
#  ('chief', 'JJ', 'NN'),
#  ('ordered', 'VBD', 'VBN'),
#  ('killing', 'VBG', 'NN'),
#  ('American', 'NNP', 'JJ'),
#  ('have', 'VBP', 'VB'),
#  ('American', 'NNP', 'JJ'),
#  ('drop', 'NN', 'VB'),
#  ('helped', 'VBD', 'VBN'),
#  ('Harlow', 'NN', 'JJ'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('created', 'VBN', 'VBD'),
#  ('fed', 'VBN', 'VBD'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'CD'),
#  ('provided', 'VBN', 'VBD'),
#  ('slowing', 'VBG', 'NN'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'VBN'),
#  ('further', 'JJ', 'VB'),
#  ('do', 'VBP', 'VB'),
#  ('last', 'JJ', 'VB'),
#  ('that', 'IN', 'WDT'),
#  ('that', 'IN', 'WDT'),
#  ('Harlow', 'NN', 'VB'),
#  ('that', 'IN', 'DT'),
#  ('Harlow', 'NN', 'NNS'),
#  ('expect', 'VBP', 'VB'),
#  ('Harlow', 'NN', 'NNP'),
#  ('executive', 'JJ', 'NN'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('decline', 'NN', 'VB'),
#  ('Harlow', 'NN', 'NNS'),
#  ('Harlow', 'NN', 'NNS'),
#  ('cause', 'VB', 'NN'),
#  ('drop', 'NN', 'VB'),
#  ('Harlow', 'NN', 'VB'),
#  ('Harlow', 'NN', 'NNP'),
#  ('issued', 'VBN', 'VBD'),
#  ('date', 'NN', 'VB'),
#  ('general', 'JJ', 'NN'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNS'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'JJ'),
#  ('decline', 'NN', 'VB'),
#  ('rise', 'NN', 'VB'),
#  ('Harlow', 'NN', 'NNP'),
#  ('continued', 'VBD', 'VBN'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'JJ'),
#  ('comment', 'VB', 'NN'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('currently', 'RB', 'JJ'),
#  ('looked', 'VBN', 'VBD'),
#  ('included', 'VBD', 'VBN'),
#  ('Harlow', 'NN', 'NNP'),
#  ('currently', 'RB', 'JJ'),
#  ('head', 'NN', 'VB'),
#  ('Harlow', 'NN', 'NNP'),
#  ('work', 'NN', 'VB'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('profit', 'NN', 'VB'),
#  ('bought', 'VBD', 'VBN'),
#  ('cheap', 'JJ', 'NN'),
#  ('Harlow', 'NN', 'VBN'),
#  ('Harlow', 'NN', 'JJ'),
#  ('have', 'VBP', 'VB'),
#  ('turned', 'VBD', 'VBN'),
#  ('rally', 'NN', 'VB'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'VBN'),
#  ('that', 'IN', 'WDT'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('do', 'VBP', 'VB'),
#  ('Harlow', 'NN', 'JJ'),
#  ('Harlow', 'NN', 'NNP'),
#  ('have', 'VBP', 'VB'),
#  ('that', 'IN', 'WDT'),
#  ('total', 'JJ', 'NN'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'JJ'),
#  ('5', 'NN', 'VB'),
#  ('leases', 'NNS', 'VBZ'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('executive', 'JJ', 'NN'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'VBG'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNS'),
#  ('made', 'VBN', 'VBD'),
#  ('Harlow', 'NN', 'JJ'),
#  ('Harlow', 'NN', 'NNP'),
#  ('flush', 'VB', 'JJ'),
#  ('followed', 'VBD', 'VBN'),
#  ('Harlow', 'NN', 'JJ'),
#  ('Harlow', 'NN', 'JJ'),
#  ('Harlow', 'NN', 'JJ'),
#  ('wonder', 'VBP', 'NN'),
#  ('Harlow', 'NN', 'JJ'),
#  ('Harlow', 'NN', 'NNP'),
#  ('that', 'IN', 'WDT'),
#  ('Harlow', 'NN', 'NNS'),
#  ('turn', 'VB', 'NN'),
#  ('Harlow', 'NN', 'JJ'),
#  ('Harlow', 'NN', 'NNS'),
#  ('advanced', 'VBD', 'VBN'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('that', 'IN', 'DT'),
#  ('end', 'NN', 'VB'),
#  ('Harlow', 'NN', 'NNP'),
#  ('many', 'JJ', 'RB'),
#  ('produced', 'VBN', 'VBD'),
#  ('Harlow', 'NN', 'JJ'),
#  ('required', 'VBN', 'VBD'),
#  ('Harlow', 'NN', 'JJ'),
#  ('require', 'VB', 'VBP'),
#  ('claim', 'NN', 'VBP'),
#  ('Harlow', 'NN', 'VB'),
#  ('Harlow', 'NN', 'NNS'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('represent', 'VB', 'VBP'),
#  ('Harlow', 'NN', 'JJ'),
#  ('grave', 'NN', 'JJ'),
#  ('answer', 'NN', 'VB'),
#  ('Harlow', 'NN', 'VB'),
#  ('raised', 'VBD', 'VBN'),
#  ('asked', 'VBD', 'VBN'),
#  ('address', 'NN', 'VB'),
#  ('decide', 'VB', 'VBP'),
#  ('work', 'NN', 'VB'),
#  ('Harlow', 'NN', 'VBG'),
#  ('no', 'DT', 'RB'),
#  ('Harlow', 'NN', 'VBN'),
#  ('Harlow', 'NN', 'JJ'),
#  ('that', 'IN', 'WDT'),
#  ('address', 'NN', 'VB'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'VBG'),
#  ('net', 'JJ', 'NN'),
#  ('Harlow', 'NN', 'CD'),
#  ('tumble', 'NN', 'VB'),
#  ('5', 'NN', 'VB'),
#  ('blamed', 'VBN', 'VBD'),
#  ('Harlow', 'NN', 'CD'),
#  ('there', 'EX', 'RB'),
#  ('Harlow', 'NN', 'NNP'),
#  ('net', 'JJ', 'NN'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'CD'),
#  ('repurchased', 'VBN', 'VBD'),
#  ('Harlow', 'NN', 'JJ'),
#  ('acquired', 'VBD', 'VBN'),
#  ('total', 'JJ', 'NN'),
#  ('net', 'JJ', 'NN'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'CD'),
#  ('managed', 'VBD', 'VBN'),
#  ('Harlow', 'NN', 'NNP'),
#  ('agreed', 'VBD', 'VBN'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('executive', 'JJ', 'NN'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNS'),
#  ('Harlow', 'NN', 'NNP'),
#  ('approached', 'VBD', 'VBN'),
#  ('Harlow', 'NN', 'NNS'),
#  ('Harlow', 'NN', 'NNS'),
#  ('failed', 'VBD', 'VBN'),
#  ('have', 'VBP', 'VB'),
#  ('put', 'VB', 'VBN'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNS'),
#  ('Harlow', 'NN', 'NNP'),
#  ('executive', 'JJ', 'NN'),
#  ('include', 'VBP', 'VB'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('executive', 'JJ', 'NN'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('executive', 'JJ', 'NN'),
#  ('Harlow', 'NN', 'NNP'),
#  ('assume', 'VBP', 'VB'),
#  ('Harlow', 'NN', 'VBN'),
#  ('that', 'IN', 'WDT'),
#  ('ignored', 'VBD', 'VBN'),
#  ('that', 'IN', 'DT'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('interviewed', 'VBD', 'VBN'),
#  ('range', 'NN', 'VB'),
#  ('plans', 'NNS', 'VBZ'),
#  ('feel', 'VB', 'VBP'),
#  ('that', 'IN', 'WDT'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('only', 'RB', 'JJ'),
#  ('Harlow', 'NN', 'VB'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNS'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('titled', 'VBD', 'VBN'),
#  ('supply', 'NN', 'VB'),
#  ('that', 'IN', 'WDT'),
#  ('control', 'NN', 'VB'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'NNP'),
#  ('plans', 'NNS', 'VBZ'),
#  ('cuts', 'NNS', 'VBZ'),
#  ('declined', 'VBD', 'VBN'),
#  ('remain', 'VB', 'VBP'),
#  ('pay', 'VB', 'NN'),
#  ('net', 'JJ', 'NN'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('executive', 'JJ', 'NN'),
#  ('work', 'NN', 'VB'),
#  ('Harlow', 'NN', 'NNP'),
#  ('executive', 'JJ', 'NN'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('have', 'VBP', 'VB'),
#  ("'s", 'POS', 'VBZ'),
#  ('offer', 'NN', 'VB'),
#  ('offer', 'NN', 'VB'),
#  ('that', 'IN', 'DT'),
#  ('feel', 'VB', 'VBP'),
#  ('more', 'JJR', 'RBR'),
#  ('realized', 'VBD', 'VBN'),
#  ('use', 'NN', 'VBP'),
#  ('that', 'IN', 'WDT'),
#  ('Harlow', 'NN', 'JJ'),
#  ('Harlow', 'NN', 'JJ'),
#  ('include', 'VBP', 'VB'),
#  ('focus', 'NN', 'VB'),
#  ('that', 'IN', 'WDT'),
#  ('criticized', 'VBN', 'VBD'),
#  ('head', 'NN', 'VB'),
#  ('Harlow', 'NN', 'NNS'),
#  ('marketing', 'NN', 'VBG'),
#  ('date', 'NN', 'VB'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNS'),
#  ('test', 'NN', 'VB'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'JJ'),
#  ('clean', 'JJ', 'VB'),
#  ('Harlow', 'NN', 'NNP'),
#  ('gut', 'NN', 'VB'),
#  ('adopted', 'VBN', 'VBD'),
#  ('Harlow', 'NN', 'JJ'),
#  ('have', 'VBP', 'VB'),
#  ('seized', 'VBD', 'VBN'),
#  ('estimated', 'VBN', 'VBD'),
#  ('cost', 'NN', 'VB'),
#  ('made', 'VBN', 'VBD'),
#  ('Harlow', 'NN', 'JJ'),
#  ('Harlow', 'NN', 'NNP'),
#  ('that', 'IN', 'WDT'),
#  ('made', 'VBN', 'VBD'),
#  ('have', 'VBP', 'VB'),
#  ('sought', 'VBD', 'VBN'),
#  ('Harlow', 'NN', 'JJ'),
#  ('seized', 'VBD', 'VBN'),
#  ('step', 'NN', 'VB'),
#  ('put', 'VB', 'VBP'),
#  ('filed', 'VBN', 'VBD'),
#  ('shift', 'NN', 'VB'),
#  ('used', 'VBN', 'VBD'),
#  ('that', 'IN', 'WDT'),
#  ("'s", 'POS', 'VBZ'),
#  ('Harlow', 'NN', 'VB'),
#  ('result', 'NN', 'VB'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('say', 'VBP', 'VB'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'NNP'),
#  ('push', 'VB', 'VBP'),
#  ('seized', 'VBD', 'VBN'),
#  ('Harlow', 'NN', 'NNP'),
#  ('returned', 'VBN', 'VBD'),
#  ('pushed', 'VBN', 'VBD'),
#  ('Harlow', 'NN', 'NNP'),
#  ('subordinated', 'VBN', 'VBD'),
#  ('believed', 'VBN', 'VBD'),
#  ('emerge', 'VBP', 'VB'),
#  ('made', 'VBN', 'VBD'),
#  ('that', 'IN', 'WDT'),
#  ('make', 'VB', 'VBP'),
#  ('later', 'RB', 'JJ'),
#  ('Harlow', 'NN', 'NNP'),
#  ('emerge', 'VBP', 'VB'),
#  ('before', 'IN', 'RB'),
#  ('Harlow', 'NN', 'NNP'),
#  ('made', 'VBN', 'VBD'),
#  ('mention', 'VB', 'NN'),
#  ('Harlow', 'NN', 'NNP'),
#  ('that', 'IN', 'WDT'),
#  ('called', 'VBN', 'VBD'),
#  ('emerge', 'VBP', 'VB'),
#  ('block', 'VB', 'NN'),
#  ('South', 'NNP', 'JJ'),
#  ('American', 'NNP', 'JJ'),
#  ('caused', 'VBN', 'VBD'),
#  ('collapse', 'NN', 'VB'),
#  ('have', 'VBP', 'VB'),
#  ('have', 'VBP', 'VB'),
#  ('Harlow', 'NN', 'VBN'),
#  ('Harlow', 'NN', 'VB'),
#  ('work', 'NN', 'VB'),
#  ('estimated', 'VBN', 'VBD'),
#  ('Harlow', 'NN', 'CD'),
#  ('expected', 'VBN', 'VBD'),
#  ('have', 'VBP', 'VB'),
#  ('issue', 'NN', 'VB'),
#  ('increase', 'NN', 'VB'),
#  ('Harlow', 'NN', 'NNS'),
#  ('Harlow', 'NN', 'NNP'),
#  ('expect', 'VBP', 'VB'),
#  ('have', 'VBP', 'VB'),
#  ('hold', 'VB', 'VBP'),
#  ('have', 'VBP', 'VB'),
#  ('Harlow', 'NN', 'NNP'),
#  ('that', 'IN', 'DT'),
#  ('confirmed', 'VBD', 'VBN'),
#  ('Harlow', 'NN', 'NNP'),
#  ('have', 'VBP', 'VB'),
#  ("'s", 'POS', 'VBZ'),
#  ('press', 'NN', 'VB'),
#  ('act', 'NN', 'VB'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'JJ'),
#  ('Harlow', 'NN', 'NNP'),
#  ('projected', 'VBN', 'VBD'),
#  ('Harlow', 'NN', 'VBG'),
#  ('thanks', 'NNS', 'VBZ'),
#  ('that', 'IN', 'WDT'),
#  ('head', 'NN', 'VB'),
#  ('backed', 'VBN', 'VBD'),
#  ('Harlow', 'NN', 'JJ'),
#  ('deal', 'NN', 'VB'),
#  ('hear', 'VB', 'VBP'),
#  ('that', 'IN', 'WDT'),
#  ('Harlow', 'NN', 'VB'),
#  ('do', 'VBP', 'VB'),
#  ('elect', 'VB', 'VBP'),
#  ('claim', 'NN', 'VB'),
#  ('Harlow', 'NN', 'NNS'),
#  ('filing', 'NN', 'VBG'),
#  ('that', 'IN', 'WDT'),
#  ('Harlow', 'NN', 'VBN'),
#  ('marked', 'VBD', 'VBN'),
#  ('Harlow', 'NN', 'VBN'),
#  ('Harlow', 'NN', 'VBN'),
#  ('denied', 'VBN', 'VBD'),
#  ('try', 'VB', 'VBP'),
#  ('drive', 'VB', 'NN'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('that', 'IN', 'DT'),
#  ('have', 'VBP', 'VB'),
#  ('had', 'VBD', 'VBN'),
#  ('Harlow', 'NN', 'VBD'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'CD'),
#  ('saved', 'VBN', 'VBD'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'JJ'),
#  ('offered', 'VBN', 'VBD'),
#  ('made', 'VBN', 'VBD'),
#  ('Harlow', 'NN', 'CD'),
#  ('reported', 'VBD', 'VBN'),
#  ('Harlow', 'NN', 'CD'),
#  ('denied', 'VBN', 'VBD'),
#  ('imposed', 'VBN', 'VBD'),
#  ('entered', 'VBN', 'VBD'),
#  ('exempt', 'JJ', 'VB'),
#  ('Harlow', 'NN', 'JJ'),
#  ('Harlow', 'NN', 'VBN'),
#  ('back', 'RB', 'JJ'),
#  ('Harlow', 'NN', 'JJ'),
#  ('Harlow', 'NN', 'NNS'),
#  ("'s", 'POS', 'VBZ'),
#  ('trail', 'VB', 'NN'),
#  ('that', 'IN', 'WDT'),
#  ('closed', 'VBD', 'VBN'),
#  ('speed', 'VB', 'NN'),
#  ('Harlow', 'NN', 'NNS'),
#  ('Harlow', 'NN', 'NNS'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('limit', 'NN', 'VB'),
#  ('have', 'VBP', 'VB'),
#  ('come', 'VB', 'VBN'),
#  ('Harlow', 'NN', 'JJ'),
#  ('blow', 'NN', 'VB'),
#  ('Harlow', 'NN', 'VBG'),
#  ('Harlow', 'NN', 'VB'),
#  ('Harlow', 'NN', 'NNS'),
#  ('damage', 'NN', 'VBP'),
#  ('Harlow', 'NN', 'NNS'),
#  ('prompted', 'VBD', 'VBN'),
#  ('Harlow', 'NN', 'NNP'),
#  ('ban', 'NN', 'VB'),
#  ('back', 'RB', 'JJ'),
#  ('leap', 'NN', 'VB'),
#  ('stop', 'VB', 'NN'),
#  ('top', 'JJ', 'NN'),
#  ('allow', 'VB', 'VBP'),
#  ('Harlow', 'NN', 'NNS'),
#  ('Harlow', 'NN', 'NNS'),
#  ('shut', 'VBN', 'VB'),
#  ('that', 'IN', 'WDT'),
#  ('Harlow', 'NN', 'NNS'),
#  ('Harlow', 'NN', 'NNS'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'VBZ'),
#  ('come', 'VB', 'VBP'),
#  ('Harlow', 'NN', 'VBG'),
#  ('Harlow', 'NN', 'JJ'),
#  ('estimates', 'NNS', 'VBZ'),
#  ('Harlow', 'NN', 'NNS'),
#  ('Harlow', 'NN', 'VB'),
#  ('Harlow', 'NN', 'JJ'),
#  ('no', 'DT', 'RB'),
#  ('Harlow', 'NN', 'NNS'),
#  ('closed', 'VBD', 'VBN'),
#  ('Harlow', 'NN', 'VB'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'VBG'),
#  ('feel', 'VB', 'VBP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNS'),
#  ('Harlow', 'NN', 'NNS'),
#  ('Harlow', 'NN', 'VBD'),
#  ('Harlow', 'NN', 'NNS'),
#  ('lobby', 'NN', 'VB'),
#  ('Harlow', 'NN', 'NNS'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('won', 'VBD', 'VBN'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'VBN'),
#  ('that', 'IN', 'WDT'),
#  ('Harlow', 'NN', 'VBN'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('have', 'VBP', 'VB'),
#  ('Harlow', 'NN', 'JJ'),
#  ('that', 'IN', 'WDT'),
#  ('Harlow', 'NN', 'VB'),
#  ('more', 'JJR', 'RBR'),
#  ('ride', 'NN', 'VB'),
#  ('dismissed', 'VBD', 'VBN'),
#  ('shift', 'NN', 'VBP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'VBZ'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('do', 'VBP', 'VB'),
#  ('much', 'JJ', 'RB'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('cut', 'VB', 'NN'),
#  ('Long-term', 'JJ', 'NNP'),
#  ('half', 'NN', 'PDT'),
#  ('Harlow', 'NN', 'NNP'),
#  ('breathing', 'NN', 'VBG'),
#  ('end', 'NN', 'VB'),
#  ('watched', 'VBD', 'VBN'),
#  ('little', 'JJ', 'RB'),
#  ('Harlow', 'NN', 'CD'),
#  ('appear', 'VB', 'VBP'),
#  ('decline', 'NN', 'VB'),
#  ('that', 'IN', 'DT'),
#  ('Harlow', 'NN', 'VBN'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Associates', 'NNPS', 'NNP'),
#  ('financing', 'NN', 'VBG'),
#  ('yield', 'VB', 'NN'),
#  ('30-year', 'JJ', 'NNP'),
#  ('Late', 'RB', 'JJ'),
#  ('Consumer', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('include', 'VBP', 'VB'),
#  ('Harlow', 'NN', 'NNS'),
#  ('Harlow', 'NN', 'NNP'),
#  ('wonder', 'VBP', 'NN'),
#  ('drink', 'NN', 'VBP'),
#  ('mine', 'NN', 'VB'),
#  ('Harlow', 'NN', 'NNP'),
#  ('feel', 'VB', 'VBP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('fuel', 'NN', 'VB'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNS'),
#  ('increase', 'NN', 'VB'),
#  ('report', 'NN', 'VB'),
#  ('bring', 'VB', 'VBP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('had', 'VBD', 'VBN'),
#  ('do', 'VBP', 'VB'),
#  ('called', 'VBN', 'VBD'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'NNP'),
#  ("'s", 'POS', 'VBZ'),
#  ("'s", 'POS', 'VBZ'),
#  ('Harlow', 'NN', 'JJ'),
#  ('Harlow', 'NN', 'JJ'),
#  ('brought', 'VBN', 'VBD'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'VBG'),
#  ('Harlow', 'NN', 'JJ'),
#  ('much', 'JJ', 'RB'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'CD'),
#  ('increased', 'VBN', 'VBD'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'CD'),
#  ('Harlow', 'NN', 'CD'),
#  ('set', 'VBN', 'VBD'),
#  ('cost', 'NN', 'VB'),
#  ('rule', 'NN', 'VB'),
#  ('predict', 'VBP', 'VB'),
#  ('Harlow', 'NN', 'JJ'),
#  ('defeat', 'VB', 'NN'),
#  ('Harlow', 'NN', 'JJ'),
#  ('ruled', 'VBD', 'VBN'),
#  ('Harlow', 'NN', 'NNP'),
#  ('promises', 'VBZ', 'NNS'),
#  ('clean', 'JJ', 'VB'),
#  ('Harlow', 'NN', 'VBN'),
#  ('that', 'IN', 'DT'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'VB'),
#  ("'s", 'POS', 'VBZ'),
#  ('Harlow', 'NN', 'NNP'),
#  ('Harlow', 'NN', 'JJ'),
#  ('Harlow', 'NN', 'NNP'),
#  ...]

# %%
print("Le nombre de mots où la méthode naive s'est trompée et qui ont été corrigés par Viterbi: ", len(erreurs_naif))
# Out:
# Le nombre de mots où la méthode naive s'est trompée et qui ont été corrigés par Viterbi:  2236

# %% [markdown]
# # 2) Conditional Random Fields (CRF)

# %% [markdown]
# **CRF are disciminative models** representing the conditional distribution $P( \mathbf{y} | \mathbf{x} , \mathbf{w})$:
#
# $$ P( \mathbf{y} | \mathbf{x} , \mathbf{w})  = \frac{e^{\mathbf{w}^T  \psi(\mathbf{x},\mathbf{y}) } }{\sum\limits_{y' \in \mathcal{y}}e^{\mathbf{w}^T  \psi(\mathbf{x},\mathbf{y}') } } $$
#
# **In 'linear-chain' CRFs**, the feature functions include **unary terms $u_k$** ($\sim$ $\mathbf{B}$ matrix in HMMs) and **pairwise terms $p_k$** ($\sim$ $\mathbf{A}$ matrix in HMMs):
#
# $$ \psi(\mathbf{x},\mathbf{y}) = \sum\limits_{t=1}^T \sum_{k=1}^K F_k(y_{t-1}, y_t, \mathbf{x})  =   \sum\limits_{t=1}^T \sum_{k=1}^K \left[ u_k(y_t, \mathbf{x}) + p_k(y_{t-1}, y_t, \mathbf{x}) \right]$$
#
# [<img src="https://thome.isir.upmc.fr/classes/RITAL/crf-obs2.png" width="800" >](https://thome.isir.upmc.fr/classes/RITAL/crf-obs2.png)

# %% [markdown]
# W.T*psi = le score (ou proba) d'avoir la classe yi associée à xi sachant x et yi-1

# %% [markdown]
# We can directly use resources from nltk:
# - [CRFTagger](https://tedboy.github.io/nlps/generated/generated/nltk.CRFTagger.html)
# - [PerceptronTagger](https://www.nltk.org/_modules/nltk/tag/perceptron.html)

# %% [markdown]
# #### CRF Tagger

# %%
#pip install python-crfsuite
from nltk.tag.crf import CRFTagger

# %% [markdown]
# ### Training and evaluating the model, as before

# %%
tagger = CRFTagger()
tagger.train(alldocs, 'out/crf.model') # training

# %%
#recuperer toutes les predictions du modèle CRF
all_tagged_docs = []

for doc in alldocsT:
    doc_mots = [mot for mot, val in doc]
    tagged_docs = tagger.tag(doc_mots)
    all_tagged_docs.append(tagged_docs)

all_tagged_docs
# Out:
# [[('Rockwell', 'NNP'),
#   ('International', 'NNP'),
#   ('Corp.', 'NNP'),
#   ("'s", 'POS'),
#   ('Tulsa', 'NNP'),
#   ('unit', 'NN'),
#   ('said', 'VBD'),
#   ('it', 'PRP'),
#   ('signed', 'VBD'),
#   ('a', 'DT'),
#   ('tentative', 'JJ'),
#   ('agreement', 'NN'),
#   ('extending', 'VBG'),
#   ('its', 'PRP$'),
#   ('contract', 'NN'),
#   ('with', 'IN'),
#   ('Boeing', 'NNP'),
#   ('Co.', 'NNP'),
#   ('to', 'TO'),
#   ('provide', 'VB'),
#   ('structural', 'JJ'),
#   ('parts', 'NNS'),
#   ('for', 'IN'),
#   ('Boeing', 'NNP'),
#   ("'s", 'POS'),
#   ('747', 'CD'),
#   ('jetliners', 'NNS'),
#   ('.', '.')],
#  [('Rockwell', 'NNP'),
#   ('said', 'VBD'),
#   ('the', 'DT'),
#   ('agreement', 'NN'),
#   ('calls', 'VBZ'),
#   ('for', 'IN'),
#   ('it', 'PRP'),
#   ('to', 'TO'),
#   ('supply', 'VB'),
#   ('200', 'CD'),
#   ('additional', 'JJ'),
#   ('so-called', 'JJ'),
#   ('shipsets', 'NNS'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('planes', 'NNS'),
#   ('.', '.')],
#  [('These', 'DT'),
#   ('include', 'NN'),
#   (',', ','),
#   ('among', 'IN'),
#   ('other', 'JJ'),
#   ('parts', 'NNS'),
#   (',', ','),
#   ('each', 'DT'),
#   ('jetliner', 'NN'),
#   ("'s", 'POS'),
#   ('two', 'CD'),
#   ('major', 'JJ'),
#   ('bulkheads', 'NNS'),
#   (',', ','),
#   ('a', 'DT'),
#   ('pressure', 'NN'),
#   ('floor', 'NN'),
#   (',', ','),
#   ('torque', 'JJ'),
#   ('box', 'NN'),
#   (',', ','),
#   ('fixed', 'VBN'),
#   ('leading', 'VBG'),
#   ('edges', 'NNS'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('wings', 'NNS'),
#   ('and', 'CC'),
#   ('an', 'DT'),
#   ('aft', 'NN'),
#   ('keel', 'NN'),
#   ('beam', 'NN'),
#   ('.', '.')],
#  [('Under', 'IN'),
#   ('the', 'DT'),
#   ('existing', 'VBG'),
#   ('contract', 'NN'),
#   (',', ','),
#   ('Rockwell', 'NNP'),
#   ('said', 'VBD'),
#   (',', ','),
#   ('it', 'PRP'),
#   ('has', 'VBZ'),
#   ('already', 'RB'),
#   ('delivered', 'VBN'),
#   ('793', 'CD'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('shipsets', 'NNS'),
#   ('to', 'TO'),
#   ('Boeing', 'NNP'),
#   ('.', '.')],
#  [('Rockwell', 'NNP'),
#   (',', ','),
#   ('based', 'VBN'),
#   ('in', 'IN'),
#   ('El', 'NNP'),
#   ('Segundo', 'NNP'),
#   (',', ','),
#   ('Calif.', 'NNP'),
#   (',', ','),
#   ('is', 'VBZ'),
#   ('an', 'DT'),
#   ('aerospace', 'NN'),
#   (',', ','),
#   ('electronics', 'NNS'),
#   (',', ','),
#   ('automotive', 'JJ'),
#   ('and', 'CC'),
#   ('graphics', 'NNS'),
#   ('concern', 'VBP'),
#   ('.', '.')],
#  [('Frank', 'NNP'),
#   ('Carlucci', 'NNP'),
#   ('III', 'NNP'),
#   ('was', 'VBD'),
#   ('named', 'VBN'),
#   ('to', 'TO'),
#   ('this', 'DT'),
#   ('telecommunications', 'NNS'),
#   ('company', 'NN'),
#   ("'s", 'POS'),
#   ('board', 'NN'),
#   (',', ','),
#   ('filling', 'VBG'),
#   ('the', 'DT'),
#   ('vacancy', 'NN'),
#   ('created', 'VBN'),
#   ('by', 'IN'),
#   ('the', 'DT'),
#   ('death', 'NN'),
#   ('of', 'IN'),
#   ('William', 'NNP'),
#   ('Sobey', 'NNP'),
#   ('last', 'JJ'),
#   ('May', 'NNP'),
#   ('.', '.')],
#  [('Mr.', 'NNP'),
#   ('Carlucci', 'NNP'),
#   (',', ','),
#   ('59', 'CD'),
#   ('years', 'NNS'),
#   ('old', 'JJ'),
#   (',', ','),
#   ('served', 'VBN'),
#   ('as', 'IN'),
#   ('defense', 'NN'),
#   ('secretary', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('Reagan', 'NNP'),
#   ('administration', 'NN'),
#   ('.', '.')],
#  [('In', 'IN'),
#   ('January', 'NNP'),
#   (',', ','),
#   ('he', 'PRP'),
#   ('accepted', 'VBD'),
#   ('the', 'DT'),
#   ('position', 'NN'),
#   ('of', 'IN'),
#   ('vice', 'NN'),
#   ('chairman', 'NN'),
#   ('of', 'IN'),
#   ('Carlyle', 'NNP'),
#   ('Group', 'NNP'),
#   (',', ','),
#   ('a', 'DT'),
#   ('merchant', 'JJ'),
#   ('banking', 'NN'),
#   ('concern', 'NN'),
#   ('.', '.')],
#  [('SHEARSON', 'NNP'),
#   ('LEHMAN', 'NNP'),
#   ('HUTTON', 'NNP'),
#   ('Inc', 'NNP'),
#   ('.', '.')],
#  [('Thomas', 'NNP'),
#   ('E.', 'NNP'),
#   ('Meador', 'NNP'),
#   (',', ','),
#   ('42', 'CD'),
#   ('years', 'NNS'),
#   ('old', 'JJ'),
#   (',', ','),
#   ('was', 'VBD'),
#   ('named', 'VBN'),
#   ('president', 'NN'),
#   ('and', 'CC'),
#   ('chief', 'JJ'),
#   ('operating', 'NN'),
#   ('officer', 'NN'),
#   ('of', 'IN'),
#   ('Balcor', 'NNP'),
#   ('Co.', 'NNP'),
#   (',', ','),
#   ('a', 'DT'),
#   ('Skokie', 'NNP'),
#   (',', ','),
#   ('Ill.', 'NNP'),
#   (',', ','),
#   ('subsidiary', 'NN'),
#   ('of', 'IN'),
#   ('this', 'DT'),
#   ('New', 'NNP'),
#   ('York', 'NNP'),
#   ('investment', 'NN'),
#   ('banking', 'NN'),
#   ('firm', 'NN'),
#   ('.', '.')],
#  [('Balcor', 'NNP'),
#   (',', ','),
#   ('which', 'WDT'),
#   ('has', 'VBZ'),
#   ('interests', 'NNS'),
#   ('in', 'IN'),
#   ('real', 'JJ'),
#   ('estate', 'NN'),
#   (',', ','),
#   ('said', 'VBD'),
#   ('the', 'DT'),
#   ('position', 'NN'),
#   ('is', 'VBZ'),
#   ('newly', 'RB'),
#   ('created', 'VBN'),
#   ('.', '.')],
#  [('Mr.', 'NNP'),
#   ('Meador', 'NNP'),
#   ('had', 'VBD'),
#   ('been', 'VBN'),
#   ('executive', 'JJ'),
#   ('vice', 'NN'),
#   ('president', 'NN'),
#   ('of', 'IN'),
#   ('Balcor', 'NNP'),
#   ('.', '.')],
#  [('In', 'IN'),
#   ('addition', 'NN'),
#   ('to', 'TO'),
#   ('his', 'PRP$'),
#   ('previous', 'JJ'),
#   ('real-estate', 'NN'),
#   ('investment', 'NN'),
#   ('and', 'CC'),
#   ('asset-management', 'NN'),
#   ('duties', 'NNS'),
#   (',', ','),
#   ('Mr.', 'NNP'),
#   ('Meador', 'NNP'),
#   ('takes', 'VBZ'),
#   ('responsibility', 'NN'),
#   ('for', 'IN'),
#   ('development', 'NN'),
#   ('and', 'CC'),
#   ('property', 'NN'),
#   ('management', 'NN'),
#   ('.', '.')],
#  [('Those', 'DT'),
#   ('duties', 'NNS'),
#   ('had', 'VBD'),
#   ('been', 'VBN'),
#   ('held', 'VBN'),
#   ('by', 'IN'),
#   ('Van', 'NNP'),
#   ('Pell', 'NNP'),
#   (',', ','),
#   ('44', 'CD'),
#   (',', ','),
#   ('who', 'WP'),
#   ('resigned', 'VBD'),
#   ('as', 'IN'),
#   ('an', 'DT'),
#   ('executive', 'JJ'),
#   ('vice', 'NN'),
#   ('president', 'NN'),
#   ('.', '.')],
#  [('Shearson', 'NNP'),
#   ('is', 'VBZ'),
#   ('about', 'IN'),
#   ('60%-held', 'CD'),
#   ('by', 'IN'),
#   ('American', 'NNP'),
#   ('Express', 'NNP'),
#   ('Co', 'NNP'),
#   ('.', '.')],
#  [('Great', 'NNP'),
#   ('American', 'NNP'),
#   ('Bank', 'NNP'),
#   (',', ','),
#   ('citing', 'VBG'),
#   ('depressed', 'VBN'),
#   ('Arizona', 'NNP'),
#   ('real', 'JJ'),
#   ('estate', 'NN'),
#   ('prices', 'NNS'),
#   (',', ','),
#   ('posted', 'VBD'),
#   ('a', 'DT'),
#   ('third-quarter', 'JJ'),
#   ('loss', 'NN'),
#   ('of', 'IN'),
#   ('$', '$'),
#   ('59.4', 'CD'),
#   ('million', 'CD'),
#   (',', ','),
#   ('or', 'CC'),
#   ('$', '$'),
#   ('2.48', 'CD'),
#   ('a', 'DT'),
#   ('share', 'NN'),
#   ('.', '.')],
#  [('A', 'DT'),
#   ('year', 'NN'),
#   ('earlier', 'RBR'),
#   (',', ','),
#   ('the', 'DT'),
#   ('savings', 'NNS'),
#   ('bank', 'NN'),
#   ('had', 'VBD'),
#   ('earnings', 'NNS'),
#   ('of', 'IN'),
#   ('$', '$'),
#   ('8.1', 'CD'),
#   ('million', 'CD'),
#   (',', ','),
#   ('or', 'CC'),
#   ('33', 'CD'),
#   ('cents', 'NNS'),
#   ('a', 'DT'),
#   ('share', 'NN'),
#   ('.', '.')],
#  [('For', 'IN'),
#   ('the', 'DT'),
#   ('nine', 'CD'),
#   ('months', 'NNS'),
#   (',', ','),
#   ('it', 'PRP'),
#   ('had', 'VBD'),
#   ('a', 'DT'),
#   ('loss', 'NN'),
#   ('of', 'IN'),
#   ('$', '$'),
#   ('58.3', 'CD'),
#   ('million', 'CD'),
#   (',', ','),
#   ('or', 'CC'),
#   ('$', '$'),
#   ('2.44', 'CD'),
#   ('a', 'DT'),
#   ('share', 'NN'),
#   (',', ','),
#   ('after', 'IN'),
#   ('earnings', 'NNS'),
#   ('of', 'IN'),
#   ('$', '$'),
#   ('29.5', 'CD'),
#   ('million', 'CD'),
#   (',', ','),
#   ('or', 'CC'),
#   ('$', '$'),
#   ('1.20', 'CD'),
#   ('a', 'DT'),
#   ('share', 'NN'),
#   (',', ','),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('1988', 'CD'),
#   ('period', 'NN'),
#   ('.', '.')],
#  [('Great', 'NNP'),
#   ('American', 'NNP'),
#   ('said', 'VBD'),
#   ('it', 'PRP'),
#   ('increased', 'VBD'),
#   ('its', 'PRP$'),
#   ('loan-loss', 'NN'),
#   ('reserves', 'NNS'),
#   ('by', 'IN'),
#   ('$', '$'),
#   ('93', 'CD'),
#   ('million', 'CD'),
#   ('after', 'IN'),
#   ('reviewing', 'VBG'),
#   ('its', 'PRP$'),
#   ('loan', 'NN'),
#   ('portfolio', 'NN'),
#   (',', ','),
#   ('raising', 'VBG'),
#   ('its', 'PRP$'),
#   ('total', 'JJ'),
#   ('loan', 'NN'),
#   ('and', 'CC'),
#   ('real', 'JJ'),
#   ('estate', 'NN'),
#   ('reserves', 'NNS'),
#   ('to', 'TO'),
#   ('$', '$'),
#   ('217', 'CD'),
#   ('million', 'CD'),
#   ('.', '.')],
#  [('Before', 'IN'),
#   ('the', 'DT'),
#   ('loan-loss', 'NN'),
#   ('addition', 'NN'),
#   (',', ','),
#   ('it', 'PRP'),
#   ('said', 'VBD'),
#   (',', ','),
#   ('it', 'PRP'),
#   ('had', 'VBD'),
#   ('operating', 'VBG'),
#   ('profit', 'NN'),
#   ('of', 'IN'),
#   ('$', '$'),
#   ('10', 'CD'),
#   ('million', 'CD'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('quarter', 'NN'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('move', 'NN'),
#   ('followed', 'VBD'),
#   ('a', 'DT'),
#   ('round', 'NN'),
#   ('of', 'IN'),
#   ('similar', 'JJ'),
#   ('increases', 'NNS'),
#   ('by', 'IN'),
#   ('other', 'JJ'),
#   ('lenders', 'NNS'),
#   ('against', 'IN'),
#   ('Arizona', 'NNP'),
#   ('real', 'JJ'),
#   ('estate', 'NN'),
#   ('loans', 'NNS'),
#   (',', ','),
#   ('reflecting', 'VBG'),
#   ('a', 'DT'),
#   ('continuing', 'VBG'),
#   ('decline', 'NN'),
#   ('in', 'IN'),
#   ('that', 'DT'),
#   ('market', 'NN'),
#   ('.', '.')],
#  [('In', 'IN'),
#   ('addition', 'NN'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('increased', 'VBN'),
#   ('reserve', 'NN'),
#   (',', ','),
#   ('the', 'DT'),
#   ('savings', 'NNS'),
#   ('bank', 'NN'),
#   ('took', 'VBD'),
#   ('a', 'DT'),
#   ('special', 'JJ'),
#   ('charge', 'NN'),
#   ('of', 'IN'),
#   ('$', '$'),
#   ('5', 'CD'),
#   ('million', 'CD'),
#   ('representing', 'VBG'),
#   ('general', 'JJ'),
#   ('and', 'CC'),
#   ('administrative', 'JJ'),
#   ('expenses', 'NNS'),
#   ('from', 'IN'),
#   ('staff', 'NN'),
#   ('reductions', 'NNS'),
#   ('and', 'CC'),
#   ('other', 'JJ'),
#   ('matters', 'NNS'),
#   (',', ','),
#   ('and', 'CC'),
#   ('it', 'PRP'),
#   ('posted', 'VBD'),
#   ('a', 'DT'),
#   ('$', '$'),
#   ('7.6', 'CD'),
#   ('million', 'CD'),
#   ('reduction', 'NN'),
#   ('in', 'IN'),
#   ('expected', 'VBN'),
#   ('mortgage', 'NN'),
#   ('servicing', 'VBG'),
#   ('fees', 'NNS'),
#   (',', ','),
#   ('reflecting', 'VBG'),
#   ('the', 'DT'),
#   ('fact', 'NN'),
#   ('that', 'IN'),
#   ('more', 'JJR'),
#   ('borrowers', 'NNS'),
#   ('are', 'VBP'),
#   ('prepaying', 'VBG'),
#   ('their', 'PRP$'),
#   ('mortgages', 'NNS'),
#   ('.', '.')],
#  [('Arbitragers', 'NNS'),
#   ('were', 'VBD'),
#   ("n't", 'RB'),
#   ('the', 'DT'),
#   ('only', 'RB'),
#   ('big', 'JJ'),
#   ('losers', 'NNS'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('collapse', 'NN'),
#   ('of', 'IN'),
#   ('UAL', 'NNP'),
#   ('Corp.', 'NNP'),
#   ('stock', 'NN'),
#   ('.', '.')],
#  [('Look', 'NNP'),
#   ('at', 'IN'),
#   ('what', 'WP'),
#   ('happened', 'VBD'),
#   ('to', 'TO'),
#   ('UAL', 'NNP'),
#   ("'s", 'POS'),
#   ('chairman', 'NN'),
#   (',', ','),
#   ('Stephen', 'NNP'),
#   ('M.', 'NNP'),
#   ('Wolf', 'NNP'),
#   (',', ','),
#   ('and', 'CC'),
#   ('its', 'PRP$'),
#   ('chief', 'JJ'),
#   ('financial', 'JJ'),
#   ('officer', 'NN'),
#   (',', ','),
#   ('John', 'NNP'),
#   ('C.', 'NNP'),
#   ('Pope', 'NNP'),
#   ('.', '.')],
#  [('On', 'IN'),
#   ('a', 'DT'),
#   ('day', 'NN'),
#   ('some', 'DT'),
#   ('United', 'NNP'),
#   ('Airlines', 'NNPS'),
#   ('employees', 'NNS'),
#   ('wanted', 'VBD'),
#   ('Mr.', 'NNP'),
#   ('Wolf', 'NNP'),
#   ('fired', 'VBD'),
#   ('and', 'CC'),
#   ('takeover', 'NN'),
#   ('stock', 'NN'),
#   ('speculators', 'NNS'),
#   ('wanted', 'VBD'),
#   ('his', 'PRP$'),
#   ('scalp', 'NN'),
#   (',', ','),
#   ('Messrs.', 'NNP'),
#   ('Wolf', 'NNP'),
#   ('and', 'CC'),
#   ('Pope', 'NNP'),
#   ('saw', 'VBD'),
#   ('their', 'PRP$'),
#   ('prospective', 'JJ'),
#   ('personal', 'JJ'),
#   ('fortunes', 'NNS'),
#   ('continue', 'VBP'),
#   ('to', 'TO'),
#   ('plummet', 'VB'),
#   ('as', 'IN'),
#   ('shares', 'NNS'),
#   ('of', 'IN'),
#   ('UAL', 'NNP'),
#   (',', ','),
#   ('United', 'NNP'),
#   ("'s", 'POS'),
#   ('parent', 'NN'),
#   ('company', 'NN'),
#   (',', ','),
#   ('dived', 'VBD'),
#   ('$', '$'),
#   ('24.875', 'CD'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('Big', 'NNP'),
#   ('Board', 'NNP'),
#   ('to', 'TO'),
#   ('close', 'VB'),
#   ('at', 'IN'),
#   ('$', '$'),
#   ('198', 'CD'),
#   ('.', '.')],
#  [('Including', 'NNP'),
#   ('Monday', 'NNP'),
#   ("'s", 'POS'),
#   ('plunge', 'NN'),
#   (',', ','),
#   ('that', 'WDT'),
#   ('has', 'VBZ'),
#   ('given', 'VBN'),
#   ('the', 'DT'),
#   ('two', 'CD'),
#   ('executives', 'NNS'),
#   ('paper', 'NN'),
#   ('losses', 'NNS'),
#   ('of', 'IN'),
#   ('$', '$'),
#   ('49.5', 'CD'),
#   ('million', 'CD'),
#   (',', ','),
#   ('based', 'VBN'),
#   ('on', 'IN'),
#   ('what', 'WP'),
#   ('they', 'PRP'),
#   ('would', 'MD'),
#   ('have', 'VB'),
#   ('realized', 'VBN'),
#   ('had', 'VBD'),
#   ('the', 'DT'),
#   ('pilots', 'NNS'),
#   ('and', 'CC'),
#   ('management-led', 'JJ'),
#   ('buy-out', 'NN'),
#   ('of', 'IN'),
#   ('UAL', 'NNP'),
#   ('gone', 'NN'),
#   ('through', 'IN'),
#   ('at', 'IN'),
#   ('$', '$'),
#   ('300', 'CD'),
#   ('a', 'DT'),
#   ('share', 'NN'),
#   ('.', '.')],
#  [('When', 'WRB'),
#   ('bank', 'NN'),
#   ('financing', 'NN'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('buy-out', 'NN'),
#   ('collapsed', 'VBD'),
#   ('last', 'JJ'),
#   ('week', 'NN'),
#   (',', ','),
#   ('so', 'RB'),
#   ('did', 'VBD'),
#   ('UAL', 'NNP'),
#   ("'s", 'POS'),
#   ('stock', 'NN'),
#   ('.', '.')],
#  [('Even', 'RB'),
#   ('if', 'IN'),
#   ('the', 'DT'),
#   ('banks', 'NNS'),
#   ('resurrect', 'VBP'),
#   ('a', 'DT'),
#   ('financing', 'NN'),
#   ('package', 'NN'),
#   ('at', 'IN'),
#   ('$', '$'),
#   ('250', 'CD'),
#   ('a', 'DT'),
#   ('share', 'NN'),
#   (',', ','),
#   ('the', 'DT'),
#   ('two', 'CD'),
#   ('executives', 'NNS'),
#   ('would', 'MD'),
#   ('still', 'RB'),
#   ('get', 'VB'),
#   ('about', 'RB'),
#   ('$', '$'),
#   ('25', 'CD'),
#   ('million', 'CD'),
#   ('less', 'JJR'),
#   ('than', 'IN'),
#   ('they', 'PRP'),
#   ('stood', 'VBD'),
#   ('to', 'TO'),
#   ('gain', 'VB'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('initial', 'JJ'),
#   ('transaction', 'NN'),
#   ('.', '.')],
#  [('Mr.', 'NNP'),
#   ('Wolf', 'NNP'),
#   ('owns', 'VBZ'),
#   ('75,000', 'CD'),
#   ('UAL', 'NNP'),
#   ('shares', 'NNS'),
#   ('and', 'CC'),
#   ('has', 'VBZ'),
#   ('options', 'NNS'),
#   ('to', 'TO'),
#   ('buy', 'VB'),
#   ('another', 'DT'),
#   ('250,000', 'CD'),
#   ('at', 'IN'),
#   ('$', '$'),
#   ('83.3125', 'CD'),
#   ('each', 'DT'),
#   ('.', '.')],
#  [('In', 'IN'),
#   ('the', 'DT'),
#   ('$', '$'),
#   ('300-a-share', 'JJ'),
#   ('buyout', 'NN'),
#   (',', ','),
#   ('that', 'WDT'),
#   ('totaled', 'VBD'),
#   ('about', 'RB'),
#   ('$', '$'),
#   ('76.7', 'CD'),
#   ('million', 'CD'),
#   ('.', '.')],
#  [('By', 'IN'),
#   ('yesterday', 'NN'),
#   ("'s", 'POS'),
#   ('close', 'NN'),
#   ('of', 'IN'),
#   ('trading', 'NN'),
#   (',', ','),
#   ('it', 'PRP'),
#   ('was', 'VBD'),
#   ('good', 'JJ'),
#   ('for', 'IN'),
#   ('a', 'DT'),
#   ('paltry', 'NN'),
#   ('$', '$'),
#   ('43.5', 'CD'),
#   ('million', 'CD'),
#   ('.', '.')],
#  [('Of', 'IN'),
#   ('course', 'NN'),
#   (',', ','),
#   ('Mr.', 'NNP'),
#   ('Wolf', 'NNP'),
#   (',', ','),
#   ('48', 'CD'),
#   ('years', 'NNS'),
#   ('old', 'JJ'),
#   (',', ','),
#   ('has', 'VBZ'),
#   ('some', 'DT'),
#   ('savings', 'NNS'),
#   ('.', '.')],
#  [('He', 'PRP'),
#   ('left', 'VBD'),
#   ('his', 'PRP$'),
#   ('last', 'JJ'),
#   ('two', 'CD'),
#   ('jobs', 'NNS'),
#   ('at', 'IN'),
#   ('Republic', 'NNP'),
#   ('Airlines', 'NNPS'),
#   ('and', 'CC'),
#   ('Flying', 'NNP'),
#   ('Tiger', 'NNP'),
#   ('with', 'IN'),
#   ('combined', 'VBN'),
#   ('stock-option', 'NN'),
#   ('gains', 'NNS'),
#   ('of', 'IN'),
#   ('about', 'RB'),
#   ('$', '$'),
#   ('22', 'CD'),
#   ('million', 'CD'),
#   (',', ','),
#   ('and', 'CC'),
#   ('UAL', 'NNP'),
#   ('gave', 'VBD'),
#   ('him', 'PRP'),
#   ('a', 'DT'),
#   ('$', '$'),
#   ('15', 'CD'),
#   ('million', 'CD'),
#   ('bonus', 'NN'),
#   ('when', 'WRB'),
#   ('it', 'PRP'),
#   ('hired', 'VBD'),
#   ('him', 'PRP'),
#   ('.', '.')],
#  [('His', 'PRP$'),
#   ('1988', 'CD'),
#   ('salary', 'NN'),
#   ('was', 'VBD'),
#   ('$', '$'),
#   ('575,000', 'CD'),
#   (',', ','),
#   ('with', 'IN'),
#   ('a', 'DT'),
#   ('$', '$'),
#   ('575,000', 'CD'),
#   ('bonus', 'NN'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('40-year', 'JJ'),
#   ('old', 'JJ'),
#   ('Mr.', 'NNP'),
#   ('Pope', 'NNP'),
#   ('has', 'VBZ'),
#   ("n't", 'RB'),
#   ('changed', 'VBN'),
#   ('jobs', 'NNS'),
#   ('enough', 'RB'),
#   ('--', ':'),
#   ('at', 'IN'),
#   ('least', 'JJS'),
#   ('the', 'DT'),
#   ('right', 'NN'),
#   ('ones', 'NNS'),
#   ('--', ':'),
#   ('to', 'TO'),
#   ('stash', 'VB'),
#   ('away', 'RB'),
#   ('that', 'IN'),
#   ('kind', 'NN'),
#   ('of', 'IN'),
#   ('money', 'NN'),
#   ('.', '.')],
#  [('United', 'NNP'),
#   ('paid', 'VBD'),
#   ('him', 'PRP'),
#   ('a', 'DT'),
#   ('$', '$'),
#   ('375,000', 'CD'),
#   ('bonus', 'NN'),
#   ('to', 'TO'),
#   ('lure', 'VB'),
#   ('him', 'PRP'),
#   ('away', 'RB'),
#   ('from', 'IN'),
#   ('American', 'NNP'),
#   ('Airlines', 'NNPS'),
#   (',', ','),
#   ('and', 'CC'),
#   ('he', 'PRP'),
#   ('was', 'VBD'),
#   ('paid', 'VBN'),
#   ('a', 'DT'),
#   ('salary', 'NN'),
#   ('of', 'IN'),
#   ('$', '$'),
#   ('342,122', 'CD'),
#   ('last', 'JJ'),
#   ('year', 'NN'),
#   ('with', 'IN'),
#   ('a', 'DT'),
#   ('$', '$'),
#   ('280,000', 'CD'),
#   ('bonus', 'NN'),
#   ('.', '.')],
#  [('Mr.', 'NNP'),
#   ('Pope', 'NNP'),
#   ('owns', 'VBZ'),
#   ('10,000', 'CD'),
#   ('UAL', 'NNP'),
#   ('shares', 'NNS'),
#   ('and', 'CC'),
#   ('has', 'VBZ'),
#   ('options', 'NNS'),
#   ('to', 'TO'),
#   ('buy', 'VB'),
#   ('another', 'DT'),
#   ('150,000', 'CD'),
#   ('at', 'IN'),
#   ('$', '$'),
#   ('69', 'CD'),
#   ('each', 'DT'),
#   ('.', '.')],
#  [('That', 'DT'),
#   ('came', 'NN'),
#   ('to', 'TO'),
#   ('a', 'DT'),
#   ('combined', 'VBN'),
#   ('$', '$'),
#   ('37.7', 'CD'),
#   ('million', 'CD'),
#   ('under', 'IN'),
#   ('the', 'DT'),
#   ('$', '$'),
#   ('300-a-share', 'JJ'),
#   ('buy-out', 'NN'),
#   (',', ','),
#   ('but', 'CC'),
#   ('just', 'RB'),
#   ('$', '$'),
#   ('21.3', 'CD'),
#   ('million', 'CD'),
#   ('at', 'IN'),
#   ('yesterday', 'NN'),
#   ("'s", 'POS'),
#   ('close', 'NN'),
#   ('.', '.')],
#  [('Of', 'IN'),
#   ('the', 'DT'),
#   ('combined', 'VBN'),
#   ('$', '$'),
#   ('114.4', 'CD'),
#   ('million', 'CD'),
#   ('the', 'DT'),
#   ('two', 'CD'),
#   ('men', 'NNS'),
#   ('were', 'VBD'),
#   ('scheduled', 'VBN'),
#   ('to', 'TO'),
#   ('reap', 'VB'),
#   ('under', 'IN'),
#   ('the', 'DT'),
#   ('buy-out', 'NN'),
#   (',', ','),
#   ('they', 'PRP'),
#   ('agreed', 'VBD'),
#   ('to', 'TO'),
#   ('invest', 'VB'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('buy-out', 'NN'),
#   ('just', 'RB'),
#   ('$', '$'),
#   ('15', 'CD'),
#   ('million', 'CD'),
#   (',', ','),
#   ('angering', 'VBG'),
#   ('many', 'JJ'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('thousands', 'NNS'),
#   ('of', 'IN'),
#   ('workers', 'NNS'),
#   ('asked', 'VBD'),
#   ('to', 'TO'),
#   ('make', 'VB'),
#   ('pay', 'NN'),
#   ('concessions', 'NNS'),
#   ('so', 'RB'),
#   ('the', 'DT'),
#   ('buy-out', 'NN'),
#   ('would', 'MD'),
#   ('be', 'VB'),
#   ('a', 'DT'),
#   ('success', 'NN'),
#   ('.', '.')],
#  [('United', 'NNP'),
#   ("'s", 'POS'),
#   ('directors', 'NNS'),
#   ('voted', 'VBD'),
#   ('themselves', 'PRP'),
#   (',', ','),
#   ('and', 'CC'),
#   ('their', 'PRP$'),
#   ('spouses', 'NNS'),
#   (',', ','),
#   ('lifetime', 'JJ'),
#   ('access', 'NN'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('Friendly', 'NNP'),
#   ('Skies', 'NNP'),
#   ('--', ':'),
#   ('free', 'JJ'),
#   ('first-class', 'NN'),
#   ('travel', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('$', '$'),
#   ('20,000', 'CD'),
#   ('a', 'DT'),
#   ('year', 'NN'),
#   ('for', 'IN'),
#   ('life', 'NN'),
#   ('as', 'IN'),
#   ('well', 'RB'),
#   ('.', '.')],
#  [('Conceivably', 'RB'),
#   (',', ','),
#   ('in', 'IN'),
#   ('a', 'DT'),
#   ('scaled-back', 'NN'),
#   ('buy-out', 'NN'),
#   (',', ','),
#   ('they', 'PRP'),
#   ('could', 'MD'),
#   ('be', 'VB'),
#   ('bumped', 'VBN'),
#   ('back', 'RB'),
#   ('to', 'TO'),
#   ('coach', 'VB'),
#   ('seats', 'NNS'),
#   ('for', 'IN'),
#   ('life', 'NN'),
#   ('.', '.')],
#  [('Thomas', 'NNP'),
#   ('H.', 'NNP'),
#   ('Johnson', 'NNP'),
#   (',', ','),
#   ('president', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('Coatedboard', 'NNP'),
#   ('division', 'NN'),
#   ('of', 'IN'),
#   ('Mead', 'NNP'),
#   ('Corp.', 'NNP'),
#   (',', ','),
#   ('was', 'VBD'),
#   ('named', 'VBN'),
#   ('president', 'NN'),
#   ('of', 'IN'),
#   ('Manville', 'NNP'),
#   ('Forest', 'NNP'),
#   ('Products', 'NNP'),
#   ('Corp.', 'NNP'),
#   (',', ','),
#   ('a', 'DT'),
#   ('Manville', 'NNP'),
#   ('unit', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('senior', 'JJ'),
#   ('vice', 'NN'),
#   ('president', 'NN'),
#   ('of', 'IN'),
#   ('Manville', 'NNP'),
#   ('Corp', 'NNP'),
#   ('.', '.')],
#  [('Mr.', 'NNP'),
#   ('Johnson', 'NNP'),
#   ('succeeds', 'VBZ'),
#   ('Harry', 'NNP'),
#   ('W.', 'NNP'),
#   ('Sherman', 'NNP'),
#   (',', ','),
#   ('who', 'WP'),
#   ('resigned', 'VBD'),
#   ('to', 'TO'),
#   ('pursue', 'VB'),
#   ('other', 'JJ'),
#   ('interests', 'NNS'),
#   (',', ','),
#   ('in', 'IN'),
#   ('both', 'DT'),
#   ('positions', 'NNS'),
#   ('.', '.')],
#  [('Manville', 'NNP'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('building', 'NN'),
#   ('and', 'CC'),
#   ('forest', 'NN'),
#   ('products', 'NNS'),
#   ('concern', 'VBP'),
#   ('.', '.')],
#  [('US', 'NNP'),
#   ('Facilities', 'NNP'),
#   ('Corp.', 'NNP'),
#   ('said', 'VBD'),
#   ('Robert', 'NNP'),
#   ('J.', 'NNP'),
#   ('Percival', 'NNP'),
#   ('agreed', 'VBD'),
#   ('to', 'TO'),
#   ('step', 'VB'),
#   ('down', 'RB'),
#   ('as', 'IN'),
#   ('vice', 'NN'),
#   ('chairman', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('insurance', 'NN'),
#   ('holding', 'VBG'),
#   ('company', 'NN'),
#   ('.', '.')],
#  [('``', '``'),
#   ('There', 'EX'),
#   ('was', 'VBD'),
#   ('a', 'DT'),
#   ('difference', 'NN'),
#   ('of', 'IN'),
#   ('opinion', 'NN'),
#   ('as', 'IN'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('future', 'NN'),
#   ('direction', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('company', 'NN'),
#   (',', ','),
#   ("''", "''"),
#   ('a', 'DT'),
#   ('spokeswoman', 'NN'),
#   ('said', 'VBD'),
#   ('.', '.')],
#  [('Mr.', 'NNP'),
#   ('Percival', 'NNP'),
#   ('declined', 'VBD'),
#   ('to', 'TO'),
#   ('comment', 'VB'),
#   ('.', '.')],
#  [('In', 'IN'),
#   ('a', 'DT'),
#   ('statement', 'NN'),
#   (',', ','),
#   ('US', 'NNP'),
#   ('Facilities', 'NNP'),
#   ('said', 'VBD'),
#   ('Mr.', 'NNP'),
#   ('Percival', 'NNP'),
#   ("'s", 'POS'),
#   ('employment', 'NN'),
#   ('contract', 'NN'),
#   ('calls', 'VBZ'),
#   ('for', 'IN'),
#   ('him', 'PRP'),
#   ('to', 'TO'),
#   ('act', 'VB'),
#   ('as', 'IN'),
#   ('a', 'DT'),
#   ('consultant', 'NN'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('company', 'NN'),
#   ('for', 'IN'),
#   ('two', 'CD'),
#   ('years', 'NNS'),
#   ('.', '.')],
#  [('He', 'PRP'),
#   ('will', 'MD'),
#   ('also', 'RB'),
#   ('remain', 'VB'),
#   ('a', 'DT'),
#   ('director', 'NN'),
#   (',', ','),
#   ('US', 'NNP'),
#   ('Facilities', 'NNP'),
#   ('said', 'VBD'),
#   (',', ','),
#   ('but', 'CC'),
#   ('wo', 'MD'),
#   ("n't", 'RB'),
#   ('serve', 'VB'),
#   ('on', 'IN'),
#   ('any', 'DT'),
#   ('board', 'NN'),
#   ('committees', 'NNS'),
#   ('.', '.')],
#  [('Mr.', 'NNP'),
#   ('Percival', 'NNP'),
#   ('will', 'MD'),
#   ('be', 'VB'),
#   ('succeeded', 'VBN'),
#   ('on', 'IN'),
#   ('an', 'DT'),
#   ('interim', 'JJ'),
#   ('basis', 'NN'),
#   ('by', 'IN'),
#   ('George', 'NNP'),
#   ('Kadonada', 'NNP'),
#   (',', ','),
#   ('US', 'NNP'),
#   ('Facilities', 'NNP'),
#   ('chairman', 'NN'),
#   ('and', 'CC'),
#   ('president', 'NN'),
#   ('.', '.')],
#  [('In', 'IN'),
#   ('the', 'DT'),
#   ('same', 'JJ'),
#   ('statement', 'NN'),
#   (',', ','),
#   ('US', 'NNP'),
#   ('Facilities', 'NNP'),
#   ('also', 'RB'),
#   ('said', 'VBD'),
#   ('it', 'PRP'),
#   ('had', 'VBD'),
#   ('bought', 'VBN'),
#   ('back', 'RB'),
#   ('112,000', 'CD'),
#   ('of', 'IN'),
#   ('its', 'PRP$'),
#   ('common', 'JJ'),
#   ('shares', 'NNS'),
#   ('in', 'IN'),
#   ('a', 'DT'),
#   ('private', 'JJ'),
#   ('transaction', 'NN'),
#   ('.', '.')],
#  [('Terms', 'NNS'),
#   ('were', 'VBD'),
#   ("n't", 'RB'),
#   ('disclosed', 'VBN'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('buy-back', 'NN'),
#   ('represents', 'NNS'),
#   ('about', 'IN'),
#   ('3', 'CD'),
#   ('%', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('company', 'NN'),
#   ("'s", 'POS'),
#   ('shares', 'NNS'),
#   (',', ','),
#   ('based', 'VBN'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('3.7', 'CD'),
#   ('million', 'CD'),
#   ('shares', 'NNS'),
#   ('outstanding', 'JJ'),
#   ('as', 'IN'),
#   ('of', 'IN'),
#   ('Sept.', 'NNP'),
#   ('30', 'CD'),
#   ('.', '.')],
#  [('In', 'IN'),
#   ('national', 'JJ'),
#   ('over-the-counter', 'JJ'),
#   ('trading', 'NN'),
#   ('yesterday', 'NN'),
#   (',', ','),
#   ('US', 'NNP'),
#   ('Facilities', 'NNP'),
#   ('closed', 'VBD'),
#   ('at', 'IN'),
#   ('$', '$'),
#   ('3.625', 'CD'),
#   (',', ','),
#   ('unchanged', 'JJ'),
#   ('.', '.')],
#  [('Three', 'CD'),
#   ('leading', 'VBG'),
#   ('drug', 'NN'),
#   ('companies', 'NNS'),
#   ('reported', 'VBD'),
#   ('robust', 'RB'),
#   ('third-quarter', 'JJ'),
#   ('earnings', 'NNS'),
#   (',', ','),
#   ('bolstered', 'VBN'),
#   ('by', 'IN'),
#   ('strong', 'JJ'),
#   ('sales', 'NNS'),
#   ('of', 'IN'),
#   ('newer', 'JJR'),
#   (',', ','),
#   ('big-selling', 'VBG'),
#   ('prescriptions', 'NNS'),
#   ('drugs', 'NNS'),
#   ('that', 'WDT'),
#   ('provide', 'VBP'),
#   ('hefty', 'JJ'),
#   ('profit', 'NN'),
#   ('margins', 'NNS'),
#   ('.', '.')],
#  [('Merck', 'NNP'),
#   ('&', 'CC'),
#   ('Co.', 'NNP'),
#   ('reported', 'VBD'),
#   ('a', 'DT'),
#   ('25', 'CD'),
#   ('%', 'NN'),
#   ('increase', 'NN'),
#   ('in', 'IN'),
#   ('earnings', 'NNS'),
#   (';', ':'),
#   ('Warner-Lambert', 'NNP'),
#   ('Co.', 'NNP'),
#   ("'s", 'POS'),
#   ('profit', 'NN'),
#   ('rose', 'VBD'),
#   ('22', 'CD'),
#   ('%', 'NN'),
#   ('and', 'CC'),
#   ('Eli', 'NNP'),
#   ('Lilly', 'NNP'),
#   ('&', 'CC'),
#   ('Co.', 'NNP'),
#   ("'s", 'POS'),
#   ('net', 'JJ'),
#   ('income', 'NN'),
#   ('rose', 'VBD'),
#   ('24', 'CD'),
#   ('%', 'NN'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('results', 'NNS'),
#   ('were', 'VBD'),
#   ('in', 'IN'),
#   ('line', 'NN'),
#   ('with', 'IN'),
#   ('analysts', 'NNS'),
#   ("'", 'POS'),
#   ('expectations', 'NNS'),
#   ('.', '.')],
#  [('Merck', 'NNP'), ('&', 'CC'), ('Co', 'NNP'), ('.', '.')],
#  [('Merck', 'NNP'),
#   (',', ','),
#   ('Rahway', 'NNP'),
#   (',', ','),
#   ('N.J.', 'NNP'),
#   (',', ','),
#   ('continued', 'VBD'),
#   ('to', 'TO'),
#   ('lead', 'VB'),
#   ('the', 'DT'),
#   ('industry', 'NN'),
#   ('with', 'IN'),
#   ('a', 'DT'),
#   ('strong', 'JJ'),
#   ('sales', 'NNS'),
#   ('performance', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('human', 'NN'),
#   ('and', 'CC'),
#   ('animal', 'JJ'),
#   ('health-products', 'NNS'),
#   ('segment', 'NN'),
#   ('.', '.')],
#  [('A', 'DT'),
#   ('stronger', 'JJR'),
#   ('U.S.', 'NNP'),
#   ('dollar', 'NN'),
#   ('reduced', 'VBD'),
#   ('third-quarter', 'JJ'),
#   ('and', 'CC'),
#   ('first-nine-month', 'JJ'),
#   ('sales', 'NNS'),
#   ('growth', 'NN'),
#   ('2', 'CD'),
#   ('%', 'NN'),
#   ('and', 'CC'),
#   ('3', 'CD'),
#   ('%', 'NN'),
#   (',', ','),
#   ('respectively', 'RB'),
#   ('.', '.')],
#  [('International', 'JJ'),
#   ('sales', 'NNS'),
#   ('accounted', 'VBD'),
#   ('for', 'IN'),
#   ('47', 'CD'),
#   ('%', 'NN'),
#   ('of', 'IN'),
#   ('total', 'JJ'),
#   ('company', 'NN'),
#   ('sales', 'NNS'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('nine', 'CD'),
#   ('months', 'NNS'),
#   (',', ','),
#   ('compared', 'VBN'),
#   ('with', 'IN'),
#   ('50', 'CD'),
#   ('%', 'NN'),
#   ('a', 'DT'),
#   ('year', 'NN'),
#   ('earlier', 'RBR'),
#   ('.', '.')],
#  [('Sales', 'NNS'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('quarter', 'NN'),
#   ('rose', 'VBD'),
#   ('to', 'TO'),
#   ('$', '$'),
#   ('1.63', 'CD'),
#   ('billion', 'CD'),
#   ('from', 'IN'),
#   ('$', '$'),
#   ('1.47', 'CD'),
#   ('billion', 'CD'),
#   ('.', '.')],
#  [('Mevacor', 'NNP'),
#   (',', ','),
#   ('Merck', 'NNP'),
#   ("'s", 'POS'),
#   ('new', 'JJ'),
#   ('cholesterol-lowering', 'NN'),
#   ('drug', 'NN'),
#   (',', ','),
#   ('had', 'VBD'),
#   ('higher', 'JJR'),
#   ('sales', 'NNS'),
#   ('than', 'IN'),
#   ('any', 'DT'),
#   ('other', 'JJ'),
#   ('prescription', 'NN'),
#   ('medicine', 'NN'),
#   ('has', 'VBZ'),
#   ('ever', 'RB'),
#   ('achieved', 'VBN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('U.S.', 'NNP'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('year', 'NN'),
#   ('following', 'VBG'),
#   ('introduction', 'NN'),
#   (',', ','),
#   ('the', 'DT'),
#   ('company', 'NN'),
#   ('said', 'VBD'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('drug', 'NN'),
#   ('was', 'VBD'),
#   ('introduced', 'VBN'),
#   ('in', 'IN'),
#   ('West', 'NNP'),
#   ('Germany', 'NNP'),
#   ('this', 'DT'),
#   ('year', 'NN'),
#   ('.', '.')],
#  [('Intense', 'NN'),
#   ('competition', 'NN'),
#   (',', ','),
#   ('however', 'RB'),
#   (',', ','),
#   ('led', 'VBN'),
#   ('to', 'TO'),
#   ('unit', 'VB'),
#   ('sales', 'NNS'),
#   ('declines', 'NNS'),
#   ('for', 'IN'),
#   ('a', 'DT'),
#   ('group', 'NN'),
#   ('of', 'IN'),
#   ('Merck', 'NNP'),
#   ("'s", 'POS'),
#   ('established', 'VBN'),
#   ('human', 'NN'),
#   ('and', 'CC'),
#   ('animal-health', 'NN'),
#   ('products', 'NNS'),
#   (',', ','),
#   ('including', 'VBG'),
#   ('Aldomet', 'NNP'),
#   ('and', 'CC'),
#   ('Indocin', 'NNP'),
#   ('.', '.')],
#  [('In', 'IN'),
#   ('New', 'NNP'),
#   ('York', 'NNP'),
#   ('Stock', 'NNP'),
#   ('Exchange', 'NNP'),
#   ('composite', 'JJ'),
#   ('trading', 'NN'),
#   ('yesterday', 'NN'),
#   (',', ','),
#   ('Merck', 'NNP'),
#   ('shares', 'NNS'),
#   ('closed', 'VBD'),
#   ('at', 'IN'),
#   ('$', '$'),
#   ('75.25', 'CD'),
#   (',', ','),
#   ('up', 'IN'),
#   ('50', 'CD'),
#   ('cents', 'NNS'),
#   ('.', '.')],
#  [('Warner-Lambert', 'NNP'), ('Co', 'NNP'), ('.', '.')],
#  [('Warner-Lambert', 'NNP'),
#   (',', ','),
#   ('Morris', 'NNP'),
#   ('Plains', 'NNP'),
#   (',', ','),
#   ('N.J.', 'NNP'),
#   (',', ','),
#   ('reported', 'VBD'),
#   ('sales', 'NNS'),
#   ('that', 'WDT'),
#   ('were', 'VBD'),
#   ('a', 'DT'),
#   ('record', 'NN'),
#   ('for', 'IN'),
#   ('any', 'DT'),
#   ('quarter', 'NN'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('eighth', 'JJ'),
#   ('quarter', 'NN'),
#   ('in', 'IN'),
#   ('a', 'DT'),
#   ('row', 'NN'),
#   ('of', 'IN'),
#   ('20', 'CD'),
#   ('%', 'NN'),
#   ('or', 'CC'),
#   ('more', 'RBR'),
#   ('per-share', 'JJ'),
#   ('earnings', 'NNS'),
#   ('growth', 'NN'),
#   ('.', '.')],
#  [('Spurred', 'VBN'),
#   ('by', 'IN'),
#   ('growth', 'NN'),
#   ('in', 'IN'),
#   ('world-wide', 'JJ'),
#   ('sales', 'NNS'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('company', 'NN'),
#   ("'s", 'POS'),
#   ('prescription', 'NN'),
#   ('drugs', 'NNS'),
#   (',', ','),
#   ('Warner-Lambert', 'NNP'),
#   ('said', 'VBD'),
#   ('1989', 'CD'),
#   ('will', 'MD'),
#   ('be', 'VB'),
#   ('the', 'DT'),
#   ('best', 'JJS'),
#   ('year', 'NN'),
#   ('in', 'IN'),
#   ('its', 'PRP$'),
#   ('history', 'NN'),
#   (',', ','),
#   ('with', 'IN'),
#   ('per-share', 'JJ'),
#   ('earnings', 'NNS'),
#   ('expected', 'VBN'),
#   ('to', 'TO'),
#   ('increase', 'VB'),
#   ('more', 'JJR'),
#   ('than', 'IN'),
#   ('20', 'CD'),
#   ('%', 'NN'),
#   ('to', 'TO'),
#   ('about', 'RB'),
#   ('$', '$'),
#   ('6.10', 'CD'),
#   ('.', '.')],
#  [('Sales', 'NNS'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('quarter', 'NN'),
#   ('rose', 'VBD'),
#   ('to', 'TO'),
#   ('$', '$'),
#   ('1.11', 'CD'),
#   ('billion', 'CD'),
#   ('from', 'IN'),
#   ('$', '$'),
#   ('1.03', 'CD'),
#   ('billion', 'CD'),
#   ('.', '.')],
#  [('Prescription-drug', 'NNP'),
#   ('world-wide', 'JJ'),
#   ('sales', 'NNS'),
#   ('rose', 'VBD'),
#   ('9', 'CD'),
#   ('%', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('quarter', 'NN'),
#   ('to', 'TO'),
#   ('$', '$'),
#   ('340', 'CD'),
#   ('million', 'CD'),
#   (';', ':'),
#   ('U.S.', 'NNP'),
#   ('sales', 'NNS'),
#   ('rose', 'VBD'),
#   ('15', 'CD'),
#   ('%', 'NN'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('segment', 'NN'),
#   ("'s", 'POS'),
#   ('growth', 'NN'),
#   ('was', 'VBD'),
#   ('led', 'VBN'),
#   ('by', 'IN'),
#   ('sales', 'NNS'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('cardiovascular', 'JJ'),
#   ('drugs', 'NNS'),
#   ('Lopid', 'NNP'),
#   (',', ','),
#   ('a', 'DT'),
#   ('lipid', 'JJ'),
#   ('regulator', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('Dilzem', 'NNP'),
#   (',', ','),
#   ('a', 'DT'),
#   ('calcium', 'NN'),
#   ('channel', 'NN'),
#   ('blocker', 'NN'),
#   ('.', '.')],
#  [('World-wide', 'JJ'),
#   ('sales', 'NNS'),
#   ('of', 'IN'),
#   ('Warner-Lambert', 'NNP'),
#   ("'s", 'POS'),
#   ('non-prescription', 'NN'),
#   ('health-care', 'NN'),
#   ('products', 'NNS'),
#   (',', ','),
#   ('such', 'JJ'),
#   ('as', 'IN'),
#   ('Halls', 'NNP'),
#   ('cough', 'IN'),
#   ('tablets', 'NNS'),
#   (',', ','),
#   ('Rolaids', 'NNP'),
#   ('antacid', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('Lubriderm', 'NNP'),
#   ('skin', 'NN'),
#   ('lotion', 'NN'),
#   (',', ','),
#   ('increased', 'VBN'),
#   ('3', 'CD'),
#   ('%', 'NN'),
#   ('to', 'TO'),
#   ('$', '$'),
#   ('362', 'CD'),
#   ('million', 'CD'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('third', 'JJ'),
#   ('quarter', 'NN'),
#   (';', ':'),
#   ('U.S.', 'NNP'),
#   ('sales', 'NNS'),
#   ('rose', 'VBD'),
#   ('5', 'NN'),
#   ('%', 'NN'),
#   ('.', '.')],
#  [('Confectionery', 'NNP'),
#   ('products', 'NNS'),
#   ('sales', 'NNS'),
#   ('also', 'RB'),
#   ('had', 'VBD'),
#   ('strong', 'JJ'),
#   ('growth', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('quarter', 'NN'),
#   ('.', '.')],
#  [('World-wide', 'JJ'),
#   ('sales', 'NNS'),
#   ('of', 'IN'),
#   ('Trident', 'NNP'),
#   ('gum', 'NN'),
#   (',', ','),
#   ('Certs', 'NNP'),
#   ('breath', 'NN'),
#   ('mints', 'NNS'),
#   (',', ','),
#   ('and', 'CC'),
#   ('Clorets', 'NNPS'),
#   ('gum', 'NN'),
#   ('and', 'CC'),
#   ('breath', 'NN'),
#   ('mints', 'NNS'),
#   (',', ','),
#   ('increased', 'VBN'),
#   ('12', 'CD'),
#   ('%', 'NN'),
#   ('to', 'TO'),
#   ('$', '$'),
#   ('277', 'CD'),
#   ('million', 'CD'),
#   ('.', '.')],
#  [('Warner-Lambert', 'JJ'),
#   ('shares', 'NNS'),
#   ('closed', 'VBD'),
#   ('at', 'IN'),
#   ('$', '$'),
#   ('109.50', 'CD'),
#   ('a', 'DT'),
#   ('share', 'NN'),
#   (',', ','),
#   ('up', 'IN'),
#   ('$', '$'),
#   ('1.50', 'CD'),
#   (',', ','),
#   ('in', 'IN'),
#   ('Big', 'NNP'),
#   ('Board', 'NNP'),
#   ('composite', 'JJ'),
#   ('trading', 'NN'),
#   ('yesterday', 'NN'),
#   ('.', '.')],
#  [('Eli', 'NNP'), ('Lilly', 'NNP'), ('&', 'CC'), ('Co', 'NNP'), ('.', '.')],
#  [('Lilly', 'RB'),
#   ('attributed', 'VBN'),
#   ('record', 'NN'),
#   ('third-quarter', 'JJ'),
#   ('and', 'CC'),
#   ('nine-month', 'JJ'),
#   ('results', 'NNS'),
#   ('to', 'TO'),
#   ('world-wide', 'VB'),
#   ('gains', 'NNS'),
#   ('for', 'IN'),
#   ('pharmaceuticals', 'NNS'),
#   (',', ','),
#   ('medical', 'JJ'),
#   ('instruments', 'NNS'),
#   ('and', 'CC'),
#   ('plant-science', 'NN'),
#   ('products', 'NNS'),
#   ('despite', 'IN'),
#   ('poor', 'JJ'),
#   ('exchange', 'NN'),
#   ('rates', 'NNS'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('dollar', 'NN'),
#   ('that', 'WDT'),
#   ('slowed', 'VBD'),
#   ('sales', 'NNS'),
#   ('abroad', 'RB'),
#   ('.', '.')],
#  [('Earnings', 'NNS'),
#   ('continued', 'VBD'),
#   ('to', 'TO'),
#   ('pace', 'VB'),
#   ('sales', 'NNS'),
#   ('because', 'IN'),
#   ('of', 'IN'),
#   ('a', 'DT'),
#   ('lower', 'JJR'),
#   ('tax', 'NN'),
#   ('rate', 'NN'),
#   (',', ','),
#   ('profit', 'NN'),
#   ('from', 'IN'),
#   ('the', 'DT'),
#   ('renegotiation', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('debt', 'NN'),
#   ('instrument', 'NN'),
#   ('received', 'VBD'),
#   ('from', 'IN'),
#   ('Faberge', 'NNP'),
#   ('Inc.', 'NNP'),
#   ('in', 'IN'),
#   ('connection', 'NN'),
#   ('with', 'IN'),
#   ('Lilly', 'NNP'),
#   ("'s", 'POS'),
#   ('sale', 'NN'),
#   ('of', 'IN'),
#   ('Elizabeth', 'NNP'),
#   ('Arden', 'NNP'),
#   ('Inc.', 'NNP'),
#   ('in', 'IN'),
#   ('1987', 'CD'),
#   (',', ','),
#   ('and', 'CC'),
#   ('net', 'JJ'),
#   ('proceeds', 'NNS'),
#   ('from', 'IN'),
#   ('the', 'DT'),
#   ('settlement', 'NN'),
#   ('of', 'IN'),
#   ('patent', 'JJ'),
#   ('litigation', 'NN'),
#   ('at', 'IN'),
#   ('Lilly', 'NNP'),
#   ("'s", 'POS'),
#   ('Hybritech', 'NNP'),
#   ('Inc.', 'NNP'),
#   ('unit', 'NN'),
#   ('.', '.')],
#  [('Third-quarter', 'JJ'),
#   ('sales', 'NNS'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('Indianapolis', 'NNP'),
#   (',', ','),
#   ('Ind.', 'NNP'),
#   (',', ','),
#   ('company', 'NN'),
#   ('rose', 'VBD'),
#   ('11', 'CD'),
#   ('%', 'NN'),
#   ('to', 'TO'),
#   ('$', '$'),
#   ('1.045', 'CD'),
#   ('billion', 'CD'),
#   ('from', 'IN'),
#   ('$', '$'),
#   ('940.6', 'CD'),
#   ('million', 'CD'),
#   ('.', '.')],
#  [('Nine-month', 'JJ'),
#   ('sales', 'NNS'),
#   ('grew', 'VBD'),
#   ('12', 'CD'),
#   ('%', 'NN'),
#   ('to', 'TO'),
#   ('$', '$'),
#   ('3.39', 'CD'),
#   ('billion', 'CD'),
#   ('from', 'IN'),
#   ('$', '$'),
#   ('3.03', 'CD'),
#   ('billion', 'CD'),
#   ('a', 'DT'),
#   ('year', 'NN'),
#   ('earlier', 'RBR'),
#   ('.', '.')],
#  [('Sales', 'NNS'),
#   ('of', 'IN'),
#   ('Prozac', 'NNP'),
#   (',', ','),
#   ('an', 'DT'),
#   ('anti-depressant', 'NN'),
#   (',', ','),
#   ('led', 'VBN'),
#   ('drug-sales', 'NNS'),
#   ('increases', 'NNS'),
#   ('.', '.')],
#  [('Higher', 'JJ'),
#   ('sales', 'NNS'),
#   ('of', 'IN'),
#   ('pesticides', 'NNS'),
#   ('and', 'CC'),
#   ('other', 'JJ'),
#   ('plant-science', 'NN'),
#   ('products', 'NNS'),
#   ('more', 'JJR'),
#   ('than', 'IN'),
#   ('offset', 'VB'),
#   ('a', 'DT'),
#   ('slight', 'JJ'),
#   ('decline', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('sales', 'NNS'),
#   ('of', 'IN'),
#   ('animal-health', 'NN'),
#   ('products', 'NNS'),
#   ('to', 'TO'),
#   ('fuel', 'VB'),
#   ('the', 'DT'),
#   ('increase', 'NN'),
#   ('in', 'IN'),
#   ('world-wide', 'JJ'),
#   ('agricultural', 'JJ'),
#   ('product', 'NN'),
#   ('sales', 'NNS'),
#   (',', ','),
#   ('Lilly', 'NNP'),
#   ('said', 'VBD'),
#   ('.', '.')],
#  [('Advanced', 'NNP'),
#   ('Cardiovascular', 'NNP'),
#   ('Systems', 'NNP'),
#   ('Inc.', 'NNP'),
#   ('and', 'CC'),
#   ('Cardiac', 'NNP'),
#   ('Pacemakers', 'NNP'),
#   ('Inc.', 'NNP'),
#   ('units', 'NNS'),
#   ('led', 'VBN'),
#   ('growth', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('medical-instrument', 'NN'),
#   ('systems', 'NNS'),
#   ('division', 'NN'),
#   ('.', '.')],
#  [('Lilly', 'RB'),
#   ('shares', 'NNS'),
#   ('closed', 'VBD'),
#   ('yesterday', 'NN'),
#   ('in', 'IN'),
#   ('composite', 'JJ'),
#   ('trading', 'NN'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('Big', 'NNP'),
#   ('Board', 'NNP'),
#   ('at', 'IN'),
#   ('$', '$'),
#   ('62.25', 'CD'),
#   (',', ','),
#   ('down', 'RB'),
#   ('12.5', 'CD'),
#   ('cents', 'NNS'),
#   ('.', '.')],
#  [('Reuben', 'NNP'),
#   ('Mark', 'NNP'),
#   (',', ','),
#   ('chairman', 'NN'),
#   ('of', 'IN'),
#   ('Colgate-Palmolive', 'NNP'),
#   ('Co.', 'NNP'),
#   (',', ','),
#   ('said', 'VBD'),
#   ('he', 'PRP'),
#   ('is', 'VBZ'),
#   ('``', '``'),
#   ('comfortable', 'JJ'),
#   ("''", "''"),
#   ('with', 'IN'),
#   ('analysts', 'NNS'),
#   ("'", 'POS'),
#   ('estimates', 'NNS'),
#   ('that', 'IN'),
#   ('third-quarter', 'JJ'),
#   ('earnings', 'NNS'),
#   ('rose', 'VBD'),
#   ('to', 'TO'),
#   ('between', 'IN'),
#   ('95', 'CD'),
#   ('cents', 'NNS'),
#   ('and', 'CC'),
#   ('$', '$'),
#   ('1.05', 'CD'),
#   ('a', 'DT'),
#   ('share', 'NN'),
#   ('.', '.')],
#  [('That', 'DT'),
#   ('compares', 'NNS'),
#   ('with', 'IN'),
#   ('per-share', 'JJ'),
#   ('earnings', 'NNS'),
#   ('from', 'IN'),
#   ('continuing', 'VBG'),
#   ('operations', 'NNS'),
#   ('of', 'IN'),
#   ('69', 'CD'),
#   ('cents', 'NNS'),
#   ('the', 'DT'),
#   ('year', 'NN'),
#   ('earlier', 'RBR'),
#   (';', ':'),
#   ('including', 'VBG'),
#   ('discontinued', 'VBN'),
#   ('operations', 'NNS'),
#   (',', ','),
#   ('per-share', 'NN'),
#   ('was', 'VBD'),
#   ('88', 'CD'),
#   ('cents', 'NNS'),
#   ('a', 'DT'),
#   ('year', 'NN'),
#   ('ago', 'RB'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('per-share', 'JJ'),
#   ('estimates', 'NNS'),
#   ('mean', 'VBP'),
#   ('the', 'DT'),
#   ('consumer-products', 'NNS'),
#   ('company', 'NN'),
#   ("'s", 'POS'),
#   ('net', 'JJ'),
#   ('income', 'NN'),
#   (',', ','),
#   ('increased', 'VBN'),
#   ('to', 'TO'),
#   ('between', 'VB'),
#   ('$', '$'),
#   ('69.5', 'CD'),
#   ('million', 'CD'),
#   ('and', 'CC'),
#   ('$', '$'),
#   ('76', 'CD'),
#   ('million', 'CD'),
#   (',', ','),
#   ('from', 'IN'),
#   ('$', '$'),
#   ('47.1', 'CD'),
#   ('million', 'CD'),
#   ('the', 'DT'),
#   ('year-before', 'JJ'),
#   ('period', 'NN'),
#   ('.', '.')],
#  [('Analysts', 'NNS'),
#   ('estimate', 'VBP'),
#   ('Colgate', 'NNP'),
#   ("'s", 'POS'),
#   ('world-wide', 'JJ'),
#   ('third-quarter', 'JJ'),
#   ('sales', 'NNS'),
#   ('rose', 'VBD'),
#   ('about', 'IN'),
#   ('8', 'CD'),
#   ('%', 'NN'),
#   ('to', 'TO'),
#   ('$', '$'),
#   ('1.29', 'CD'),
#   ('billion', 'CD'),
#   ('.', '.')],
#  [('Mr.', 'NNP'),
#   ('Mark', 'NNP'),
#   ('attributed', 'VBD'),
#   ('the', 'DT'),
#   ('earnings', 'NNS'),
#   ('growth', 'NN'),
#   ('to', 'TO'),
#   ('strong', 'JJ'),
#   ('sales', 'NNS'),
#   ('in', 'IN'),
#   ('Latin', 'NNP'),
#   ('America', 'NNP'),
#   (',', ','),
#   ('Asia', 'NNP'),
#   ('and', 'CC'),
#   ('Europe', 'NNP'),
#   ('.', '.')],
#  [('Results', 'NNS'),
#   ('were', 'VBD'),
#   ('also', 'RB'),
#   ('bolstered', 'VBN'),
#   ('by', 'IN'),
#   ('``', '``'),
#   ('a', 'DT'),
#   ('very', 'RB'),
#   ('meaningful', 'JJ'),
#   ("''", "''"),
#   ('increase', 'NN'),
#   ('in', 'IN'),
#   ('operating', 'VBG'),
#   ('profit', 'NN'),
#   ('by', 'IN'),
#   ('Colgate', 'NNP'),
#   ("'s", 'POS'),
#   ('U.S.', 'NNP'),
#   ('business', 'NN'),
#   (',', ','),
#   ('Mr.', 'NNP'),
#   ('Mark', 'NNP'),
#   ('said', 'VBD'),
#   ('.', '.')],
#  [('Operating', 'VBG'),
#   ('profit', 'NN'),
#   ('at', 'IN'),
#   ('Colgate', 'NNP'),
#   ("'s", 'POS'),
#   ('U.S.', 'NNP'),
#   ('household', 'NN'),
#   ('products', 'NNS'),
#   ('and', 'CC'),
#   ('personal-care', 'JJ'),
#   ('businesses', 'NNS'),
#   ('jumped', 'VBD'),
#   ('25', 'CD'),
#   ('%', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('quarter', 'NN'),
#   (',', ','),
#   ('Mr.', 'NNP'),
#   ('Mark', 'NNP'),
#   ('added', 'VBD'),
#   ('.', '.')],
#  [('He', 'PRP'),
#   ('said', 'VBD'),
#   ('the', 'DT'),
#   ('improvement', 'NN'),
#   ('was', 'VBD'),
#   ('a', 'DT'),
#   ('result', 'NN'),
#   ('of', 'IN'),
#   ('cost', 'NN'),
#   ('savings', 'NNS'),
#   ('achieved', 'VBN'),
#   ('by', 'IN'),
#   ('consolidating', 'VBG'),
#   ('manufacturing', 'NN'),
#   ('operations', 'NNS'),
#   (',', ','),
#   ('blending', 'VBG'),
#   ('two', 'CD'),
#   ('sales', 'NNS'),
#   ('organizations', 'NNS'),
#   ('and', 'CC'),
#   ('focusing', 'VBG'),
#   ('more', 'RBR'),
#   ('carefully', 'RB'),
#   ('the', 'DT'),
#   ('company', 'NN'),
#   ("'s", 'POS'),
#   ('promotional', 'JJ'),
#   ('activities', 'NNS'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('estimated', 'VBN'),
#   ('improvement', 'NN'),
#   ('in', 'IN'),
#   ('Colgate', 'NNP'),
#   ("'s", 'POS'),
#   ('U.S.', 'NNP'),
#   ('operations', 'NNS'),
#   ('took', 'VBD'),
#   ('some', 'DT'),
#   ('analysts', 'NNS'),
#   ('by', 'IN'),
#   ('surprise', 'NN'),
#   ('.', '.')],
#  [('Colgate', 'NNP'),
#   ("'s", 'POS'),
#   ('household', 'NN'),
#   ('products', 'NNS'),
#   ('business', 'NN'),
#   (',', ','),
#   ('which', 'WDT'),
#   ('includes', 'VBZ'),
#   ('such', 'JJ'),
#   ('brands', 'NNS'),
#   ('as', 'IN'),
#   ('Fab', 'NNP'),
#   ('laundry', 'NN'),
#   ('detergent', 'NN'),
#   ('and', 'CC'),
#   ('Ajax', 'NNP'),
#   ('cleanser', 'NN'),
#   (',', ','),
#   ('has', 'VBZ'),
#   ('been', 'VBN'),
#   ('a', 'DT'),
#   ('weak', 'JJ'),
#   ('performer', 'NN'),
#   ('.', '.')],
#  [('Analysts', 'NNS'),
#   ('estimate', 'VBP'),
#   ('Colgate', 'NNP'),
#   ("'s", 'POS'),
#   ('sales', 'NNS'),
#   ('of', 'IN'),
#   ('household', 'NN'),
#   ('products', 'NNS'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('U.S.', 'NNP'),
#   ('were', 'VBD'),
#   ('flat', 'JJ'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('quarter', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('they', 'PRP'),
#   ('estimated', 'VBD'),
#   ('operating', 'VBG'),
#   ('margins', 'NNS'),
#   ('at', 'IN'),
#   ('only', 'RB'),
#   ('1', 'CD'),
#   ('%', 'NN'),
#   ('to', 'TO'),
#   ('3', 'CD'),
#   ('%', 'NN'),
#   ('.', '.')],
#  [('``', '``'),
#   ('If', 'IN'),
#   ('you', 'PRP'),
#   ('could', 'MD'),
#   ('say', 'VB'),
#   ('their', 'PRP$'),
#   ('business', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('U.S.', 'NNP'),
#   ('was', 'VBD'),
#   ('mediocre', 'NN'),
#   (',', ','),
#   ('but', 'CC'),
#   ('great', 'JJ'),
#   ('everywhere', 'NN'),
#   ('else', 'RB'),
#   (',', ','),
#   ('that', 'WDT'),
#   ('would', 'MD'),
#   ('be', 'VB'),
#   ('fine', 'JJ'),
#   (',', ','),
#   ("''", "''"),
#   ('says', 'VBZ'),
#   ('Bonita', 'NNP'),
#   ('Austin', 'NNP'),
#   (',', ','),
#   ('an', 'DT'),
#   ('analyst', 'NN'),
#   ('with', 'IN'),
#   ('Wertheim', 'NNP'),
#   ('Schroder', 'NNP'),
#   ('&', 'CC'),
#   ('Co', 'NNP'),
#   ('.', '.')],
#  [('``', '``'),
#   ('But', 'CC'),
#   ('it', 'PRP'),
#   ("'s", 'VBZ'),
#   ('not', 'RB'),
#   ('mediocre', 'JJ'),
#   (',', ','),
#   ('it', 'PRP'),
#   ("'s", 'VBZ'),
#   ('a', 'DT'),
#   ('real', 'JJ'),
#   ('problem', 'NN'),
#   ('.', '.'),
#   ("''", "''")],
#  [('Mr.', 'NNP'),
#   ('Mark', 'NNP'),
#   ('conceded', 'VBD'),
#   ('that', 'IN'),
#   ('Colgate', 'NNP'),
#   ("'s", 'POS'),
#   ('domestic', 'JJ'),
#   ('business', 'NN'),
#   (',', ','),
#   ('apart', 'NN'),
#   ('from', 'IN'),
#   ('its', 'PRP$'),
#   ('highly', 'RB'),
#   ('profitable', 'JJ'),
#   ('Hill', 'NNP'),
#   ("'s", 'POS'),
#   ('Pet', 'NNP'),
#   ('Products', 'NNPS'),
#   ('unit', 'NN'),
#   (',', ','),
#   ('has', 'VBZ'),
#   ('lagged', 'VBN'),
#   ('.', '.')],
#  [('``', '``'),
#   ('We', 'PRP'),
#   ("'ve", 'VBP'),
#   ('done', 'VBN'),
#   ('a', 'DT'),
#   ('lot', 'NN'),
#   ('to', 'TO'),
#   ('improve', 'VB'),
#   ('-LCB-', '('),
#   ('U.S.', 'NNP'),
#   ('.', '.'),
#   ('-RCB-', ')'),
#   ('results', 'NNS'),
#   (',', ','),
#   ('and', 'CC'),
#   ('a', 'DT'),
#   ('lot', 'NN'),
#   ('more', 'RBR'),
#   ('will', 'MD'),
#   ('be', 'VB'),
#   ('done', 'VBN'),
#   (',', ','),
#   ("''", "''"),
#   ('Mr.', 'NNP'),
#   ('Mark', 'NNP'),
#   ('said', 'VBD'),
#   ('.', '.')],
#  [('``', '``'),
#   ('Improving', 'VBG'),
#   ('profitability', 'NN'),
#   ('of', 'IN'),
#   ('U.S.', 'NNP'),
#   ('operations', 'NNS'),
#   ('is', 'VBZ'),
#   ('an', 'DT'),
#   ('extremely', 'RB'),
#   ('high', 'JJ'),
#   ('priority', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('company', 'NN'),
#   ('.', '.'),
#   ("''", "''")],
#  [('To', 'TO'),
#   ('focus', 'VB'),
#   ('on', 'IN'),
#   ('its', 'PRP$'),
#   ('global', 'JJ'),
#   ('consumer-products', 'NNS'),
#   ('business', 'NN'),
#   (',', ','),
#   ('Colgate', 'NNP'),
#   ('sold', 'VBD'),
#   ('its', 'PRP$'),
#   ('Kendall', 'NNP'),
#   ('health-care', 'NN'),
#   ('business', 'NN'),
#   ('in', 'IN'),
#   ('1988', 'CD'),
#   ('.', '.')],
#  [('H.', 'NNP'),
#   ('Anthony', 'NNP'),
#   ('Ittleson', 'NNP'),
#   ('was', 'VBD'),
#   ('elected', 'VBN'),
#   ('a', 'DT'),
#   ('director', 'NN'),
#   ('of', 'IN'),
#   ('this', 'DT'),
#   ('company', 'NN'),
#   (',', ','),
#   ('which', 'WDT'),
#   ('primarily', 'RB'),
#   ('has', 'VBZ'),
#   ('interests', 'NNS'),
#   ('in', 'IN'),
#   ('radio', 'NN'),
#   ('and', 'CC'),
#   ('television', 'NN'),
#   ('stations', 'NNS'),
#   (',', ','),
#   ('increasing', 'VBG'),
#   ('the', 'DT'),
#   ('number', 'NN'),
#   ('of', 'IN'),
#   ('seats', 'NNS'),
#   ('to', 'TO'),
#   ('five', 'CD'),
#   ('.', '.')],
#  [('Osborn', 'IN'),
#   ('also', 'RB'),
#   ('operates', 'VBZ'),
#   ('Muzak', 'NNP'),
#   ('franchises', 'NNS'),
#   (',', ','),
#   ('entertainment', 'NN'),
#   ('properties', 'NNS'),
#   ('and', 'CC'),
#   ('small', 'JJ'),
#   ('cable-television', 'NN'),
#   ('systems', 'NNS'),
#   ('.', '.')],
#  [('Mr.', 'NNP'),
#   ('Ittleson', 'NNP'),
#   ('is', 'VBZ'),
#   ('executive', 'JJ'),
#   (',', ','),
#   ('special', 'JJ'),
#   ('projects', 'NNS'),
#   (',', ','),
#   ('at', 'IN'),
#   ('CIT', 'NNP'),
#   ('Group', 'NNP'),
#   ('Holdings', 'NNP'),
#   ('Inc.', 'NNP'),
#   (',', ','),
#   ('which', 'WDT'),
#   ('is', 'VBZ'),
#   ('controlled', 'VBN'),
#   ('by', 'IN'),
#   ('Manufacturers', 'NNP'),
#   ('Hanover', 'NNP'),
#   ('Corp', 'NNP'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('Boston', 'NNP'),
#   ('Globe', 'NNP'),
#   ('says', 'VBZ'),
#   ('its', 'PRP$'),
#   ('newly', 'RB'),
#   ('redesigned', 'VBN'),
#   ('pages', 'NNS'),
#   ('have', 'VBP'),
#   ('a', 'DT'),
#   ('``', '``'),
#   ('crisper', 'NN'),
#   ("''", "''"),
#   ('look', 'NN'),
#   ('with', 'IN'),
#   ('revamped', 'JJ'),
#   ('fixtures', 'NNS'),
#   ('aimed', 'VBN'),
#   ('at', 'IN'),
#   ('making', 'VBG'),
#   ('the', 'DT'),
#   ('paper', 'NN'),
#   ('``', '``'),
#   ('more', 'JJR'),
#   ('consistent', 'NN'),
#   ("''", "''"),
#   ('and', 'CC'),
#   ('``', '``'),
#   ('easier', 'JJR'),
#   ('to', 'TO'),
#   ('read', 'VB'),
#   ('.', '.'),
#   ("''", "''")],
#  [('Maybe', 'RB'),
#   ('so', 'RB'),
#   ('--', ':'),
#   ('if', 'IN'),
#   ('you', 'PRP'),
#   ('can', 'MD'),
#   ('find', 'VB'),
#   ('where', 'WRB'),
#   ('your', 'PRP$'),
#   ('favorite', 'JJ'),
#   ('writer', 'NN'),
#   ('went', 'NN'),
#   ('.', '.')],
#  [('Beantown', 'JJ'),
#   ('scribes', 'NNS'),
#   (',', ','),
#   ('who', 'WP'),
#   ('spare', 'VBP'),
#   ('no', 'DT'),
#   ('invective', 'JJ'),
#   ('when', 'WRB'),
#   ('taking', 'VBG'),
#   ('on', 'IN'),
#   ('local', 'JJ'),
#   ('luminaries', 'NNS'),
#   ('such', 'JJ'),
#   ('as', 'IN'),
#   ('Michael', 'NNP'),
#   ('``', '``'),
#   ('Pee', 'NNP'),
#   ('Wee', 'NNP'),
#   ("''", "''"),
#   ('Dukakis', 'NNP'),
#   (',', ','),
#   ('or', 'CC'),
#   ('New', 'NNP'),
#   ('England', 'NNP'),
#   ('Patriots', 'NNP'),
#   ('Coach', 'NNP'),
#   ('Raymond', 'NNP'),
#   ('``', '``'),
#   ('Rev.', 'NNP'),
#   ('Ray', 'NNP'),
#   ("''", "''"),
#   ('Berry', 'NNP'),
#   (',', ','),
#   ('yesterday', 'NN'),
#   ('poured', 'VBN'),
#   ('ridicule', 'NN'),
#   ('on', 'IN'),
#   ('new', 'JJ'),
#   ('drawings', 'NNS'),
#   ('of', 'IN'),
#   ('Globe', 'NNP'),
#   ('columnists', 'NNS'),
#   ('that', 'WDT'),
#   ('replaced', 'VBD'),
#   ('old', 'JJ'),
#   ('photos', 'NNS'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('revamped', 'JJ'),
#   ('pages', 'NNS'),
#   ('this', 'DT'),
#   ('week', 'NN'),
#   ('.', '.')],
#  [('By', 'IN'),
#   ('late', 'JJ'),
#   ('last', 'JJ'),
#   ('night', 'NN'),
#   (',', ','),
#   ('Globe', 'NNP'),
#   ('Managing', 'NNP'),
#   ('Editor', 'NNP'),
#   ('Thomas', 'NNP'),
#   ('Mulvoy', 'NNP'),
#   (',', ','),
#   ('bending', 'VBG'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('will', 'NN'),
#   ('of', 'IN'),
#   ('his', 'PRP$'),
#   ('troops', 'NNS'),
#   (',', ','),
#   ('scrapped', 'VBD'),
#   ('the', 'DT'),
#   ('new', 'JJ'),
#   ('drawings', 'NNS'),
#   ('.', '.')],
#  [('For', 'IN'),
#   ('a', 'DT'),
#   ('few', 'JJ'),
#   ('days', 'NNS'),
#   ('at', 'IN'),
#   ('least', 'JJS'),
#   (',', ','),
#   ('he', 'PRP'),
#   ('says', 'VBZ'),
#   (',', ','),
#   ('no', 'DT'),
#   ('pictures', 'NNS'),
#   ('or', 'CC'),
#   ('drawings', 'NNS'),
#   ('of', 'IN'),
#   ('any', 'DT'),
#   ('kind', 'NN'),
#   ('will', 'MD'),
#   ('adorn', 'VB'),
#   ('the', 'DT'),
#   ('columns', 'NNS'),
#   ('.', '.')],
#  [('Trouble', 'NNP'),
#   ('was', 'VBD'),
#   (',', ','),
#   ('nobody', 'NN'),
#   ('thought', 'VBD'),
#   ('they', 'PRP'),
#   ('looked', 'VBD'),
#   ('right', 'RB'),
#   ('.', '.')],
#  [('Globe', 'NNP'),
#   ('columnist', 'NN'),
#   ('Mike', 'IN'),
#   ('Barnicle', 'NNP'),
#   ('--', ':'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('second', 'JJ'),
#   ('attack', 'NN'),
#   ('on', 'IN'),
#   ('his', 'PRP$'),
#   ('employer', 'NN'),
#   ('in', 'IN'),
#   ('as', 'IN'),
#   ('many', 'JJ'),
#   ('weeks', 'NNS'),
#   ('--', ':'),
#   ('averred', 'VBN'),
#   ('that', 'IN'),
#   ('his', 'PRP$'),
#   ('shadowy', 'JJ'),
#   ('countenance', 'NN'),
#   ('was', 'VBD'),
#   ('so', 'RB'),
#   ('bad', 'JJ'),
#   (',', ','),
#   ('it', 'PRP'),
#   ('looked', 'VBD'),
#   ('``', '``'),
#   ('like', 'IN'),
#   ('a', 'DT'),
#   ('face', 'NN'),
#   ('you', 'PRP'),
#   ("'d", 'MD'),
#   ('find', 'VB'),
#   ('on', 'IN'),
#   ('a', 'DT'),
#   ('bottle', 'NN'),
# ...
#   ('is', 'VBZ'),
#   ('considered', 'VBN'),
#   ('an', 'DT'),
#   ('early', 'JJ'),
#   ('signal', 'NN'),
#   ('of', 'IN'),
#   ('changes', 'NNS'),
#   ('in', 'IN'),
#   ('Fed', 'NNP'),
#   ('policy', 'NN'),
#   ('.', '.')],
#  [('It', 'PRP'),
#   ('ended', 'VBD'),
#   ('at', 'IN'),
#   ('about', 'IN'),
#   ('8', 'CD'),
#   ('11\\/16', 'CD'),
#   ('%', 'NN'),
#   ('yesterday', 'NN'),
#   (',', ','),
#   ('but', 'CC'),
#   ('was', 'VBD'),
#   ('as', 'IN'),
#   ('low', 'JJ'),
#   ('as', 'IN'),
#   ('8', 'CD'),
#   ('1\\/2', 'CD'),
#   ('%', 'NN'),
#   ('Monday', 'NNP'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('Treasury', 'NNP'),
#   ("'s", 'POS'),
#   ('benchmark', 'NN'),
#   ('30-year', 'JJ'),
#   ('bond', 'NN'),
#   ('fell', 'VBD'),
#   ('more', 'JJR'),
#   ('than', 'IN'),
#   ('1\\/2', 'CD'),
#   ('point', 'NN'),
#   (',', ','),
#   ('or', 'CC'),
#   ('over', 'IN'),
#   ('$', '$'),
#   ('5', 'NN'),
#   ('for', 'IN'),
#   ('each', 'DT'),
#   ('$', '$'),
#   ('1,000', 'CD'),
#   ('face', 'NN'),
#   ('amount', 'NN'),
#   (',', ','),
#   ('while', 'IN'),
#   ('the', 'DT'),
#   ('yield', 'NN'),
#   ('moved', 'VBD'),
#   ('above', 'IN'),
#   ('8', 'CD'),
#   ('%', 'NN'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('first', 'JJ'),
#   ('time', 'NN'),
#   ('since', 'IN'),
#   ('Thursday', 'NNP'),
#   ('.', '.')],
#  [('Investment-grade', 'JJ'),
#   ('corporate', 'JJ'),
#   (',', ','),
#   ('municipal', 'JJ'),
#   ('and', 'CC'),
#   ('mortgage-backed', 'JJ'),
#   ('securities', 'NNS'),
#   ('also', 'RB'),
#   ('fell', 'VBD'),
#   ('.', '.')],
#  [('But', 'CC'),
#   ('most', 'RBS'),
#   ('junk', 'NN'),
#   ('bonds', 'NNS'),
#   ('closed', 'VBD'),
#   ('unchanged', 'VBN'),
#   ('after', 'IN'),
#   ('opening', 'VBG'),
#   ('slightly', 'RB'),
#   ('higher', 'JJR'),
#   ('on', 'IN'),
#   ('bargain-hunting', 'VBG'),
#   ('by', 'IN'),
#   ('institutional', 'JJ'),
#   ('investors', 'NNS'),
#   ('.', '.')],
#  [('Some', 'DT'),
#   ('so-called', 'JJ'),
#   ('high-quality', 'NN'),
#   ('junk', 'NN'),
#   ('issues', 'NNS'),
#   (',', ','),
#   ('such', 'JJ'),
#   ('as', 'IN'),
#   ('R.H.', 'NNP'),
#   ('Macy', 'NNP'),
#   ('&', 'CC'),
#   ('Co.', 'NNP'),
#   ("'s", 'POS'),
#   ('14', 'CD'),
#   ('1\\/2', 'CD'),
#   ('%', 'NN'),
#   ('subordinated', 'VBD'),
#   ('debentures', 'NNS'),
#   (',', ','),
#   ('rose', 'VBD'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('Macy', 'NNP'),
#   ("'s", 'POS'),
#   ('issue', 'NN'),
#   ('closed', 'VBD'),
#   ('up', 'IN'),
#   ('about', 'IN'),
#   ('one', 'CD'),
#   ('point', 'NN'),
#   ('at', 'IN'),
#   ('a', 'DT'),
#   ('bid', 'NN'),
#   ('price', 'NN'),
#   ('of', 'IN'),
#   ('97', 'CD'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('TVA', 'NNP'),
#   ("'s", 'POS'),
#   ('public', 'JJ'),
#   ('debt', 'NN'),
#   ('offering', 'NN'),
#   ('was', 'VBD'),
#   ('its', 'PRP$'),
#   ('first', 'JJ'),
#   ('in', 'IN'),
#   ('15', 'CD'),
#   ('years', 'NNS'),
#   ('.', '.')],
#  [('Strong', 'JJ'),
#   ('investor', 'NN'),
#   ('demand', 'NN'),
#   ('prompted', 'VBD'),
#   ('it', 'PRP'),
#   ('to', 'TO'),
#   ('boost', 'VB'),
#   ('the', 'DT'),
#   ('size', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('issue', 'NN'),
#   ('from', 'IN'),
#   ('$', '$'),
#   ('3', 'CD'),
#   ('billion', 'CD'),
#   ('.', '.')],
#  [('Traders', 'NNS'),
#   ('said', 'VBD'),
#   ('hedging', 'VBG'),
#   ('related', 'VBN'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('TVA', 'NNP'),
#   ('pricing', 'VBG'),
#   ('also', 'RB'),
#   ('pressured', 'VBN'),
#   ('Treasury', 'NNP'),
#   ('bonds', 'NNS'),
#   ('.', '.')],
#  [('``', '``'),
#   ('Underwriters', 'NNS'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('TVA', 'NNP'),
#   ('bonds', 'NNS'),
#   ('reduced', 'VBD'),
#   ('their', 'PRP$'),
#   ('market', 'NN'),
#   ('risk', 'NN'),
#   ('by', 'IN'),
#   ('selling', 'VBG'),
#   ('Treasurys', 'NNPS'),
#   ('to', 'TO'),
#   ('cover', 'VB'),
#   ('at', 'IN'),
#   ('least', 'JJS'),
#   ('part', 'NN'),
#   ('of', 'IN'),
#   ('their', 'PRP$'),
#   ('-LCB-', '('),
#   ('TVA', 'NNP'),
#   ('-RCB-', ')'),
#   ('holdings', 'NNS'),
#   (',', ','),
#   ("''", "''"),
#   ('said', 'VBD'),
#   ('James', 'NNP'),
#   ('R.', 'NNP'),
#   ('Capra', 'NNP'),
#   (',', ','),
#   ('a', 'DT'),
#   ('senior', 'JJ'),
#   ('vice', 'NN'),
#   ('president', 'NN'),
#   ('at', 'IN'),
#   ('Shearson', 'NNP'),
#   ('Lehman', 'NNP'),
#   ('Government', 'NNP'),
#   ('Securities', 'NNP'),
#   ('Inc', 'NNP'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('TVA', 'NNP'),
#   ('bonds', 'NNS'),
#   ('also', 'RB'),
#   ('``', '``'),
#   ('served', 'VBN'),
#   ('to', 'TO'),
#   ('remind', 'VB'),
#   ('the', 'DT'),
#   ('market', 'NN'),
#   ('that', 'IN'),
#   ('there', 'EX'),
#   ('will', 'MD'),
#   ('be', 'VB'),
#   ('even', 'RB'),
#   ('more', 'RBR'),
#   ('new', 'JJ'),
#   ('supply', 'NN'),
#   (',', ','),
#   ("''", "''"),
#   ('said', 'VBD'),
#   ('Lawrence', 'NNP'),
#   ('N.', 'NNP'),
#   ('Leuzzi', 'NNP'),
#   (',', ','),
#   ('a', 'DT'),
#   ('managing', 'VBG'),
#   ('director', 'NN'),
#   ('at', 'IN'),
#   ('S.G.', 'NNP'),
#   ('Warburg', 'NNP'),
#   ('Securities', 'NNP'),
#   ('&', 'CC'),
#   ('Co', 'NNP'),
#   ('.', '.')],
#  [('Today', 'NN'),
#   ('the', 'DT'),
#   ('Treasury', 'NNP'),
#   ('will', 'MD'),
#   ('announce', 'VB'),
#   ('the', 'DT'),
#   ('size', 'NN'),
#   ('of', 'IN'),
#   ('its', 'PRP$'),
#   ('next', 'JJ'),
#   ('two-year', 'JJ'),
#   ('note', 'NN'),
#   ('sale', 'NN'),
#   ('and', 'CC'),
#   ('Resolution', 'NNP'),
#   ('Funding', 'NNP'),
#   ('Corp.', 'NNP'),
#   ('will', 'MD'),
#   ('announce', 'VB'),
#   ('details', 'NNS'),
#   ('of', 'IN'),
#   ('its', 'PRP$'),
#   ('first', 'JJ'),
#   ('bond', 'NN'),
#   ('offering', 'NN'),
#   ('.', '.')],
#  [('Some', 'DT'),
#   ('traders', 'NNS'),
#   ('estimate', 'VBP'),
#   ('$', '$'),
#   ('9.75', 'CD'),
#   ('billion', 'CD'),
#   ('of', 'IN'),
#   ('new', 'JJ'),
#   ('two-year', 'JJ'),
#   ('Treasurys', 'NNPS'),
#   ('will', 'MD'),
#   ('be', 'VB'),
#   ('sold', 'VBN'),
#   ('next', 'JJ'),
#   ('week', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('they', 'PRP'),
#   ('expect', 'VBP'),
#   ('Refcorp', 'NNP'),
#   ('to', 'TO'),
#   ('offer', 'VB'),
#   ('$', '$'),
#   ('4', 'CD'),
#   ('billion', 'CD'),
#   ('to', 'TO'),
#   ('$', '$'),
#   ('6', 'CD'),
#   ('billion', 'CD'),
#   ('of', 'IN'),
#   ('long-term', 'JJ'),
#   ('``', '``'),
#   ('bailout', 'NN'),
#   ("''", "''"),
#   ('bonds', 'NNS'),
#   ('.', '.')],
#  [('Refcorp', 'NNP'),
#   ('was', 'VBD'),
#   ('created', 'VBN'),
#   ('to', 'TO'),
#   ('help', 'VB'),
#   ('fund', 'NN'),
#   ('the', 'DT'),
#   ('thrift', 'NN'),
#   ('bailout', 'NN'),
#   ('.', '.')],
#  [('Another', 'DT'),
#   ('agency', 'NN'),
#   ('issue', 'NN'),
#   ('came', 'VBD'),
#   ('to', 'TO'),
#   ('market', 'VB'),
#   ('yesterday', 'NN'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('Office', 'NNP'),
#   ('of', 'IN'),
#   ('Finance', 'NNP'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('Federal', 'NNP'),
#   ('Home', 'NNP'),
#   ('Loan', 'NNP'),
#   ('Banks', 'NNP'),
#   ('said', 'VBD'),
#   ('it', 'PRP'),
#   ('priced', 'VBD'),
#   ('a', 'DT'),
#   ('four-part', 'NN'),
#   ('$', '$'),
#   ('2.27', 'CD'),
#   ('billion', 'CD'),
#   ('bond', 'NN'),
#   ('offering', 'NN'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('banks', 'NNS'),
#   ('to', 'TO'),
#   ('yield', 'VB'),
#   ('from', 'IN'),
#   ('8.125', 'CD'),
#   ('%', 'NN'),
#   ('to', 'TO'),
#   ('8.375', 'CD'),
#   ('%', 'NN'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('release', 'NN'),
#   ('of', 'IN'),
#   ('several', 'JJ'),
#   ('economic', 'JJ'),
#   ('reports', 'NNS'),
#   ('had', 'VBD'),
#   ('little', 'JJ'),
#   ('impact', 'NN'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('market', 'NN'),
#   (',', ','),
#   ('including', 'VBG'),
#   ('a', 'DT'),
#   ('report', 'NN'),
#   ('that', 'IN'),
#   ('the', 'DT'),
#   ('U.S.', 'NNP'),
#   ('trade', 'NN'),
#   ('deficit', 'NN'),
#   ('expanded', 'VBN'),
#   ('to', 'TO'),
#   ('a', 'DT'),
#   ('surprisingly', 'RB'),
#   ('wide', 'JJ'),
#   ('$', '$'),
#   ('10.77', 'CD'),
#   ('billion', 'CD'),
#   ('in', 'IN'),
#   ('August', 'NNP'),
#   (',', ','),
#   ('up', 'IN'),
#   ('from', 'IN'),
#   ('a', 'DT'),
#   ('revised', 'VBN'),
#   ('$', '$'),
#   ('8.24', 'CD'),
#   ('billion', 'CD'),
#   ('in', 'IN'),
#   ('July', 'NNP'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('August', 'NNP'),
#   ('gap', 'NN'),
#   ('was', 'VBD'),
#   ('expected', 'VBN'),
#   ('to', 'TO'),
#   ('have', 'VB'),
#   ('expanded', 'VBN'),
#   ('to', 'TO'),
#   ('$', '$'),
#   ('9.1', 'CD'),
#   ('billion', 'CD'),
#   ('.', '.')],
#  [('Treasury', 'NNP'), ('Securities', 'NNP')],
#  [('Treasury', 'NNP'),
#   ('securities', 'NNS'),
#   ('were', 'VBD'),
#   ('essentially', 'RB'),
#   ('flat', 'JJ'),
#   ('to', 'TO'),
#   ('about', 'IN'),
#   ('1\\/2', 'CD'),
#   ('point', 'NN'),
#   ('lower', 'JJR'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('benchmark', 'NN'),
#   ('30-year', 'JJ'),
#   ('bond', 'NN'),
#   ('was', 'VBD'),
#   ('quoted', 'VBN'),
#   ('late', 'JJ'),
#   ('at', 'IN'),
#   ('100', 'CD'),
#   ('28\\/32', 'CD'),
#   ('to', 'TO'),
#   ('yield', 'VB'),
#   ('8.04', 'CD'),
#   ('%', 'NN'),
#   (',', ','),
#   ('compared', 'VBN'),
#   ('with', 'IN'),
#   ('101', 'CD'),
#   ('19\\/32', 'CD'),
#   ('to', 'TO'),
#   ('yield', 'VB'),
#   ('7.97', 'CD'),
#   ('%', 'NN'),
#   ('Monday', 'NNP'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('latest', 'JJS'),
#   ('10-year', 'JJ'),
#   ('notes', 'NNS'),
#   ('were', 'VBD'),
#   ('quoted', 'VBN'),
#   ('late', 'JJ'),
#   ('at', 'IN'),
#   ('99', 'CD'),
#   ('25\\/32', 'CD'),
#   ('to', 'TO'),
#   ('yield', 'VB'),
#   ('8.01', 'CD'),
#   ('%', 'NN'),
#   (',', ','),
#   ('compared', 'VBN'),
#   ('with', 'IN'),
#   ('100', 'CD'),
#   ('1\\/32', 'CD'),
#   ('to', 'TO'),
#   ('yield', 'VB'),
#   ('7.97', 'CD'),
#   ('%', 'NN'),
#   ('.', '.')],
#  [('Short-term', 'JJ'), ('rates', 'NNS'), ('increased', 'VBN'), ('.', '.')],
#  [('The', 'DT'),
#   ('discount', 'NN'),
#   ('rate', 'NN'),
#   ('on', 'IN'),
#   ('three-month', 'JJ'),
#   ('bills', 'NNS'),
#   ('rose', 'VBD'),
#   ('to', 'TO'),
#   ('7.52', 'CD'),
#   ('%', 'NN'),
#   ('for', 'IN'),
#   ('a', 'DT'),
#   ('bond-equivalent', 'NN'),
#   ('yield', 'NN'),
#   ('of', 'IN'),
#   ('7.75', 'CD'),
#   ('%', 'NN'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('rate', 'NN'),
#   ('on', 'IN'),
#   ('six-month', 'JJ'),
#   ('bills', 'NNS'),
#   ('rose', 'VBD'),
#   ('to', 'TO'),
#   ('7.53', 'CD'),
#   ('%', 'NN'),
#   ('for', 'IN'),
#   ('a', 'DT'),
#   ('bond-equivalent', 'NN'),
#   ('yield', 'NN'),
#   ('of', 'IN'),
#   ('7.92', 'CD'),
#   ('%', 'NN'),
#   ('.', '.')],
#  [('Corporate', 'NNP'), (',', ','), ('Other', 'JJ'), ('Issues', 'NNS')],
#  [('Investment-grade', 'JJ'),
#   ('corporate', 'JJ'),
#   ('bonds', 'NNS'),
#   ('ended', 'VBD'),
#   ('1\\/4', 'CD'),
#   ('to', 'TO'),
#   ('1\\/2', 'CD'),
#   ('point', 'NN'),
#   ('lower', 'JJR'),
#   (',', ','),
#   ('while', 'IN'),
#   ('most', 'RBS'),
#   ('junk', 'NN'),
#   ('bonds', 'NNS'),
#   ('ended', 'VBD'),
#   ('unchanged', 'JJ'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('TVA', 'NNP'),
#   ("'s", 'POS'),
#   ('huge', 'JJ'),
#   ('$', '$'),
#   ('4', 'CD'),
#   ('billion', 'CD'),
#   ('offering', 'NN'),
#   ('dominated', 'VBN'),
#   ('attention', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('new-issue', 'JJ'),
#   ('market', 'NN'),
#   ('.', '.')],
#  [('TVA', 'NNP'),
#   ('offered', 'VBD'),
#   ('$', '$'),
#   ('2', 'CD'),
#   ('billion', 'CD'),
#   ('of', 'IN'),
#   ('30-year', 'JJ'),
#   ('bonds', 'NNS'),
#   ('priced', 'VBN'),
#   ('to', 'TO'),
#   ('yield', 'VB'),
#   ('9.06', 'CD'),
#   ('%', 'NN'),
#   (';', ':'),
#   ('$', '$'),
#   ('1', 'CD'),
#   ('billion', 'CD'),
#   ('in', 'IN'),
#   ('10-year', 'JJ'),
#   ('notes', 'NNS'),
#   ('priced', 'VBN'),
#   ('to', 'TO'),
#   ('yield', 'VB'),
#   ('8.42', 'CD'),
#   ('%', 'NN'),
#   (';', ':'),
#   ('and', 'CC'),
#   ('$', '$'),
#   ('1', 'CD'),
#   ('billion', 'CD'),
#   ('in', 'IN'),
#   ('five-year', 'JJ'),
#   ('notes', 'NNS'),
#   ('priced', 'VBN'),
#   ('to', 'TO'),
#   ('yield', 'VB'),
#   ('8.33', 'CD'),
#   ('%', 'NN'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('TVA', 'NNP'),
#   (',', ','),
#   ('which', 'WDT'),
#   ('operates', 'VBZ'),
#   ('one', 'CD'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('nation', 'NN'),
#   ("'s", 'POS'),
#   ('largest', 'JJS'),
#   ('electric', 'JJ'),
#   ('power', 'NN'),
#   ('systems', 'NNS'),
#   (',', ','),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('corporation', 'NN'),
#   ('wholly', 'RB'),
#   ('owned', 'VBN'),
#   ('by', 'IN'),
#   ('the', 'DT'),
#   ('U.S.', 'NNP'),
#   ('government', 'NN'),
#   ('.', '.')],
#  [('Yesterday', 'NN'),
#   ("'s", 'POS'),
#   ('bond', 'NN'),
#   ('sale', 'NN'),
#   ('was', 'VBD'),
#   ('part', 'NN'),
#   ('of', 'IN'),
#   ('a', 'DT'),
#   ('$', '$'),
#   ('6.7', 'CD'),
#   ('billion', 'CD'),
#   ('refinancing', 'NN'),
#   ('plan', 'NN'),
#   ('to', 'TO'),
#   ('pay', 'VB'),
#   ('off', 'IN'),
#   ('high-interest', 'JJ'),
#   ('debt', 'NN'),
#   ('the', 'DT'),
#   ('TVA', 'NNP'),
#   ('owes', 'VBZ'),
#   ('the', 'DT'),
#   ('Federal', 'NNP'),
#   ('Financing', 'NNP'),
#   ('Bank', 'NNP'),
#   (',', ','),
#   ('an', 'DT'),
#   ('arm', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('Treasury', 'NNP'),
#   ('.', '.')],
#  [('Meanwhile', 'RB'),
#   (',', ','),
#   ('Lockheed', 'NNP'),
#   ('Corp.', 'NNP'),
#   ('priced', 'VBD'),
#   ('a', 'DT'),
#   ('$', '$'),
#   ('300', 'CD'),
#   ('million', 'CD'),
#   ('note', 'NN'),
#   ('offering', 'NN'),
#   ('to', 'TO'),
#   ('yield', 'VB'),
#   ('9.39', 'CD'),
#   ('%', 'NN'),
#   ('.', '.')],
#  [('Mortgage-Backed', 'JJ'), ('Securities', 'NNPS')],
#  [('The', 'DT'),
#   ('derivative', 'JJ'),
#   ('mortgage-backed', 'JJ'),
#   ('market', 'NN'),
#   ('revived', 'VBN'),
#   ('after', 'IN'),
#   ('a', 'DT'),
#   ('brief', 'JJ'),
#   ('hiatus', 'NN'),
#   ('as', 'IN'),
#   ('two', 'CD'),
#   ('new', 'JJ'),
#   ('Remics', 'NNS'),
#   ('totaling', 'VBG'),
#   ('$', '$'),
#   ('850', 'CD'),
#   ('million', 'CD'),
#   ('were', 'VBD'),
#   ('offered', 'VBN'),
#   ('and', 'CC'),
#   ('talk', 'VB'),
#   ('circulated', 'VBN'),
#   ('about', 'IN'),
#   ('two', 'CD'),
#   ('more', 'JJR'),
#   ('issues', 'NNS'),
#   ('that', 'WDT'),
#   ('could', 'MD'),
#   ('be', 'VB'),
#   ('priced', 'VBN'),
#   ('today', 'NN'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('revival', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('real', 'JJ'),
#   ('estate', 'NN'),
#   ('mortgage', 'NN'),
#   ('investment', 'NN'),
#   ('conduit', 'NN'),
#   ('market', 'NN'),
#   ('reflected', 'VBD'),
#   ('the', 'DT'),
#   ('relative', 'JJ'),
#   ('calm', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('mortgage', 'NN'),
#   ('market', 'NN'),
#   ('after', 'IN'),
#   ('two', 'CD'),
#   ('days', 'NNS'),
#   ('of', 'IN'),
#   ('volatile', 'JJ'),
#   ('trading', 'NN'),
#   ('.', '.')],
#  [('Dealers', 'NNS'),
#   ('noted', 'VBD'),
#   ('that', 'IN'),
#   ('it', 'PRP'),
#   ("'s", 'VBZ'),
#   ('difficult', 'JJ'),
#   ('to', 'TO'),
#   ('structure', 'VB'),
#   ('new', 'JJ'),
#   ('Remics', 'NNS'),
#   ('when', 'WRB'),
#   ('prices', 'NNS'),
#   ('are', 'VBP'),
#   ('moving', 'VBG'),
#   ('widely', 'RB'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('two', 'CD'),
#   ('Remics', 'NNS'),
#   ('priced', 'VBN'),
#   ('were', 'VBD'),
#   ('a', 'DT'),
#   ('$', '$'),
#   ('500', 'CD'),
#   ('million', 'CD'),
#   ('Federal', 'NNP'),
#   ('Home', 'NNP'),
#   ('Loan', 'NNP'),
#   ('Mortgage', 'NNP'),
#   ('Corp.', 'NNP'),
#   ('issue', 'NN'),
#   ('underwritten', 'VBN'),
#   ('by', 'IN'),
#   ('Salomon', 'NNP'),
#   ('Brothers', 'NNP'),
#   ('Inc.', 'NNP'),
#   ('and', 'CC'),
#   ('a', 'DT'),
#   ('$', '$'),
#   ('350', 'CD'),
#   ('million', 'CD'),
#   ('Federal', 'NNP'),
#   ('National', 'NNP'),
#   ('Mortgage', 'NNP'),
#   ('Association', 'NNP'),
#   ('deal', 'NN'),
#   ('underwritten', 'VBN'),
#   ('by', 'IN'),
#   ('Greenwich', 'NNP'),
#   ('Capital', 'NNP'),
#   ('Markets', 'NNPS'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('Remic', 'NNP'),
#   ('issuance', 'NN'),
#   ('supported', 'VBD'),
#   ('prices', 'NNS'),
#   ('of', 'IN'),
#   ('Freddie', 'NNP'),
#   ('Mac', 'NNP'),
#   ('and', 'CC'),
#   ('Fannie', 'NNP'),
#   ('Mae', 'NNP'),
#   ('securities', 'NNS'),
#   (',', ','),
#   ('which', 'WDT'),
#   ('held', 'VBD'),
#   ('up', 'IN'),
#   ('better', 'JJR'),
#   ('than', 'IN'),
#   ('Government', 'NNP'),
#   ('National', 'NNP'),
#   ('Mortgage', 'NNP'),
#   ('Association', 'NNP'),
#   ('securities', 'NNS'),
#   ('during', 'IN'),
#   ('an', 'DT'),
#   ('afternoon', 'NN'),
#   ('sell-off', 'NN'),
#   ('.', '.')],
#  [('Ginnie', 'NNP'),
#   ('Mae', 'NNP'),
#   ('9', 'CD'),
#   ('%', 'NN'),
#   ('securities', 'NNS'),
#   ('for', 'IN'),
#   ('November', 'NNP'),
#   ('delivery', 'NN'),
#   ('ended', 'VBN'),
#   ('at', 'IN'),
#   ('97', 'CD'),
#   ('29\\/32', 'CD'),
#   (',', ','),
#   ('down', 'RB'),
#   ('7\\/32', 'CD'),
#   (';', ':'),
#   ('9', 'CD'),
#   ('1\\/2', 'CD'),
#   ('%', 'NN'),
#   ('securities', 'NNS'),
#   ('at', 'IN'),
#   ('99', 'CD'),
#   ('31\\/32', 'CD'),
#   (',', ','),
#   ('down', 'RB'),
#   ('6\\/32', 'CD'),
#   (';', ':'),
#   ('and', 'CC'),
#   ('10', 'CD'),
#   ('%', 'NN'),
#   ('securities', 'NNS'),
#   ('at', 'IN'),
#   ('101', 'CD'),
#   ('29\\/32', 'CD'),
#   (',', ','),
#   ('down', 'RB'),
#   ('5\\/32', 'CD'),
#   ('.', '.')],
#  [('Freddie', 'NNP'),
#   ('Mac', 'NNP'),
#   ('9', 'CD'),
#   ('%', 'NN'),
#   ('securities', 'NNS'),
#   ('were', 'VBD'),
#   ('at', 'IN'),
#   ('97', 'CD'),
#   ('5\\/32', 'CD'),
#   (',', ','),
#   ('down', 'RB'),
#   ('3\\/32', 'CD'),
#   ('.', '.')],
#  ...]

# %% [markdown]
# ##### Comparaison

# %%
nb_correct=0
nb_mots = 0
for i in range(len(alldocsT)):
    doc_true= alldocsT[i]
    doc_pred_crf=all_tagged_docs[i]
    for j in range(len(doc_true)):
        nb_mots += 1
        if(doc_true[j][1]==doc_pred_crf[j][1]) :
            nb_correct+= 1
print("Nombre de tags corrects: ", nb_correct)
print("Accuracy: ", nb_correct/nb_mots)
# Out:
# Nombre de tags corrects:  45612
# Accuracy:  0.9627456360681343

# %% [markdown]
# Check: 1720 bonnes réponses

# %% [markdown]
# #### Perceptron

# %%
# perceptron
from nltk.tag.perceptron import PerceptronTagger

# %%
tagger_perceptron = PerceptronTagger(load=False)
tagger_perceptron.train(alldocs)

# %%
#recuperer toutes les predictions du modèle perceptron
all_tagged_docs_perceptron = []

for doc in alldocsT:
    doc_mots = [mot for mot, val in doc]
    tagged_docs = tagger_perceptron.tag(doc_mots)
    all_tagged_docs_perceptron.append(tagged_docs)

all_tagged_docs_perceptron
# Out:
# [[('Rockwell', 'NNP'),
#   ('International', 'NNP'),
#   ('Corp.', 'NNP'),
#   ("'s", 'POS'),
#   ('Tulsa', 'NNP'),
#   ('unit', 'NN'),
#   ('said', 'VBD'),
#   ('it', 'PRP'),
#   ('signed', 'VBD'),
#   ('a', 'DT'),
#   ('tentative', 'JJ'),
#   ('agreement', 'NN'),
#   ('extending', 'VBG'),
#   ('its', 'PRP$'),
#   ('contract', 'NN'),
#   ('with', 'IN'),
#   ('Boeing', 'NNP'),
#   ('Co.', 'NNP'),
#   ('to', 'TO'),
#   ('provide', 'VB'),
#   ('structural', 'JJ'),
#   ('parts', 'NNS'),
#   ('for', 'IN'),
#   ('Boeing', 'NNP'),
#   ("'s", 'POS'),
#   ('747', 'CD'),
#   ('jetliners', 'NNS'),
#   ('.', '.')],
#  [('Rockwell', 'NNP'),
#   ('said', 'VBD'),
#   ('the', 'DT'),
#   ('agreement', 'NN'),
#   ('calls', 'VBZ'),
#   ('for', 'IN'),
#   ('it', 'PRP'),
#   ('to', 'TO'),
#   ('supply', 'VB'),
#   ('200', 'CD'),
#   ('additional', 'JJ'),
#   ('so-called', 'JJ'),
#   ('shipsets', 'NNS'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('planes', 'NNS'),
#   ('.', '.')],
#  [('These', 'DT'),
#   ('include', 'VBP'),
#   (',', ','),
#   ('among', 'IN'),
#   ('other', 'JJ'),
#   ('parts', 'NNS'),
#   (',', ','),
#   ('each', 'DT'),
#   ('jetliner', 'NN'),
#   ("'s", 'POS'),
#   ('two', 'CD'),
#   ('major', 'JJ'),
#   ('bulkheads', 'NNS'),
#   (',', ','),
#   ('a', 'DT'),
#   ('pressure', 'NN'),
#   ('floor', 'NN'),
#   (',', ','),
#   ('torque', 'JJ'),
#   ('box', 'NN'),
#   (',', ','),
#   ('fixed', 'VBN'),
#   ('leading', 'VBG'),
#   ('edges', 'NNS'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('wings', 'NNS'),
#   ('and', 'CC'),
#   ('an', 'DT'),
#   ('aft', 'NN'),
#   ('keel', 'NN'),
#   ('beam', 'NN'),
#   ('.', '.')],
#  [('Under', 'IN'),
#   ('the', 'DT'),
#   ('existing', 'VBG'),
#   ('contract', 'NN'),
#   (',', ','),
#   ('Rockwell', 'NNP'),
#   ('said', 'VBD'),
#   (',', ','),
#   ('it', 'PRP'),
#   ('has', 'VBZ'),
#   ('already', 'RB'),
#   ('delivered', 'VBN'),
#   ('793', 'CD'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('shipsets', 'NNS'),
#   ('to', 'TO'),
#   ('Boeing', 'NNP'),
#   ('.', '.')],
#  [('Rockwell', 'NNP'),
#   (',', ','),
#   ('based', 'VBN'),
#   ('in', 'IN'),
#   ('El', 'NNP'),
#   ('Segundo', 'NNP'),
#   (',', ','),
#   ('Calif.', 'NNP'),
#   (',', ','),
#   ('is', 'VBZ'),
#   ('an', 'DT'),
#   ('aerospace', 'NN'),
#   (',', ','),
#   ('electronics', 'NNS'),
#   (',', ','),
#   ('automotive', 'JJ'),
#   ('and', 'CC'),
#   ('graphics', 'NNS'),
#   ('concern', 'VBP'),
#   ('.', '.')],
#  [('Frank', 'NNP'),
#   ('Carlucci', 'NNP'),
#   ('III', 'NNP'),
#   ('was', 'VBD'),
#   ('named', 'VBN'),
#   ('to', 'TO'),
#   ('this', 'DT'),
#   ('telecommunications', 'NNS'),
#   ('company', 'NN'),
#   ("'s", 'POS'),
#   ('board', 'NN'),
#   (',', ','),
#   ('filling', 'VBG'),
#   ('the', 'DT'),
#   ('vacancy', 'NN'),
#   ('created', 'VBN'),
#   ('by', 'IN'),
#   ('the', 'DT'),
#   ('death', 'NN'),
#   ('of', 'IN'),
#   ('William', 'NNP'),
#   ('Sobey', 'NNP'),
#   ('last', 'JJ'),
#   ('May', 'NNP'),
#   ('.', '.')],
#  [('Mr.', 'NNP'),
#   ('Carlucci', 'NNP'),
#   (',', ','),
#   ('59', 'CD'),
#   ('years', 'NNS'),
#   ('old', 'JJ'),
#   (',', ','),
#   ('served', 'VBD'),
#   ('as', 'IN'),
#   ('defense', 'NN'),
#   ('secretary', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('Reagan', 'NNP'),
#   ('administration', 'NN'),
#   ('.', '.')],
#  [('In', 'IN'),
#   ('January', 'NNP'),
#   (',', ','),
#   ('he', 'PRP'),
#   ('accepted', 'VBD'),
#   ('the', 'DT'),
#   ('position', 'NN'),
#   ('of', 'IN'),
#   ('vice', 'NN'),
#   ('chairman', 'NN'),
#   ('of', 'IN'),
#   ('Carlyle', 'NNP'),
#   ('Group', 'NNP'),
#   (',', ','),
#   ('a', 'DT'),
#   ('merchant', 'NN'),
#   ('banking', 'NN'),
#   ('concern', 'NN'),
#   ('.', '.')],
#  [('SHEARSON', 'NNP'),
#   ('LEHMAN', 'NNP'),
#   ('HUTTON', 'NNP'),
#   ('Inc', 'NNP'),
#   ('.', '.')],
#  [('Thomas', 'NNP'),
#   ('E.', 'NNP'),
#   ('Meador', 'NNP'),
#   (',', ','),
#   ('42', 'CD'),
#   ('years', 'NNS'),
#   ('old', 'JJ'),
#   (',', ','),
#   ('was', 'VBD'),
#   ('named', 'VBN'),
#   ('president', 'NN'),
#   ('and', 'CC'),
#   ('chief', 'JJ'),
#   ('operating', 'VBG'),
#   ('officer', 'NN'),
#   ('of', 'IN'),
#   ('Balcor', 'NNP'),
#   ('Co.', 'NNP'),
#   (',', ','),
#   ('a', 'DT'),
#   ('Skokie', 'NNP'),
#   (',', ','),
#   ('Ill.', 'NNP'),
#   (',', ','),
#   ('subsidiary', 'NN'),
#   ('of', 'IN'),
#   ('this', 'DT'),
#   ('New', 'NNP'),
#   ('York', 'NNP'),
#   ('investment', 'NN'),
#   ('banking', 'NN'),
#   ('firm', 'NN'),
#   ('.', '.')],
#  [('Balcor', 'NNP'),
#   (',', ','),
#   ('which', 'WDT'),
#   ('has', 'VBZ'),
#   ('interests', 'NNS'),
#   ('in', 'IN'),
#   ('real', 'JJ'),
#   ('estate', 'NN'),
#   (',', ','),
#   ('said', 'VBD'),
#   ('the', 'DT'),
#   ('position', 'NN'),
#   ('is', 'VBZ'),
#   ('newly', 'RB'),
#   ('created', 'VBN'),
#   ('.', '.')],
#  [('Mr.', 'NNP'),
#   ('Meador', 'NNP'),
#   ('had', 'VBD'),
#   ('been', 'VBN'),
#   ('executive', 'JJ'),
#   ('vice', 'NN'),
#   ('president', 'NN'),
#   ('of', 'IN'),
#   ('Balcor', 'NNP'),
#   ('.', '.')],
#  [('In', 'IN'),
#   ('addition', 'NN'),
#   ('to', 'TO'),
#   ('his', 'PRP$'),
#   ('previous', 'JJ'),
#   ('real-estate', 'NN'),
#   ('investment', 'NN'),
#   ('and', 'CC'),
#   ('asset-management', 'JJ'),
#   ('duties', 'NNS'),
#   (',', ','),
#   ('Mr.', 'NNP'),
#   ('Meador', 'NNP'),
#   ('takes', 'VBZ'),
#   ('responsibility', 'NN'),
#   ('for', 'IN'),
#   ('development', 'NN'),
#   ('and', 'CC'),
#   ('property', 'NN'),
#   ('management', 'NN'),
#   ('.', '.')],
#  [('Those', 'DT'),
#   ('duties', 'NNS'),
#   ('had', 'VBD'),
#   ('been', 'VBN'),
#   ('held', 'VBN'),
#   ('by', 'IN'),
#   ('Van', 'NNP'),
#   ('Pell', 'NNP'),
#   (',', ','),
#   ('44', 'CD'),
#   (',', ','),
#   ('who', 'WP'),
#   ('resigned', 'VBD'),
#   ('as', 'IN'),
#   ('an', 'DT'),
#   ('executive', 'JJ'),
#   ('vice', 'NN'),
#   ('president', 'NN'),
#   ('.', '.')],
#  [('Shearson', 'NNP'),
#   ('is', 'VBZ'),
#   ('about', 'IN'),
#   ('60%-held', 'JJ'),
#   ('by', 'IN'),
#   ('American', 'NNP'),
#   ('Express', 'NNP'),
#   ('Co', 'NNP'),
#   ('.', '.')],
#  [('Great', 'NNP'),
#   ('American', 'NNP'),
#   ('Bank', 'NNP'),
#   (',', ','),
#   ('citing', 'VBG'),
#   ('depressed', 'JJ'),
#   ('Arizona', 'NNP'),
#   ('real', 'JJ'),
#   ('estate', 'NN'),
#   ('prices', 'NNS'),
#   (',', ','),
#   ('posted', 'VBD'),
#   ('a', 'DT'),
#   ('third-quarter', 'JJ'),
#   ('loss', 'NN'),
#   ('of', 'IN'),
#   ('$', '$'),
#   ('59.4', 'CD'),
#   ('million', 'CD'),
#   (',', ','),
#   ('or', 'CC'),
#   ('$', '$'),
#   ('2.48', 'CD'),
#   ('a', 'DT'),
#   ('share', 'NN'),
#   ('.', '.')],
#  [('A', 'DT'),
#   ('year', 'NN'),
#   ('earlier', 'RBR'),
#   (',', ','),
#   ('the', 'DT'),
#   ('savings', 'NNS'),
#   ('bank', 'NN'),
#   ('had', 'VBD'),
#   ('earnings', 'NNS'),
#   ('of', 'IN'),
#   ('$', '$'),
#   ('8.1', 'CD'),
#   ('million', 'CD'),
#   (',', ','),
#   ('or', 'CC'),
#   ('33', 'CD'),
#   ('cents', 'NNS'),
#   ('a', 'DT'),
#   ('share', 'NN'),
#   ('.', '.')],
#  [('For', 'IN'),
#   ('the', 'DT'),
#   ('nine', 'CD'),
#   ('months', 'NNS'),
#   (',', ','),
#   ('it', 'PRP'),
#   ('had', 'VBD'),
#   ('a', 'DT'),
#   ('loss', 'NN'),
#   ('of', 'IN'),
#   ('$', '$'),
#   ('58.3', 'CD'),
#   ('million', 'CD'),
#   (',', ','),
#   ('or', 'CC'),
#   ('$', '$'),
#   ('2.44', 'CD'),
#   ('a', 'DT'),
#   ('share', 'NN'),
#   (',', ','),
#   ('after', 'IN'),
#   ('earnings', 'NNS'),
#   ('of', 'IN'),
#   ('$', '$'),
#   ('29.5', 'CD'),
#   ('million', 'CD'),
#   (',', ','),
#   ('or', 'CC'),
#   ('$', '$'),
#   ('1.20', 'CD'),
#   ('a', 'DT'),
#   ('share', 'NN'),
#   (',', ','),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('1988', 'CD'),
#   ('period', 'NN'),
#   ('.', '.')],
#  [('Great', 'NNP'),
#   ('American', 'NNP'),
#   ('said', 'VBD'),
#   ('it', 'PRP'),
#   ('increased', 'VBD'),
#   ('its', 'PRP$'),
#   ('loan-loss', 'NN'),
#   ('reserves', 'NNS'),
#   ('by', 'IN'),
#   ('$', '$'),
#   ('93', 'CD'),
#   ('million', 'CD'),
#   ('after', 'IN'),
#   ('reviewing', 'VBG'),
#   ('its', 'PRP$'),
#   ('loan', 'NN'),
#   ('portfolio', 'NN'),
#   (',', ','),
#   ('raising', 'VBG'),
#   ('its', 'PRP$'),
#   ('total', 'JJ'),
#   ('loan', 'NN'),
#   ('and', 'CC'),
#   ('real', 'JJ'),
#   ('estate', 'NN'),
#   ('reserves', 'NNS'),
#   ('to', 'TO'),
#   ('$', '$'),
#   ('217', 'CD'),
#   ('million', 'CD'),
#   ('.', '.')],
#  [('Before', 'IN'),
#   ('the', 'DT'),
#   ('loan-loss', 'JJ'),
#   ('addition', 'NN'),
#   (',', ','),
#   ('it', 'PRP'),
#   ('said', 'VBD'),
#   (',', ','),
#   ('it', 'PRP'),
#   ('had', 'VBD'),
#   ('operating', 'VBG'),
#   ('profit', 'NN'),
#   ('of', 'IN'),
#   ('$', '$'),
#   ('10', 'CD'),
#   ('million', 'CD'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('quarter', 'NN'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('move', 'NN'),
#   ('followed', 'VBD'),
#   ('a', 'DT'),
#   ('round', 'NN'),
#   ('of', 'IN'),
#   ('similar', 'JJ'),
#   ('increases', 'NNS'),
#   ('by', 'IN'),
#   ('other', 'JJ'),
#   ('lenders', 'NNS'),
#   ('against', 'IN'),
#   ('Arizona', 'NNP'),
#   ('real', 'JJ'),
#   ('estate', 'NN'),
#   ('loans', 'NNS'),
#   (',', ','),
#   ('reflecting', 'VBG'),
#   ('a', 'DT'),
#   ('continuing', 'VBG'),
#   ('decline', 'NN'),
#   ('in', 'IN'),
#   ('that', 'DT'),
#   ('market', 'NN'),
#   ('.', '.')],
#  [('In', 'IN'),
#   ('addition', 'NN'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('increased', 'VBN'),
#   ('reserve', 'NN'),
#   (',', ','),
#   ('the', 'DT'),
#   ('savings', 'NNS'),
#   ('bank', 'NN'),
#   ('took', 'VBD'),
#   ('a', 'DT'),
#   ('special', 'JJ'),
#   ('charge', 'NN'),
#   ('of', 'IN'),
#   ('$', '$'),
#   ('5', 'NN'),
#   ('million', 'CD'),
#   ('representing', 'VBG'),
#   ('general', 'JJ'),
#   ('and', 'CC'),
#   ('administrative', 'JJ'),
#   ('expenses', 'NNS'),
#   ('from', 'IN'),
#   ('staff', 'NN'),
#   ('reductions', 'NNS'),
#   ('and', 'CC'),
#   ('other', 'JJ'),
#   ('matters', 'NNS'),
#   (',', ','),
#   ('and', 'CC'),
#   ('it', 'PRP'),
#   ('posted', 'VBD'),
#   ('a', 'DT'),
#   ('$', '$'),
#   ('7.6', 'CD'),
#   ('million', 'CD'),
#   ('reduction', 'NN'),
#   ('in', 'IN'),
#   ('expected', 'VBN'),
#   ('mortgage', 'NN'),
#   ('servicing', 'VBG'),
#   ('fees', 'NNS'),
#   (',', ','),
#   ('reflecting', 'VBG'),
#   ('the', 'DT'),
#   ('fact', 'NN'),
#   ('that', 'IN'),
#   ('more', 'JJR'),
#   ('borrowers', 'NNS'),
#   ('are', 'VBP'),
#   ('prepaying', 'VBG'),
#   ('their', 'PRP$'),
#   ('mortgages', 'NNS'),
#   ('.', '.')],
#  [('Arbitragers', 'NNS'),
#   ('were', 'VBD'),
#   ("n't", 'RB'),
#   ('the', 'DT'),
#   ('only', 'JJ'),
#   ('big', 'JJ'),
#   ('losers', 'NNS'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('collapse', 'NN'),
#   ('of', 'IN'),
#   ('UAL', 'NNP'),
#   ('Corp.', 'NNP'),
#   ('stock', 'NN'),
#   ('.', '.')],
#  [('Look', 'VB'),
#   ('at', 'IN'),
#   ('what', 'WP'),
#   ('happened', 'VBD'),
#   ('to', 'TO'),
#   ('UAL', 'NNP'),
#   ("'s", 'POS'),
#   ('chairman', 'NN'),
#   (',', ','),
#   ('Stephen', 'NNP'),
#   ('M.', 'NNP'),
#   ('Wolf', 'NNP'),
#   (',', ','),
#   ('and', 'CC'),
#   ('its', 'PRP$'),
#   ('chief', 'JJ'),
#   ('financial', 'JJ'),
#   ('officer', 'NN'),
#   (',', ','),
#   ('John', 'NNP'),
#   ('C.', 'NNP'),
#   ('Pope', 'NNP'),
#   ('.', '.')],
#  [('On', 'IN'),
#   ('a', 'DT'),
#   ('day', 'NN'),
#   ('some', 'DT'),
#   ('United', 'NNP'),
#   ('Airlines', 'NNPS'),
#   ('employees', 'NNS'),
#   ('wanted', 'VBD'),
#   ('Mr.', 'NNP'),
#   ('Wolf', 'NNP'),
#   ('fired', 'VBD'),
#   ('and', 'CC'),
#   ('takeover', 'NN'),
#   ('stock', 'NN'),
#   ('speculators', 'NNS'),
#   ('wanted', 'VBD'),
#   ('his', 'PRP$'),
#   ('scalp', 'NN'),
#   (',', ','),
#   ('Messrs.', 'NNP'),
#   ('Wolf', 'NNP'),
#   ('and', 'CC'),
#   ('Pope', 'NNP'),
#   ('saw', 'VBD'),
#   ('their', 'PRP$'),
#   ('prospective', 'JJ'),
#   ('personal', 'JJ'),
#   ('fortunes', 'NNS'),
#   ('continue', 'VBP'),
#   ('to', 'TO'),
#   ('plummet', 'VB'),
#   ('as', 'IN'),
#   ('shares', 'NNS'),
#   ('of', 'IN'),
#   ('UAL', 'NNP'),
#   (',', ','),
#   ('United', 'NNP'),
#   ("'s", 'POS'),
#   ('parent', 'NN'),
#   ('company', 'NN'),
#   (',', ','),
#   ('dived', 'VBD'),
#   ('$', '$'),
#   ('24.875', 'CD'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('Big', 'NNP'),
#   ('Board', 'NNP'),
#   ('to', 'TO'),
#   ('close', 'VB'),
#   ('at', 'IN'),
#   ('$', '$'),
#   ('198', 'CD'),
#   ('.', '.')],
#  [('Including', 'VBG'),
#   ('Monday', 'NNP'),
#   ("'s", 'POS'),
#   ('plunge', 'NN'),
#   (',', ','),
#   ('that', 'WDT'),
#   ('has', 'VBZ'),
#   ('given', 'VBN'),
#   ('the', 'DT'),
#   ('two', 'CD'),
#   ('executives', 'NNS'),
#   ('paper', 'NN'),
#   ('losses', 'NNS'),
#   ('of', 'IN'),
#   ('$', '$'),
#   ('49.5', 'CD'),
#   ('million', 'CD'),
#   (',', ','),
#   ('based', 'VBN'),
#   ('on', 'IN'),
#   ('what', 'WP'),
#   ('they', 'PRP'),
#   ('would', 'MD'),
#   ('have', 'VB'),
#   ('realized', 'VBN'),
#   ('had', 'VBD'),
#   ('the', 'DT'),
#   ('pilots', 'NNS'),
#   ('and', 'CC'),
#   ('management-led', 'JJ'),
#   ('buy-out', 'NN'),
#   ('of', 'IN'),
#   ('UAL', 'NNP'),
#   ('gone', 'NN'),
#   ('through', 'IN'),
#   ('at', 'IN'),
#   ('$', '$'),
#   ('300', 'CD'),
#   ('a', 'DT'),
#   ('share', 'NN'),
#   ('.', '.')],
#  [('When', 'WRB'),
#   ('bank', 'NN'),
#   ('financing', 'NN'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('buy-out', 'NN'),
#   ('collapsed', 'VBD'),
#   ('last', 'JJ'),
#   ('week', 'NN'),
#   (',', ','),
#   ('so', 'RB'),
#   ('did', 'VBD'),
#   ('UAL', 'NNP'),
#   ("'s", 'POS'),
#   ('stock', 'NN'),
#   ('.', '.')],
#  [('Even', 'RB'),
#   ('if', 'IN'),
#   ('the', 'DT'),
#   ('banks', 'NNS'),
#   ('resurrect', 'VBP'),
#   ('a', 'DT'),
#   ('financing', 'NN'),
#   ('package', 'NN'),
#   ('at', 'IN'),
#   ('$', '$'),
#   ('250', 'CD'),
#   ('a', 'DT'),
#   ('share', 'NN'),
#   (',', ','),
#   ('the', 'DT'),
#   ('two', 'CD'),
#   ('executives', 'NNS'),
#   ('would', 'MD'),
#   ('still', 'RB'),
#   ('get', 'VB'),
#   ('about', 'RB'),
#   ('$', '$'),
#   ('25', 'CD'),
#   ('million', 'CD'),
#   ('less', 'JJR'),
#   ('than', 'IN'),
#   ('they', 'PRP'),
#   ('stood', 'VBD'),
#   ('to', 'TO'),
#   ('gain', 'VB'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('initial', 'JJ'),
#   ('transaction', 'NN'),
#   ('.', '.')],
#  [('Mr.', 'NNP'),
#   ('Wolf', 'NNP'),
#   ('owns', 'VBZ'),
#   ('75,000', 'CD'),
#   ('UAL', 'NNP'),
#   ('shares', 'NNS'),
#   ('and', 'CC'),
#   ('has', 'VBZ'),
#   ('options', 'NNS'),
#   ('to', 'TO'),
#   ('buy', 'VB'),
#   ('another', 'DT'),
#   ('250,000', 'CD'),
#   ('at', 'IN'),
#   ('$', '$'),
#   ('83.3125', 'CD'),
#   ('each', 'DT'),
#   ('.', '.')],
#  [('In', 'IN'),
#   ('the', 'DT'),
#   ('$', '$'),
#   ('300-a-share', 'JJ'),
#   ('buyout', 'NN'),
#   (',', ','),
#   ('that', 'WDT'),
#   ('totaled', 'VBD'),
#   ('about', 'RB'),
#   ('$', '$'),
#   ('76.7', 'CD'),
#   ('million', 'CD'),
#   ('.', '.')],
#  [('By', 'IN'),
#   ('yesterday', 'NN'),
#   ("'s", 'POS'),
#   ('close', 'NN'),
#   ('of', 'IN'),
#   ('trading', 'NN'),
#   (',', ','),
#   ('it', 'PRP'),
#   ('was', 'VBD'),
#   ('good', 'JJ'),
#   ('for', 'IN'),
#   ('a', 'DT'),
#   ('paltry', 'NN'),
#   ('$', '$'),
#   ('43.5', 'CD'),
#   ('million', 'CD'),
#   ('.', '.')],
#  [('Of', 'IN'),
#   ('course', 'NN'),
#   (',', ','),
#   ('Mr.', 'NNP'),
#   ('Wolf', 'NNP'),
#   (',', ','),
#   ('48', 'CD'),
#   ('years', 'NNS'),
#   ('old', 'JJ'),
#   (',', ','),
#   ('has', 'VBZ'),
#   ('some', 'DT'),
#   ('savings', 'NNS'),
#   ('.', '.')],
#  [('He', 'PRP'),
#   ('left', 'VBD'),
#   ('his', 'PRP$'),
#   ('last', 'JJ'),
#   ('two', 'CD'),
#   ('jobs', 'NNS'),
#   ('at', 'IN'),
#   ('Republic', 'NNP'),
#   ('Airlines', 'NNPS'),
#   ('and', 'CC'),
#   ('Flying', 'NNP'),
#   ('Tiger', 'NNP'),
#   ('with', 'IN'),
#   ('combined', 'VBN'),
#   ('stock-option', 'JJ'),
#   ('gains', 'NNS'),
#   ('of', 'IN'),
#   ('about', 'RB'),
#   ('$', '$'),
#   ('22', 'CD'),
#   ('million', 'CD'),
#   (',', ','),
#   ('and', 'CC'),
#   ('UAL', 'NNP'),
#   ('gave', 'VBD'),
#   ('him', 'PRP'),
#   ('a', 'DT'),
#   ('$', '$'),
#   ('15', 'CD'),
#   ('million', 'CD'),
#   ('bonus', 'NN'),
#   ('when', 'WRB'),
#   ('it', 'PRP'),
#   ('hired', 'VBD'),
#   ('him', 'PRP'),
#   ('.', '.')],
#  [('His', 'PRP$'),
#   ('1988', 'CD'),
#   ('salary', 'NN'),
#   ('was', 'VBD'),
#   ('$', '$'),
#   ('575,000', 'CD'),
#   (',', ','),
#   ('with', 'IN'),
#   ('a', 'DT'),
#   ('$', '$'),
#   ('575,000', 'CD'),
#   ('bonus', 'NN'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('40-year', 'JJ'),
#   ('old', 'JJ'),
#   ('Mr.', 'NNP'),
#   ('Pope', 'NNP'),
#   ('has', 'VBZ'),
#   ("n't", 'RB'),
#   ('changed', 'VBN'),
#   ('jobs', 'NNS'),
#   ('enough', 'RB'),
#   ('--', ':'),
#   ('at', 'IN'),
#   ('least', 'JJS'),
#   ('the', 'DT'),
#   ('right', 'NN'),
#   ('ones', 'NNS'),
#   ('--', ':'),
#   ('to', 'TO'),
#   ('stash', 'VB'),
#   ('away', 'RB'),
#   ('that', 'IN'),
#   ('kind', 'NN'),
#   ('of', 'IN'),
#   ('money', 'NN'),
#   ('.', '.')],
#  [('United', 'NNP'),
#   ('paid', 'VBN'),
#   ('him', 'PRP'),
#   ('a', 'DT'),
#   ('$', '$'),
#   ('375,000', 'CD'),
#   ('bonus', 'NN'),
#   ('to', 'TO'),
#   ('lure', 'VB'),
#   ('him', 'PRP'),
#   ('away', 'RB'),
#   ('from', 'IN'),
#   ('American', 'JJ'),
#   ('Airlines', 'NNPS'),
#   (',', ','),
#   ('and', 'CC'),
#   ('he', 'PRP'),
#   ('was', 'VBD'),
#   ('paid', 'VBN'),
#   ('a', 'DT'),
#   ('salary', 'NN'),
#   ('of', 'IN'),
#   ('$', '$'),
#   ('342,122', 'CD'),
#   ('last', 'JJ'),
#   ('year', 'NN'),
#   ('with', 'IN'),
#   ('a', 'DT'),
#   ('$', '$'),
#   ('280,000', 'CD'),
#   ('bonus', 'NN'),
#   ('.', '.')],
#  [('Mr.', 'NNP'),
#   ('Pope', 'NNP'),
#   ('owns', 'VBZ'),
#   ('10,000', 'CD'),
#   ('UAL', 'NNP'),
#   ('shares', 'NNS'),
#   ('and', 'CC'),
#   ('has', 'VBZ'),
#   ('options', 'NNS'),
#   ('to', 'TO'),
#   ('buy', 'VB'),
#   ('another', 'DT'),
#   ('150,000', 'CD'),
#   ('at', 'IN'),
#   ('$', '$'),
#   ('69', 'CD'),
#   ('each', 'DT'),
#   ('.', '.')],
#  [('That', 'DT'),
#   ('came', 'VBD'),
#   ('to', 'TO'),
#   ('a', 'DT'),
#   ('combined', 'VBN'),
#   ('$', '$'),
#   ('37.7', 'CD'),
#   ('million', 'CD'),
#   ('under', 'IN'),
#   ('the', 'DT'),
#   ('$', '$'),
#   ('300-a-share', 'JJ'),
#   ('buy-out', 'NN'),
#   (',', ','),
#   ('but', 'CC'),
#   ('just', 'RB'),
#   ('$', '$'),
#   ('21.3', 'CD'),
#   ('million', 'CD'),
#   ('at', 'IN'),
#   ('yesterday', 'NN'),
#   ("'s", 'POS'),
#   ('close', 'NN'),
#   ('.', '.')],
#  [('Of', 'IN'),
#   ('the', 'DT'),
#   ('combined', 'VBN'),
#   ('$', '$'),
#   ('114.4', 'CD'),
#   ('million', 'CD'),
#   ('the', 'DT'),
#   ('two', 'CD'),
#   ('men', 'NNS'),
#   ('were', 'VBD'),
#   ('scheduled', 'VBN'),
#   ('to', 'TO'),
#   ('reap', 'VB'),
#   ('under', 'IN'),
#   ('the', 'DT'),
#   ('buy-out', 'NN'),
#   (',', ','),
#   ('they', 'PRP'),
#   ('agreed', 'VBD'),
#   ('to', 'TO'),
#   ('invest', 'VB'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('buy-out', 'NN'),
#   ('just', 'RB'),
#   ('$', '$'),
#   ('15', 'CD'),
#   ('million', 'CD'),
#   (',', ','),
#   ('angering', 'VBG'),
#   ('many', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('thousands', 'NNS'),
#   ('of', 'IN'),
#   ('workers', 'NNS'),
#   ('asked', 'VBD'),
#   ('to', 'TO'),
#   ('make', 'VB'),
#   ('pay', 'NN'),
#   ('concessions', 'NNS'),
#   ('so', 'RB'),
#   ('the', 'DT'),
#   ('buy-out', 'NN'),
#   ('would', 'MD'),
#   ('be', 'VB'),
#   ('a', 'DT'),
#   ('success', 'NN'),
#   ('.', '.')],
#  [('United', 'NNP'),
#   ("'s", 'POS'),
#   ('directors', 'NNS'),
#   ('voted', 'VBD'),
#   ('themselves', 'PRP'),
#   (',', ','),
#   ('and', 'CC'),
#   ('their', 'PRP$'),
#   ('spouses', 'NNS'),
#   (',', ','),
#   ('lifetime', 'JJ'),
#   ('access', 'NN'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('Friendly', 'NNP'),
#   ('Skies', 'NNP'),
#   ('--', ':'),
#   ('free', 'JJ'),
#   ('first-class', 'JJ'),
#   ('travel', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('$', '$'),
#   ('20,000', 'CD'),
#   ('a', 'DT'),
#   ('year', 'NN'),
#   ('for', 'IN'),
#   ('life', 'NN'),
#   ('as', 'IN'),
#   ('well', 'RB'),
#   ('.', '.')],
#  [('Conceivably', 'RB'),
#   (',', ','),
#   ('in', 'IN'),
#   ('a', 'DT'),
#   ('scaled-back', 'JJ'),
#   ('buy-out', 'NN'),
#   (',', ','),
#   ('they', 'PRP'),
#   ('could', 'MD'),
#   ('be', 'VB'),
#   ('bumped', 'VBN'),
#   ('back', 'RB'),
#   ('to', 'TO'),
#   ('coach', 'VB'),
#   ('seats', 'NNS'),
#   ('for', 'IN'),
#   ('life', 'NN'),
#   ('.', '.')],
#  [('Thomas', 'NNP'),
#   ('H.', 'NNP'),
#   ('Johnson', 'NNP'),
#   (',', ','),
#   ('president', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('Coatedboard', 'NNP'),
#   ('division', 'NN'),
#   ('of', 'IN'),
#   ('Mead', 'NNP'),
#   ('Corp.', 'NNP'),
#   (',', ','),
#   ('was', 'VBD'),
#   ('named', 'VBN'),
#   ('president', 'NN'),
#   ('of', 'IN'),
#   ('Manville', 'NNP'),
#   ('Forest', 'NNP'),
#   ('Products', 'NNP'),
#   ('Corp.', 'NNP'),
#   (',', ','),
#   ('a', 'DT'),
#   ('Manville', 'NNP'),
#   ('unit', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('senior', 'JJ'),
#   ('vice', 'NN'),
#   ('president', 'NN'),
#   ('of', 'IN'),
#   ('Manville', 'NNP'),
#   ('Corp', 'NNP'),
#   ('.', '.')],
#  [('Mr.', 'NNP'),
#   ('Johnson', 'NNP'),
#   ('succeeds', 'VBZ'),
#   ('Harry', 'NNP'),
#   ('W.', 'NNP'),
#   ('Sherman', 'NNP'),
#   (',', ','),
#   ('who', 'WP'),
#   ('resigned', 'VBD'),
#   ('to', 'TO'),
#   ('pursue', 'VB'),
#   ('other', 'JJ'),
#   ('interests', 'NNS'),
#   (',', ','),
#   ('in', 'IN'),
#   ('both', 'DT'),
#   ('positions', 'NNS'),
#   ('.', '.')],
#  [('Manville', 'NNP'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('building', 'NN'),
#   ('and', 'CC'),
#   ('forest', 'NN'),
#   ('products', 'NNS'),
#   ('concern', 'VBP'),
#   ('.', '.')],
#  [('US', 'NNP'),
#   ('Facilities', 'NNP'),
#   ('Corp.', 'NNP'),
#   ('said', 'VBD'),
#   ('Robert', 'NNP'),
#   ('J.', 'NNP'),
#   ('Percival', 'NNP'),
#   ('agreed', 'VBD'),
#   ('to', 'TO'),
#   ('step', 'VB'),
#   ('down', 'RB'),
#   ('as', 'IN'),
#   ('vice', 'NN'),
#   ('chairman', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('insurance', 'NN'),
#   ('holding', 'VBG'),
#   ('company', 'NN'),
#   ('.', '.')],
#  [('``', '``'),
#   ('There', 'EX'),
#   ('was', 'VBD'),
#   ('a', 'DT'),
#   ('difference', 'NN'),
#   ('of', 'IN'),
#   ('opinion', 'NN'),
#   ('as', 'IN'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('future', 'NN'),
#   ('direction', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('company', 'NN'),
#   (',', ','),
#   ("''", "''"),
#   ('a', 'DT'),
#   ('spokeswoman', 'NN'),
#   ('said', 'VBD'),
#   ('.', '.')],
#  [('Mr.', 'NNP'),
#   ('Percival', 'NNP'),
#   ('declined', 'VBD'),
#   ('to', 'TO'),
#   ('comment', 'VB'),
#   ('.', '.')],
#  [('In', 'IN'),
#   ('a', 'DT'),
#   ('statement', 'NN'),
#   (',', ','),
#   ('US', 'NNP'),
#   ('Facilities', 'NNP'),
#   ('said', 'VBD'),
#   ('Mr.', 'NNP'),
#   ('Percival', 'NNP'),
#   ("'s", 'POS'),
#   ('employment', 'NN'),
#   ('contract', 'NN'),
#   ('calls', 'NNS'),
#   ('for', 'IN'),
#   ('him', 'PRP'),
#   ('to', 'TO'),
#   ('act', 'VB'),
#   ('as', 'IN'),
#   ('a', 'DT'),
#   ('consultant', 'NN'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('company', 'NN'),
#   ('for', 'IN'),
#   ('two', 'CD'),
#   ('years', 'NNS'),
#   ('.', '.')],
#  [('He', 'PRP'),
#   ('will', 'MD'),
#   ('also', 'RB'),
#   ('remain', 'VB'),
#   ('a', 'DT'),
#   ('director', 'NN'),
#   (',', ','),
#   ('US', 'NNP'),
#   ('Facilities', 'NNP'),
#   ('said', 'VBD'),
#   (',', ','),
#   ('but', 'CC'),
#   ('wo', 'MD'),
#   ("n't", 'RB'),
#   ('serve', 'VB'),
#   ('on', 'IN'),
#   ('any', 'DT'),
#   ('board', 'NN'),
#   ('committees', 'NNS'),
#   ('.', '.')],
#  [('Mr.', 'NNP'),
#   ('Percival', 'NNP'),
#   ('will', 'MD'),
#   ('be', 'VB'),
#   ('succeeded', 'VBN'),
#   ('on', 'IN'),
#   ('an', 'DT'),
#   ('interim', 'JJ'),
#   ('basis', 'NN'),
#   ('by', 'IN'),
#   ('George', 'NNP'),
#   ('Kadonada', 'NNP'),
#   (',', ','),
#   ('US', 'NNP'),
#   ('Facilities', 'NNP'),
#   ('chairman', 'NN'),
#   ('and', 'CC'),
#   ('president', 'NN'),
#   ('.', '.')],
#  [('In', 'IN'),
#   ('the', 'DT'),
#   ('same', 'JJ'),
#   ('statement', 'NN'),
#   (',', ','),
#   ('US', 'NNP'),
#   ('Facilities', 'NNP'),
#   ('also', 'RB'),
#   ('said', 'VBD'),
#   ('it', 'PRP'),
#   ('had', 'VBD'),
#   ('bought', 'VBN'),
#   ('back', 'JJ'),
#   ('112,000', 'CD'),
#   ('of', 'IN'),
#   ('its', 'PRP$'),
#   ('common', 'JJ'),
#   ('shares', 'NNS'),
#   ('in', 'IN'),
#   ('a', 'DT'),
#   ('private', 'JJ'),
#   ('transaction', 'NN'),
#   ('.', '.')],
#  [('Terms', 'NNS'),
#   ('were', 'VBD'),
#   ("n't", 'RB'),
#   ('disclosed', 'VBN'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('buy-back', 'NN'),
#   ('represents', 'VBZ'),
#   ('about', 'IN'),
#   ('3', 'CD'),
#   ('%', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('company', 'NN'),
#   ("'s", 'POS'),
#   ('shares', 'NNS'),
#   (',', ','),
#   ('based', 'VBN'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('3.7', 'CD'),
#   ('million', 'CD'),
#   ('shares', 'NNS'),
#   ('outstanding', 'JJ'),
#   ('as', 'IN'),
#   ('of', 'IN'),
#   ('Sept.', 'NNP'),
#   ('30', 'CD'),
#   ('.', '.')],
#  [('In', 'IN'),
#   ('national', 'JJ'),
#   ('over-the-counter', 'JJ'),
#   ('trading', 'NN'),
#   ('yesterday', 'NN'),
#   (',', ','),
#   ('US', 'NNP'),
#   ('Facilities', 'NNP'),
#   ('closed', 'VBD'),
#   ('at', 'IN'),
#   ('$', '$'),
#   ('3.625', 'CD'),
#   (',', ','),
#   ('unchanged', 'JJ'),
#   ('.', '.')],
#  [('Three', 'CD'),
#   ('leading', 'VBG'),
#   ('drug', 'NN'),
#   ('companies', 'NNS'),
#   ('reported', 'VBD'),
#   ('robust', 'JJ'),
#   ('third-quarter', 'JJ'),
#   ('earnings', 'NNS'),
#   (',', ','),
#   ('bolstered', 'VBN'),
#   ('by', 'IN'),
#   ('strong', 'JJ'),
#   ('sales', 'NNS'),
#   ('of', 'IN'),
#   ('newer', 'JJR'),
#   (',', ','),
#   ('big-selling', 'JJ'),
#   ('prescriptions', 'NNS'),
#   ('drugs', 'NNS'),
#   ('that', 'WDT'),
#   ('provide', 'VBP'),
#   ('hefty', 'JJ'),
#   ('profit', 'NN'),
#   ('margins', 'NNS'),
#   ('.', '.')],
#  [('Merck', 'NNP'),
#   ('&', 'CC'),
#   ('Co.', 'NNP'),
#   ('reported', 'VBD'),
#   ('a', 'DT'),
#   ('25', 'CD'),
#   ('%', 'NN'),
#   ('increase', 'NN'),
#   ('in', 'IN'),
#   ('earnings', 'NNS'),
#   (';', ':'),
#   ('Warner-Lambert', 'NNP'),
#   ('Co.', 'NNP'),
#   ("'s", 'POS'),
#   ('profit', 'NN'),
#   ('rose', 'VBD'),
#   ('22', 'CD'),
#   ('%', 'NN'),
#   ('and', 'CC'),
#   ('Eli', 'NNP'),
#   ('Lilly', 'NNP'),
#   ('&', 'CC'),
#   ('Co.', 'NNP'),
#   ("'s", 'POS'),
#   ('net', 'JJ'),
#   ('income', 'NN'),
#   ('rose', 'VBD'),
#   ('24', 'CD'),
#   ('%', 'NN'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('results', 'NNS'),
#   ('were', 'VBD'),
#   ('in', 'IN'),
#   ('line', 'NN'),
#   ('with', 'IN'),
#   ('analysts', 'NNS'),
#   ("'", 'POS'),
#   ('expectations', 'NNS'),
#   ('.', '.')],
#  [('Merck', 'NNP'), ('&', 'CC'), ('Co', 'NNP'), ('.', '.')],
#  [('Merck', 'NNP'),
#   (',', ','),
#   ('Rahway', 'NNP'),
#   (',', ','),
#   ('N.J.', 'NNP'),
#   (',', ','),
#   ('continued', 'VBD'),
#   ('to', 'TO'),
#   ('lead', 'VB'),
#   ('the', 'DT'),
#   ('industry', 'NN'),
#   ('with', 'IN'),
#   ('a', 'DT'),
#   ('strong', 'JJ'),
#   ('sales', 'NNS'),
#   ('performance', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('human', 'JJ'),
#   ('and', 'CC'),
#   ('animal', 'JJ'),
#   ('health-products', 'JJ'),
#   ('segment', 'NN'),
#   ('.', '.')],
#  [('A', 'DT'),
#   ('stronger', 'JJR'),
#   ('U.S.', 'NNP'),
#   ('dollar', 'NN'),
#   ('reduced', 'VBD'),
#   ('third-quarter', 'JJ'),
#   ('and', 'CC'),
#   ('first-nine-month', 'JJ'),
#   ('sales', 'NNS'),
#   ('growth', 'NN'),
#   ('2', 'CD'),
#   ('%', 'NN'),
#   ('and', 'CC'),
#   ('3', 'CD'),
#   ('%', 'NN'),
#   (',', ','),
#   ('respectively', 'RB'),
#   ('.', '.')],
#  [('International', 'NNP'),
#   ('sales', 'NNS'),
#   ('accounted', 'VBD'),
#   ('for', 'IN'),
#   ('47', 'CD'),
#   ('%', 'NN'),
#   ('of', 'IN'),
#   ('total', 'JJ'),
#   ('company', 'NN'),
#   ('sales', 'NNS'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('nine', 'CD'),
#   ('months', 'NNS'),
#   (',', ','),
#   ('compared', 'VBN'),
#   ('with', 'IN'),
#   ('50', 'CD'),
#   ('%', 'NN'),
#   ('a', 'DT'),
#   ('year', 'NN'),
#   ('earlier', 'RBR'),
#   ('.', '.')],
#  [('Sales', 'NNS'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('quarter', 'NN'),
#   ('rose', 'VBD'),
#   ('to', 'TO'),
#   ('$', '$'),
#   ('1.63', 'CD'),
#   ('billion', 'CD'),
#   ('from', 'IN'),
#   ('$', '$'),
#   ('1.47', 'CD'),
#   ('billion', 'CD'),
#   ('.', '.')],
#  [('Mevacor', 'NNP'),
#   (',', ','),
#   ('Merck', 'NNP'),
#   ("'s", 'POS'),
#   ('new', 'JJ'),
#   ('cholesterol-lowering', 'JJ'),
#   ('drug', 'NN'),
#   (',', ','),
#   ('had', 'VBD'),
#   ('higher', 'JJR'),
#   ('sales', 'NNS'),
#   ('than', 'IN'),
#   ('any', 'DT'),
#   ('other', 'JJ'),
#   ('prescription', 'NN'),
#   ('medicine', 'NN'),
#   ('has', 'VBZ'),
#   ('ever', 'RB'),
#   ('achieved', 'VBN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('U.S.', 'NNP'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('year', 'NN'),
#   ('following', 'VBG'),
#   ('introduction', 'NN'),
#   (',', ','),
#   ('the', 'DT'),
#   ('company', 'NN'),
#   ('said', 'VBD'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('drug', 'NN'),
#   ('was', 'VBD'),
#   ('introduced', 'VBN'),
#   ('in', 'IN'),
#   ('West', 'NNP'),
#   ('Germany', 'NNP'),
#   ('this', 'DT'),
#   ('year', 'NN'),
#   ('.', '.')],
#  [('Intense', 'JJ'),
#   ('competition', 'NN'),
#   (',', ','),
#   ('however', 'RB'),
#   (',', ','),
#   ('led', 'VBD'),
#   ('to', 'TO'),
#   ('unit', 'NN'),
#   ('sales', 'NNS'),
#   ('declines', 'NNS'),
#   ('for', 'IN'),
#   ('a', 'DT'),
#   ('group', 'NN'),
#   ('of', 'IN'),
#   ('Merck', 'NNP'),
#   ("'s", 'POS'),
#   ('established', 'VBN'),
#   ('human', 'JJ'),
#   ('and', 'CC'),
#   ('animal-health', 'JJ'),
#   ('products', 'NNS'),
#   (',', ','),
#   ('including', 'VBG'),
#   ('Aldomet', 'NNP'),
#   ('and', 'CC'),
#   ('Indocin', 'NNP'),
#   ('.', '.')],
#  [('In', 'IN'),
#   ('New', 'NNP'),
#   ('York', 'NNP'),
#   ('Stock', 'NNP'),
#   ('Exchange', 'NNP'),
#   ('composite', 'JJ'),
#   ('trading', 'NN'),
#   ('yesterday', 'NN'),
#   (',', ','),
#   ('Merck', 'NNP'),
#   ('shares', 'NNS'),
#   ('closed', 'VBD'),
#   ('at', 'IN'),
#   ('$', '$'),
#   ('75.25', 'CD'),
#   (',', ','),
#   ('up', 'IN'),
#   ('50', 'CD'),
#   ('cents', 'NNS'),
#   ('.', '.')],
#  [('Warner-Lambert', 'JJ'), ('Co', 'NNP'), ('.', '.')],
#  [('Warner-Lambert', 'JJ'),
#   (',', ','),
#   ('Morris', 'NNP'),
#   ('Plains', 'NNP'),
#   (',', ','),
#   ('N.J.', 'NNP'),
#   (',', ','),
#   ('reported', 'VBD'),
#   ('sales', 'NNS'),
#   ('that', 'WDT'),
#   ('were', 'VBD'),
#   ('a', 'DT'),
#   ('record', 'NN'),
#   ('for', 'IN'),
#   ('any', 'DT'),
#   ('quarter', 'NN'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('eighth', 'JJ'),
#   ('quarter', 'NN'),
#   ('in', 'IN'),
#   ('a', 'DT'),
#   ('row', 'NN'),
#   ('of', 'IN'),
#   ('20', 'CD'),
#   ('%', 'NN'),
#   ('or', 'CC'),
#   ('more', 'JJR'),
#   ('per-share', 'JJ'),
#   ('earnings', 'NNS'),
#   ('growth', 'NN'),
#   ('.', '.')],
#  [('Spurred', 'VBN'),
#   ('by', 'IN'),
#   ('growth', 'NN'),
#   ('in', 'IN'),
#   ('world-wide', 'JJ'),
#   ('sales', 'NNS'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('company', 'NN'),
#   ("'s", 'POS'),
#   ('prescription', 'NN'),
#   ('drugs', 'NNS'),
#   (',', ','),
#   ('Warner-Lambert', 'NNP'),
#   ('said', 'VBD'),
#   ('1989', 'CD'),
#   ('will', 'MD'),
#   ('be', 'VB'),
#   ('the', 'DT'),
#   ('best', 'JJS'),
#   ('year', 'NN'),
#   ('in', 'IN'),
#   ('its', 'PRP$'),
#   ('history', 'NN'),
#   (',', ','),
#   ('with', 'IN'),
#   ('per-share', 'JJ'),
#   ('earnings', 'NNS'),
#   ('expected', 'VBN'),
#   ('to', 'TO'),
#   ('increase', 'VB'),
#   ('more', 'JJR'),
#   ('than', 'IN'),
#   ('20', 'CD'),
#   ('%', 'NN'),
#   ('to', 'TO'),
#   ('about', 'RB'),
#   ('$', '$'),
#   ('6.10', 'CD'),
#   ('.', '.')],
#  [('Sales', 'NNS'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('quarter', 'NN'),
#   ('rose', 'VBD'),
#   ('to', 'TO'),
#   ('$', '$'),
#   ('1.11', 'CD'),
#   ('billion', 'CD'),
#   ('from', 'IN'),
#   ('$', '$'),
#   ('1.03', 'CD'),
#   ('billion', 'CD'),
#   ('.', '.')],
#  [('Prescription-drug', 'JJ'),
#   ('world-wide', 'JJ'),
#   ('sales', 'NNS'),
#   ('rose', 'VBD'),
#   ('9', 'CD'),
#   ('%', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('quarter', 'NN'),
#   ('to', 'TO'),
#   ('$', '$'),
#   ('340', 'CD'),
#   ('million', 'CD'),
#   (';', ':'),
#   ('U.S.', 'NNP'),
#   ('sales', 'NNS'),
#   ('rose', 'VBD'),
#   ('15', 'CD'),
#   ('%', 'NN'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('segment', 'NN'),
#   ("'s", 'POS'),
#   ('growth', 'NN'),
#   ('was', 'VBD'),
#   ('led', 'VBN'),
#   ('by', 'IN'),
#   ('sales', 'NNS'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('cardiovascular', 'JJ'),
#   ('drugs', 'NNS'),
#   ('Lopid', 'NNP'),
#   (',', ','),
#   ('a', 'DT'),
#   ('lipid', 'JJ'),
#   ('regulator', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('Dilzem', 'NNP'),
#   (',', ','),
#   ('a', 'DT'),
#   ('calcium', 'NN'),
#   ('channel', 'NN'),
#   ('blocker', 'NN'),
#   ('.', '.')],
#  [('World-wide', 'JJ'),
#   ('sales', 'NNS'),
#   ('of', 'IN'),
#   ('Warner-Lambert', 'NNP'),
#   ("'s", 'POS'),
#   ('non-prescription', 'JJ'),
#   ('health-care', 'JJ'),
#   ('products', 'NNS'),
#   (',', ','),
#   ('such', 'JJ'),
#   ('as', 'IN'),
#   ('Halls', 'NNP'),
#   ('cough', 'NN'),
#   ('tablets', 'NNS'),
#   (',', ','),
#   ('Rolaids', 'NNP'),
#   ('antacid', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('Lubriderm', 'NNP'),
#   ('skin', 'JJ'),
#   ('lotion', 'NN'),
#   (',', ','),
#   ('increased', 'VBN'),
#   ('3', 'CD'),
#   ('%', 'NN'),
#   ('to', 'TO'),
#   ('$', '$'),
#   ('362', 'CD'),
#   ('million', 'CD'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('third', 'JJ'),
#   ('quarter', 'NN'),
#   (';', ':'),
#   ('U.S.', 'NNP'),
#   ('sales', 'NNS'),
#   ('rose', 'VBD'),
#   ('5', 'NN'),
#   ('%', 'NN'),
#   ('.', '.')],
#  [('Confectionery', 'NNP'),
#   ('products', 'NNS'),
#   ('sales', 'NNS'),
#   ('also', 'RB'),
#   ('had', 'VBD'),
#   ('strong', 'JJ'),
#   ('growth', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('quarter', 'NN'),
#   ('.', '.')],
#  [('World-wide', 'JJ'),
#   ('sales', 'NNS'),
#   ('of', 'IN'),
#   ('Trident', 'NNP'),
#   ('gum', 'NN'),
#   (',', ','),
#   ('Certs', 'NNP'),
#   ('breath', 'NN'),
#   ('mints', 'NNS'),
#   (',', ','),
#   ('and', 'CC'),
#   ('Clorets', 'NNP'),
#   ('gum', 'NN'),
#   ('and', 'CC'),
#   ('breath', 'NN'),
#   ('mints', 'NNS'),
#   (',', ','),
#   ('increased', 'VBN'),
#   ('12', 'CD'),
#   ('%', 'NN'),
#   ('to', 'TO'),
#   ('$', '$'),
#   ('277', 'CD'),
#   ('million', 'CD'),
#   ('.', '.')],
#  [('Warner-Lambert', 'JJ'),
#   ('shares', 'NNS'),
#   ('closed', 'VBD'),
#   ('at', 'IN'),
#   ('$', '$'),
#   ('109.50', 'CD'),
#   ('a', 'DT'),
#   ('share', 'NN'),
#   (',', ','),
#   ('up', 'IN'),
#   ('$', '$'),
#   ('1.50', 'CD'),
#   (',', ','),
#   ('in', 'IN'),
#   ('Big', 'NNP'),
#   ('Board', 'NNP'),
#   ('composite', 'JJ'),
#   ('trading', 'NN'),
#   ('yesterday', 'NN'),
#   ('.', '.')],
#  [('Eli', 'NNP'), ('Lilly', 'NNP'), ('&', 'CC'), ('Co', 'NNP'), ('.', '.')],
#  [('Lilly', 'RB'),
#   ('attributed', 'VBD'),
#   ('record', 'NN'),
#   ('third-quarter', 'JJ'),
#   ('and', 'CC'),
#   ('nine-month', 'JJ'),
#   ('results', 'NNS'),
#   ('to', 'TO'),
#   ('world-wide', 'JJ'),
#   ('gains', 'NNS'),
#   ('for', 'IN'),
#   ('pharmaceuticals', 'NNS'),
#   (',', ','),
#   ('medical', 'JJ'),
#   ('instruments', 'NNS'),
#   ('and', 'CC'),
#   ('plant-science', 'NN'),
#   ('products', 'NNS'),
#   ('despite', 'IN'),
#   ('poor', 'JJ'),
#   ('exchange', 'NN'),
#   ('rates', 'NNS'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('dollar', 'NN'),
#   ('that', 'WDT'),
#   ('slowed', 'VBD'),
#   ('sales', 'NNS'),
#   ('abroad', 'RB'),
#   ('.', '.')],
#  [('Earnings', 'NNS'),
#   ('continued', 'VBD'),
#   ('to', 'TO'),
#   ('pace', 'VB'),
#   ('sales', 'NNS'),
#   ('because', 'IN'),
#   ('of', 'IN'),
#   ('a', 'DT'),
#   ('lower', 'JJR'),
#   ('tax', 'NN'),
#   ('rate', 'NN'),
#   (',', ','),
#   ('profit', 'NN'),
#   ('from', 'IN'),
#   ('the', 'DT'),
#   ('renegotiation', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('debt', 'NN'),
#   ('instrument', 'NN'),
#   ('received', 'VBD'),
#   ('from', 'IN'),
#   ('Faberge', 'NNP'),
#   ('Inc.', 'NNP'),
#   ('in', 'IN'),
#   ('connection', 'NN'),
#   ('with', 'IN'),
#   ('Lilly', 'NNP'),
#   ("'s", 'POS'),
#   ('sale', 'NN'),
#   ('of', 'IN'),
#   ('Elizabeth', 'NNP'),
#   ('Arden', 'NNP'),
#   ('Inc.', 'NNP'),
#   ('in', 'IN'),
#   ('1987', 'CD'),
#   (',', ','),
#   ('and', 'CC'),
#   ('net', 'JJ'),
#   ('proceeds', 'NNS'),
#   ('from', 'IN'),
#   ('the', 'DT'),
#   ('settlement', 'NN'),
#   ('of', 'IN'),
#   ('patent', 'NN'),
#   ('litigation', 'NN'),
#   ('at', 'IN'),
#   ('Lilly', 'NNP'),
#   ("'s", 'POS'),
#   ('Hybritech', 'NNP'),
#   ('Inc.', 'NNP'),
#   ('unit', 'NN'),
#   ('.', '.')],
#  [('Third-quarter', 'JJ'),
#   ('sales', 'NNS'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('Indianapolis', 'NNP'),
#   (',', ','),
#   ('Ind.', 'NNP'),
#   (',', ','),
#   ('company', 'NN'),
#   ('rose', 'VBD'),
#   ('11', 'CD'),
#   ('%', 'NN'),
#   ('to', 'TO'),
#   ('$', '$'),
#   ('1.045', 'CD'),
#   ('billion', 'CD'),
#   ('from', 'IN'),
#   ('$', '$'),
#   ('940.6', 'CD'),
#   ('million', 'CD'),
#   ('.', '.')],
#  [('Nine-month', 'JJ'),
#   ('sales', 'NNS'),
#   ('grew', 'VBD'),
#   ('12', 'CD'),
#   ('%', 'NN'),
#   ('to', 'TO'),
#   ('$', '$'),
#   ('3.39', 'CD'),
#   ('billion', 'CD'),
#   ('from', 'IN'),
#   ('$', '$'),
#   ('3.03', 'CD'),
#   ('billion', 'CD'),
#   ('a', 'DT'),
#   ('year', 'NN'),
#   ('earlier', 'RBR'),
#   ('.', '.')],
#  [('Sales', 'NNS'),
#   ('of', 'IN'),
#   ('Prozac', 'NNP'),
#   (',', ','),
#   ('an', 'DT'),
#   ('anti-depressant', 'JJ'),
#   (',', ','),
#   ('led', 'VBD'),
#   ('drug-sales', 'JJ'),
#   ('increases', 'NNS'),
#   ('.', '.')],
#  [('Higher', 'DT'),
#   ('sales', 'NNS'),
#   ('of', 'IN'),
#   ('pesticides', 'NNS'),
#   ('and', 'CC'),
#   ('other', 'JJ'),
#   ('plant-science', 'JJ'),
#   ('products', 'NNS'),
#   ('more', 'JJR'),
#   ('than', 'IN'),
#   ('offset', 'VB'),
#   ('a', 'DT'),
#   ('slight', 'JJ'),
#   ('decline', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('sales', 'NNS'),
#   ('of', 'IN'),
#   ('animal-health', 'JJ'),
#   ('products', 'NNS'),
#   ('to', 'TO'),
#   ('fuel', 'VB'),
#   ('the', 'DT'),
#   ('increase', 'NN'),
#   ('in', 'IN'),
#   ('world-wide', 'JJ'),
#   ('agricultural', 'JJ'),
#   ('product', 'NN'),
#   ('sales', 'NNS'),
#   (',', ','),
#   ('Lilly', 'NNP'),
#   ('said', 'VBD'),
#   ('.', '.')],
#  [('Advanced', 'NNP'),
#   ('Cardiovascular', 'NNP'),
#   ('Systems', 'NNP'),
#   ('Inc.', 'NNP'),
#   ('and', 'CC'),
#   ('Cardiac', 'NNP'),
#   ('Pacemakers', 'NNP'),
#   ('Inc.', 'NNP'),
#   ('units', 'NNS'),
#   ('led', 'VBD'),
#   ('growth', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('medical-instrument', 'NN'),
#   ('systems', 'NNS'),
#   ('division', 'NN'),
#   ('.', '.')],
#  [('Lilly', 'RB'),
#   ('shares', 'NNS'),
#   ('closed', 'VBD'),
#   ('yesterday', 'NN'),
#   ('in', 'IN'),
#   ('composite', 'JJ'),
#   ('trading', 'NN'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('Big', 'NNP'),
#   ('Board', 'NNP'),
#   ('at', 'IN'),
#   ('$', '$'),
#   ('62.25', 'CD'),
#   (',', ','),
#   ('down', 'RB'),
#   ('12.5', 'CD'),
#   ('cents', 'NNS'),
#   ('.', '.')],
#  [('Reuben', 'NNP'),
#   ('Mark', 'NNP'),
#   (',', ','),
#   ('chairman', 'NN'),
#   ('of', 'IN'),
#   ('Colgate-Palmolive', 'NNP'),
#   ('Co.', 'NNP'),
#   (',', ','),
#   ('said', 'VBD'),
#   ('he', 'PRP'),
#   ('is', 'VBZ'),
#   ('``', '``'),
#   ('comfortable', 'JJ'),
#   ("''", "''"),
#   ('with', 'IN'),
#   ('analysts', 'NNS'),
#   ("'", 'POS'),
#   ('estimates', 'NNS'),
#   ('that', 'IN'),
#   ('third-quarter', 'JJ'),
#   ('earnings', 'NNS'),
#   ('rose', 'VBD'),
#   ('to', 'TO'),
#   ('between', 'IN'),
#   ('95', 'CD'),
#   ('cents', 'NNS'),
#   ('and', 'CC'),
#   ('$', '$'),
#   ('1.05', 'CD'),
#   ('a', 'DT'),
#   ('share', 'NN'),
#   ('.', '.')],
#  [('That', 'DT'),
#   ('compares', 'VBZ'),
#   ('with', 'IN'),
#   ('per-share', 'JJ'),
#   ('earnings', 'NNS'),
#   ('from', 'IN'),
#   ('continuing', 'VBG'),
#   ('operations', 'NNS'),
#   ('of', 'IN'),
#   ('69', 'CD'),
#   ('cents', 'NNS'),
#   ('the', 'DT'),
#   ('year', 'NN'),
#   ('earlier', 'RBR'),
#   (';', ':'),
#   ('including', 'VBG'),
#   ('discontinued', 'VBN'),
#   ('operations', 'NNS'),
#   (',', ','),
#   ('per-share', 'NN'),
#   ('was', 'VBD'),
#   ('88', 'CD'),
#   ('cents', 'NNS'),
#   ('a', 'DT'),
#   ('year', 'NN'),
#   ('ago', 'RB'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('per-share', 'JJ'),
#   ('estimates', 'NNS'),
#   ('mean', 'VBP'),
#   ('the', 'DT'),
#   ('consumer-products', 'NNS'),
#   ('company', 'NN'),
#   ("'s", 'POS'),
#   ('net', 'JJ'),
#   ('income', 'NN'),
#   (',', ','),
#   ('increased', 'VBN'),
#   ('to', 'TO'),
#   ('between', 'IN'),
#   ('$', '$'),
#   ('69.5', 'CD'),
#   ('million', 'CD'),
#   ('and', 'CC'),
#   ('$', '$'),
#   ('76', 'CD'),
#   ('million', 'CD'),
#   (',', ','),
#   ('from', 'IN'),
#   ('$', '$'),
#   ('47.1', 'CD'),
#   ('million', 'CD'),
#   ('the', 'DT'),
#   ('year-before', 'JJ'),
#   ('period', 'NN'),
#   ('.', '.')],
#  [('Analysts', 'NNS'),
#   ('estimate', 'VBP'),
#   ('Colgate', 'NNP'),
#   ("'s", 'POS'),
#   ('world-wide', 'JJ'),
#   ('third-quarter', 'JJ'),
#   ('sales', 'NNS'),
#   ('rose', 'VBD'),
#   ('about', 'IN'),
#   ('8', 'CD'),
#   ('%', 'NN'),
#   ('to', 'TO'),
#   ('$', '$'),
#   ('1.29', 'CD'),
#   ('billion', 'CD'),
#   ('.', '.')],
#  [('Mr.', 'NNP'),
#   ('Mark', 'NNP'),
#   ('attributed', 'VBD'),
#   ('the', 'DT'),
#   ('earnings', 'NNS'),
#   ('growth', 'NN'),
#   ('to', 'TO'),
#   ('strong', 'JJ'),
#   ('sales', 'NNS'),
#   ('in', 'IN'),
#   ('Latin', 'NNP'),
#   ('America', 'NNP'),
#   (',', ','),
#   ('Asia', 'NNP'),
#   ('and', 'CC'),
#   ('Europe', 'NNP'),
#   ('.', '.')],
#  [('Results', 'NNS'),
#   ('were', 'VBD'),
#   ('also', 'RB'),
#   ('bolstered', 'VBN'),
#   ('by', 'IN'),
#   ('``', '``'),
#   ('a', 'DT'),
#   ('very', 'RB'),
#   ('meaningful', 'JJ'),
#   ("''", "''"),
#   ('increase', 'NN'),
#   ('in', 'IN'),
#   ('operating', 'VBG'),
#   ('profit', 'NN'),
#   ('by', 'IN'),
#   ('Colgate', 'NNP'),
#   ("'s", 'POS'),
#   ('U.S.', 'NNP'),
#   ('business', 'NN'),
#   (',', ','),
#   ('Mr.', 'NNP'),
#   ('Mark', 'NNP'),
#   ('said', 'VBD'),
#   ('.', '.')],
#  [('Operating', 'NN'),
#   ('profit', 'NN'),
#   ('at', 'IN'),
#   ('Colgate', 'NNP'),
#   ("'s", 'POS'),
#   ('U.S.', 'NNP'),
#   ('household', 'NN'),
#   ('products', 'NNS'),
#   ('and', 'CC'),
#   ('personal-care', 'JJ'),
#   ('businesses', 'NNS'),
#   ('jumped', 'VBD'),
#   ('25', 'CD'),
#   ('%', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('quarter', 'NN'),
#   (',', ','),
#   ('Mr.', 'NNP'),
#   ('Mark', 'NNP'),
#   ('added', 'VBD'),
#   ('.', '.')],
#  [('He', 'PRP'),
#   ('said', 'VBD'),
#   ('the', 'DT'),
#   ('improvement', 'NN'),
#   ('was', 'VBD'),
#   ('a', 'DT'),
#   ('result', 'NN'),
#   ('of', 'IN'),
#   ('cost', 'NN'),
#   ('savings', 'NNS'),
#   ('achieved', 'VBN'),
#   ('by', 'IN'),
#   ('consolidating', 'VBG'),
#   ('manufacturing', 'NN'),
#   ('operations', 'NNS'),
#   (',', ','),
#   ('blending', 'VBG'),
#   ('two', 'CD'),
#   ('sales', 'NNS'),
#   ('organizations', 'NNS'),
#   ('and', 'CC'),
#   ('focusing', 'VBG'),
#   ('more', 'RBR'),
#   ('carefully', 'RB'),
#   ('the', 'DT'),
#   ('company', 'NN'),
#   ("'s", 'POS'),
#   ('promotional', 'JJ'),
#   ('activities', 'NNS'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('estimated', 'VBN'),
#   ('improvement', 'NN'),
#   ('in', 'IN'),
#   ('Colgate', 'NNP'),
#   ("'s", 'POS'),
#   ('U.S.', 'NNP'),
#   ('operations', 'NNS'),
#   ('took', 'VBD'),
#   ('some', 'DT'),
#   ('analysts', 'NNS'),
#   ('by', 'IN'),
#   ('surprise', 'NN'),
#   ('.', '.')],
#  [('Colgate', 'NNP'),
#   ("'s", 'POS'),
#   ('household', 'NN'),
#   ('products', 'NNS'),
#   ('business', 'NN'),
#   (',', ','),
#   ('which', 'WDT'),
#   ('includes', 'VBZ'),
#   ('such', 'JJ'),
#   ('brands', 'NNS'),
#   ('as', 'IN'),
#   ('Fab', 'NNP'),
#   ('laundry', 'NN'),
#   ('detergent', 'NN'),
#   ('and', 'CC'),
#   ('Ajax', 'NNP'),
#   ('cleanser', 'NN'),
#   (',', ','),
#   ('has', 'VBZ'),
#   ('been', 'VBN'),
#   ('a', 'DT'),
#   ('weak', 'JJ'),
#   ('performer', 'NN'),
#   ('.', '.')],
#  [('Analysts', 'NNS'),
#   ('estimate', 'VBP'),
#   ('Colgate', 'NNP'),
#   ("'s", 'POS'),
#   ('sales', 'NNS'),
#   ('of', 'IN'),
#   ('household', 'NN'),
#   ('products', 'NNS'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('U.S.', 'NNP'),
#   ('were', 'VBD'),
#   ('flat', 'JJ'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('quarter', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('they', 'PRP'),
#   ('estimated', 'VBD'),
#   ('operating', 'VBG'),
#   ('margins', 'NNS'),
#   ('at', 'IN'),
#   ('only', 'RB'),
#   ('1', 'CD'),
#   ('%', 'NN'),
#   ('to', 'TO'),
#   ('3', 'CD'),
#   ('%', 'NN'),
#   ('.', '.')],
#  [('``', '``'),
#   ('If', 'IN'),
#   ('you', 'PRP'),
#   ('could', 'MD'),
#   ('say', 'VB'),
#   ('their', 'PRP$'),
#   ('business', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('U.S.', 'NNP'),
#   ('was', 'VBD'),
#   ('mediocre', 'JJ'),
#   (',', ','),
#   ('but', 'CC'),
#   ('great', 'JJ'),
#   ('everywhere', 'NN'),
#   ('else', 'RB'),
#   (',', ','),
#   ('that', 'WDT'),
#   ('would', 'MD'),
#   ('be', 'VB'),
#   ('fine', 'JJ'),
#   (',', ','),
#   ("''", "''"),
#   ('says', 'VBZ'),
#   ('Bonita', 'NNP'),
#   ('Austin', 'NNP'),
#   (',', ','),
#   ('an', 'DT'),
#   ('analyst', 'NN'),
#   ('with', 'IN'),
#   ('Wertheim', 'NNP'),
#   ('Schroder', 'NNP'),
#   ('&', 'CC'),
#   ('Co', 'NNP'),
#   ('.', '.')],
#  [('``', '``'),
#   ('But', 'CC'),
#   ('it', 'PRP'),
#   ("'s", 'VBZ'),
#   ('not', 'RB'),
#   ('mediocre', 'JJ'),
#   (',', ','),
#   ('it', 'PRP'),
#   ("'s", 'VBZ'),
#   ('a', 'DT'),
#   ('real', 'JJ'),
#   ('problem', 'NN'),
#   ('.', '.'),
#   ("''", "''")],
#  [('Mr.', 'NNP'),
#   ('Mark', 'NNP'),
#   ('conceded', 'VBD'),
#   ('that', 'IN'),
#   ('Colgate', 'NNP'),
#   ("'s", 'POS'),
#   ('domestic', 'JJ'),
#   ('business', 'NN'),
#   (',', ','),
#   ('apart', 'RB'),
#   ('from', 'IN'),
#   ('its', 'PRP$'),
#   ('highly', 'RB'),
#   ('profitable', 'JJ'),
#   ('Hill', 'NNP'),
#   ("'s", 'POS'),
#   ('Pet', 'NNP'),
#   ('Products', 'NNP'),
#   ('unit', 'NN'),
#   (',', ','),
#   ('has', 'VBZ'),
#   ('lagged', 'VBN'),
#   ('.', '.')],
#  [('``', '``'),
#   ('We', 'PRP'),
#   ("'ve", 'VBP'),
#   ('done', 'VBN'),
#   ('a', 'DT'),
#   ('lot', 'NN'),
#   ('to', 'TO'),
#   ('improve', 'VB'),
#   ('-LCB-', '('),
#   ('U.S.', 'NNP'),
#   ('.', '.'),
#   ('-RCB-', ')'),
#   ('results', 'NNS'),
#   (',', ','),
#   ('and', 'CC'),
#   ('a', 'DT'),
#   ('lot', 'NN'),
#   ('more', 'JJR'),
#   ('will', 'MD'),
#   ('be', 'VB'),
#   ('done', 'VBN'),
#   (',', ','),
#   ("''", "''"),
#   ('Mr.', 'NNP'),
#   ('Mark', 'NNP'),
#   ('said', 'VBD'),
#   ('.', '.')],
#  [('``', '``'),
#   ('Improving', 'VBG'),
#   ('profitability', 'NN'),
#   ('of', 'IN'),
#   ('U.S.', 'NNP'),
#   ('operations', 'NNS'),
#   ('is', 'VBZ'),
#   ('an', 'DT'),
#   ('extremely', 'RB'),
#   ('high', 'JJ'),
#   ('priority', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('company', 'NN'),
#   ('.', '.'),
#   ("''", "''")],
#  [('To', 'TO'),
#   ('focus', 'VB'),
#   ('on', 'IN'),
#   ('its', 'PRP$'),
#   ('global', 'JJ'),
#   ('consumer-products', 'JJ'),
#   ('business', 'NN'),
#   (',', ','),
#   ('Colgate', 'NNP'),
#   ('sold', 'VBD'),
#   ('its', 'PRP$'),
#   ('Kendall', 'NNP'),
#   ('health-care', 'JJ'),
#   ('business', 'NN'),
#   ('in', 'IN'),
#   ('1988', 'CD'),
#   ('.', '.')],
#  [('H.', 'NNP'),
#   ('Anthony', 'NNP'),
#   ('Ittleson', 'NNP'),
#   ('was', 'VBD'),
#   ('elected', 'VBN'),
#   ('a', 'DT'),
#   ('director', 'NN'),
#   ('of', 'IN'),
#   ('this', 'DT'),
#   ('company', 'NN'),
#   (',', ','),
#   ('which', 'WDT'),
#   ('primarily', 'RB'),
#   ('has', 'VBZ'),
#   ('interests', 'NNS'),
#   ('in', 'IN'),
#   ('radio', 'NN'),
#   ('and', 'CC'),
#   ('television', 'NN'),
#   ('stations', 'NNS'),
#   (',', ','),
#   ('increasing', 'VBG'),
#   ('the', 'DT'),
#   ('number', 'NN'),
#   ('of', 'IN'),
#   ('seats', 'NNS'),
#   ('to', 'TO'),
#   ('five', 'CD'),
#   ('.', '.')],
#  [('Osborn', 'NNP'),
#   ('also', 'RB'),
#   ('operates', 'VBZ'),
#   ('Muzak', 'NNP'),
#   ('franchises', 'NNS'),
#   (',', ','),
#   ('entertainment', 'NN'),
#   ('properties', 'NNS'),
#   ('and', 'CC'),
#   ('small', 'JJ'),
#   ('cable-television', 'NN'),
#   ('systems', 'NNS'),
#   ('.', '.')],
#  [('Mr.', 'NNP'),
#   ('Ittleson', 'NNP'),
#   ('is', 'VBZ'),
#   ('executive', 'JJ'),
#   (',', ','),
#   ('special', 'JJ'),
#   ('projects', 'NNS'),
#   (',', ','),
#   ('at', 'IN'),
#   ('CIT', 'NNP'),
#   ('Group', 'NNP'),
#   ('Holdings', 'NNP'),
#   ('Inc.', 'NNP'),
#   (',', ','),
#   ('which', 'WDT'),
#   ('is', 'VBZ'),
#   ('controlled', 'VBN'),
#   ('by', 'IN'),
#   ('Manufacturers', 'NNP'),
#   ('Hanover', 'NNP'),
#   ('Corp', 'NNP'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('Boston', 'NNP'),
#   ('Globe', 'NNP'),
#   ('says', 'VBZ'),
#   ('its', 'PRP$'),
#   ('newly', 'RB'),
#   ('redesigned', 'VBN'),
#   ('pages', 'NNS'),
#   ('have', 'VBP'),
#   ('a', 'DT'),
#   ('``', '``'),
#   ('crisper', 'NN'),
#   ("''", "''"),
#   ('look', 'NN'),
#   ('with', 'IN'),
#   ('revamped', 'JJ'),
#   ('fixtures', 'NNS'),
#   ('aimed', 'VBN'),
#   ('at', 'IN'),
#   ('making', 'VBG'),
#   ('the', 'DT'),
#   ('paper', 'NN'),
#   ('``', '``'),
#   ('more', 'JJR'),
#   ('consistent', 'NN'),
#   ("''", "''"),
#   ('and', 'CC'),
#   ('``', '``'),
#   ('easier', 'JJR'),
#   ('to', 'TO'),
#   ('read', 'VB'),
#   ('.', '.'),
#   ("''", "''")],
#  [('Maybe', 'RB'),
#   ('so', 'RB'),
#   ('--', ':'),
#   ('if', 'IN'),
#   ('you', 'PRP'),
#   ('can', 'MD'),
#   ('find', 'VB'),
#   ('where', 'WRB'),
#   ('your', 'PRP$'),
#   ('favorite', 'NN'),
#   ('writer', 'NN'),
#   ('went', 'VBD'),
#   ('.', '.')],
#  [('Beantown', 'NNP'),
#   ('scribes', 'NN'),
#   (',', ','),
#   ('who', 'WP'),
#   ('spare', 'VBP'),
#   ('no', 'DT'),
#   ('invective', 'NN'),
#   ('when', 'WRB'),
#   ('taking', 'VBG'),
#   ('on', 'IN'),
#   ('local', 'JJ'),
#   ('luminaries', 'NNS'),
#   ('such', 'JJ'),
#   ('as', 'IN'),
#   ('Michael', 'NNP'),
#   ('``', '``'),
#   ('Pee', 'NNP'),
#   ('Wee', 'NNP'),
#   ("''", "''"),
#   ('Dukakis', 'NNP'),
#   (',', ','),
#   ('or', 'CC'),
#   ('New', 'NNP'),
#   ('England', 'NNP'),
#   ('Patriots', 'NNP'),
#   ('Coach', 'NNP'),
#   ('Raymond', 'NNP'),
#   ('``', '``'),
#   ('Rev.', 'NNP'),
#   ('Ray', 'NNP'),
#   ("''", "''"),
#   ('Berry', 'NNP'),
#   (',', ','),
#   ('yesterday', 'NN'),
#   ('poured', 'VBN'),
#   ('ridicule', 'NN'),
#   ('on', 'IN'),
#   ('new', 'JJ'),
#   ('drawings', 'NNS'),
#   ('of', 'IN'),
#   ('Globe', 'NNP'),
#   ('columnists', 'NNS'),
#   ('that', 'IN'),
#   ('replaced', 'VBD'),
#   ('old', 'JJ'),
#   ('photos', 'NNS'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('revamped', 'VBN'),
#   ('pages', 'VBZ'),
#   ('this', 'DT'),
#   ('week', 'NN'),
#   ('.', '.')],
#  [('By', 'IN'),
#   ('late', 'JJ'),
#   ('last', 'JJ'),
#   ('night', 'NN'),
#   (',', ','),
#   ('Globe', 'NNP'),
#   ('Managing', 'VBG'),
#   ('Editor', 'NNP'),
#   ('Thomas', 'NNP'),
#   ('Mulvoy', 'NNP'),
#   (',', ','),
#   ('bending', 'VBG'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('will', 'MD'),
#   ('of', 'IN'),
#   ('his', 'PRP$'),
#   ('troops', 'NNS'),
#   (',', ','),
#   ('scrapped', 'VBD'),
#   ('the', 'DT'),
#   ('new', 'JJ'),
#   ('drawings', 'NNS'),
#   ('.', '.')],
#  [('For', 'IN'),
#   ('a', 'DT'),
#   ('few', 'JJ'),
#   ('days', 'NNS'),
#   ('at', 'IN'),
#   ('least', 'JJS'),
#   (',', ','),
#   ('he', 'PRP'),
#   ('says', 'VBZ'),
#   (',', ','),
#   ('no', 'DT'),
#   ('pictures', 'NNS'),
#   ('or', 'CC'),
#   ('drawings', 'NNS'),
#   ('of', 'IN'),
#   ('any', 'DT'),
#   ('kind', 'NN'),
#   ('will', 'MD'),
#   ('adorn', 'VB'),
#   ('the', 'DT'),
#   ('columns', 'NNS'),
#   ('.', '.')],
#  [('Trouble', 'NN'),
#   ('was', 'VBD'),
#   (',', ','),
#   ('nobody', 'NN'),
#   ('thought', 'VBD'),
#   ('they', 'PRP'),
#   ('looked', 'VBD'),
#   ('right', 'NN'),
#   ('.', '.')],
#  [('Globe', 'NNP'),
#   ('columnist', 'NN'),
#   ('Mike', 'NNP'),
#   ('Barnicle', 'NNP'),
#   ('--', ':'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('second', 'JJ'),
#   ('attack', 'NN'),
#   ('on', 'IN'),
#   ('his', 'PRP$'),
#   ('employer', 'NN'),
#   ('in', 'IN'),
#   ('as', 'IN'),
#   ('many', 'JJ'),
#   ('weeks', 'NNS'),
#   ('--', ':'),
#   ('averred', 'VBN'),
#   ('that', 'IN'),
#   ('his', 'PRP$'),
#   ('shadowy', 'NN'),
#   ('countenance', 'NN'),
#   ('was', 'VBD'),
#   ('so', 'RB'),
#   ('bad', 'JJ'),
#   (',', ','),
#   ('it', 'PRP'),
#   ('looked', 'VBD'),
#   ('``', '``'),
#   ('like', 'IN'),
#   ('a', 'DT'),
#   ('face', 'NN'),
#   ('you', 'PRP'),
#   ("'d", 'MD'),
#   ('find', 'VB'),
#   ('on', 'IN'),
#   ('a', 'DT'),
#   ('bottle', 'NN'),
# ...
#   (',', ','),
#   ('is', 'VBZ'),
#   ('considered', 'VBN'),
#   ('an', 'DT'),
#   ('early', 'JJ'),
#   ('signal', 'NN'),
#   ('of', 'IN'),
#   ('changes', 'NNS'),
#   ('in', 'IN'),
#   ('Fed', 'NNP'),
#   ('policy', 'NN'),
#   ('.', '.')],
#  [('It', 'PRP'),
#   ('ended', 'VBD'),
#   ('at', 'IN'),
#   ('about', 'IN'),
#   ('8', 'CD'),
#   ('11\\/16', 'CD'),
#   ('%', 'NN'),
#   ('yesterday', 'NN'),
#   (',', ','),
#   ('but', 'CC'),
#   ('was', 'VBD'),
#   ('as', 'RB'),
#   ('low', 'JJ'),
#   ('as', 'IN'),
#   ('8', 'CD'),
#   ('1\\/2', 'CD'),
#   ('%', 'NN'),
#   ('Monday', 'NNP'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('Treasury', 'NNP'),
#   ("'s", 'POS'),
#   ('benchmark', 'NN'),
#   ('30-year', 'JJ'),
#   ('bond', 'NN'),
#   ('fell', 'VBD'),
#   ('more', 'JJR'),
#   ('than', 'IN'),
#   ('1\\/2', 'CD'),
#   ('point', 'NN'),
#   (',', ','),
#   ('or', 'CC'),
#   ('over', 'IN'),
#   ('$', '$'),
#   ('5', 'NN'),
#   ('for', 'IN'),
#   ('each', 'DT'),
#   ('$', '$'),
#   ('1,000', 'CD'),
#   ('face', 'NN'),
#   ('amount', 'NN'),
#   (',', ','),
#   ('while', 'IN'),
#   ('the', 'DT'),
#   ('yield', 'NN'),
#   ('moved', 'VBD'),
#   ('above', 'IN'),
#   ('8', 'CD'),
#   ('%', 'NN'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('first', 'JJ'),
#   ('time', 'NN'),
#   ('since', 'IN'),
#   ('Thursday', 'NNP'),
#   ('.', '.')],
#  [('Investment-grade', 'JJ'),
#   ('corporate', 'JJ'),
#   (',', ','),
#   ('municipal', 'JJ'),
#   ('and', 'CC'),
#   ('mortgage-backed', 'JJ'),
#   ('securities', 'NNS'),
#   ('also', 'RB'),
#   ('fell', 'VBD'),
#   ('.', '.')],
#  [('But', 'CC'),
#   ('most', 'RBS'),
#   ('junk', 'NN'),
#   ('bonds', 'NNS'),
#   ('closed', 'VBD'),
#   ('unchanged', 'JJ'),
#   ('after', 'IN'),
#   ('opening', 'VBG'),
#   ('slightly', 'RB'),
#   ('higher', 'JJR'),
#   ('on', 'IN'),
#   ('bargain-hunting', 'JJ'),
#   ('by', 'IN'),
#   ('institutional', 'JJ'),
#   ('investors', 'NNS'),
#   ('.', '.')],
#  [('Some', 'DT'),
#   ('so-called', 'JJ'),
#   ('high-quality', 'JJ'),
#   ('junk', 'NN'),
#   ('issues', 'NNS'),
#   (',', ','),
#   ('such', 'JJ'),
#   ('as', 'IN'),
#   ('R.H.', 'NNP'),
#   ('Macy', 'NNP'),
#   ('&', 'CC'),
#   ('Co.', 'NNP'),
#   ("'s", 'POS'),
#   ('14', 'CD'),
#   ('1\\/2', 'CD'),
#   ('%', 'NN'),
#   ('subordinated', 'VBD'),
#   ('debentures', 'NNS'),
#   (',', ','),
#   ('rose', 'VBD'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('Macy', 'NNP'),
#   ("'s", 'POS'),
#   ('issue', 'NN'),
#   ('closed', 'VBD'),
#   ('up', 'IN'),
#   ('about', 'IN'),
#   ('one', 'CD'),
#   ('point', 'NN'),
#   ('at', 'IN'),
#   ('a', 'DT'),
#   ('bid', 'NN'),
#   ('price', 'NN'),
#   ('of', 'IN'),
#   ('97', 'CD'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('TVA', 'NNP'),
#   ("'s", 'POS'),
#   ('public', 'JJ'),
#   ('debt', 'NN'),
#   ('offering', 'NN'),
#   ('was', 'VBD'),
#   ('its', 'PRP$'),
#   ('first', 'JJ'),
#   ('in', 'IN'),
#   ('15', 'CD'),
#   ('years', 'NNS'),
#   ('.', '.')],
#  [('Strong', 'JJ'),
#   ('investor', 'NN'),
#   ('demand', 'NN'),
#   ('prompted', 'VBD'),
#   ('it', 'PRP'),
#   ('to', 'TO'),
#   ('boost', 'VB'),
#   ('the', 'DT'),
#   ('size', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('issue', 'NN'),
#   ('from', 'IN'),
#   ('$', '$'),
#   ('3', 'CD'),
#   ('billion', 'CD'),
#   ('.', '.')],
#  [('Traders', 'NNS'),
#   ('said', 'VBD'),
#   ('hedging', 'VBG'),
#   ('related', 'VBN'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('TVA', 'NNP'),
#   ('pricing', 'NN'),
#   ('also', 'RB'),
#   ('pressured', 'VBD'),
#   ('Treasury', 'NNP'),
#   ('bonds', 'NNS'),
#   ('.', '.')],
#  [('``', '``'),
#   ('Underwriters', 'NNS'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('TVA', 'NNP'),
#   ('bonds', 'NNS'),
#   ('reduced', 'VBD'),
#   ('their', 'PRP$'),
#   ('market', 'NN'),
#   ('risk', 'NN'),
#   ('by', 'IN'),
#   ('selling', 'VBG'),
#   ('Treasurys', 'NNPS'),
#   ('to', 'TO'),
#   ('cover', 'VB'),
#   ('at', 'IN'),
#   ('least', 'JJS'),
#   ('part', 'NN'),
#   ('of', 'IN'),
#   ('their', 'PRP$'),
#   ('-LCB-', '('),
#   ('TVA', 'NNP'),
#   ('-RCB-', ')'),
#   ('holdings', 'NNS'),
#   (',', ','),
#   ("''", "''"),
#   ('said', 'VBD'),
#   ('James', 'NNP'),
#   ('R.', 'NNP'),
#   ('Capra', 'NNP'),
#   (',', ','),
#   ('a', 'DT'),
#   ('senior', 'JJ'),
#   ('vice', 'NN'),
#   ('president', 'NN'),
#   ('at', 'IN'),
#   ('Shearson', 'NNP'),
#   ('Lehman', 'NNP'),
#   ('Government', 'NNP'),
#   ('Securities', 'NNP'),
#   ('Inc', 'NNP'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('TVA', 'NNP'),
#   ('bonds', 'NNS'),
#   ('also', 'RB'),
#   ('``', '``'),
#   ('served', 'VBN'),
#   ('to', 'TO'),
#   ('remind', 'VB'),
#   ('the', 'DT'),
#   ('market', 'NN'),
#   ('that', 'IN'),
#   ('there', 'EX'),
#   ('will', 'MD'),
#   ('be', 'VB'),
#   ('even', 'RB'),
#   ('more', 'JJR'),
#   ('new', 'JJ'),
#   ('supply', 'NN'),
#   (',', ','),
#   ("''", "''"),
#   ('said', 'VBD'),
#   ('Lawrence', 'NNP'),
#   ('N.', 'NNP'),
#   ('Leuzzi', 'NNP'),
#   (',', ','),
#   ('a', 'DT'),
#   ('managing', 'VBG'),
#   ('director', 'NN'),
#   ('at', 'IN'),
#   ('S.G.', 'NNP'),
#   ('Warburg', 'NNP'),
#   ('Securities', 'NNP'),
#   ('&', 'CC'),
#   ('Co', 'NNP'),
#   ('.', '.')],
#  [('Today', 'NN'),
#   ('the', 'DT'),
#   ('Treasury', 'NNP'),
#   ('will', 'MD'),
#   ('announce', 'VB'),
#   ('the', 'DT'),
#   ('size', 'NN'),
#   ('of', 'IN'),
#   ('its', 'PRP$'),
#   ('next', 'JJ'),
#   ('two-year', 'JJ'),
#   ('note', 'NN'),
#   ('sale', 'NN'),
#   ('and', 'CC'),
#   ('Resolution', 'NNP'),
#   ('Funding', 'NNP'),
#   ('Corp.', 'NNP'),
#   ('will', 'MD'),
#   ('announce', 'VB'),
#   ('details', 'NNS'),
#   ('of', 'IN'),
#   ('its', 'PRP$'),
#   ('first', 'JJ'),
#   ('bond', 'NN'),
#   ('offering', 'NN'),
#   ('.', '.')],
#  [('Some', 'DT'),
#   ('traders', 'NNS'),
#   ('estimate', 'VBP'),
#   ('$', '$'),
#   ('9.75', 'CD'),
#   ('billion', 'CD'),
#   ('of', 'IN'),
#   ('new', 'JJ'),
#   ('two-year', 'JJ'),
#   ('Treasurys', 'NNPS'),
#   ('will', 'MD'),
#   ('be', 'VB'),
#   ('sold', 'VBN'),
#   ('next', 'JJ'),
#   ('week', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('they', 'PRP'),
#   ('expect', 'VBP'),
#   ('Refcorp', 'NNP'),
#   ('to', 'TO'),
#   ('offer', 'VB'),
#   ('$', '$'),
#   ('4', 'CD'),
#   ('billion', 'CD'),
#   ('to', 'TO'),
#   ('$', '$'),
#   ('6', 'CD'),
#   ('billion', 'CD'),
#   ('of', 'IN'),
#   ('long-term', 'JJ'),
#   ('``', '``'),
#   ('bailout', 'NN'),
#   ("''", "''"),
#   ('bonds', 'NNS'),
#   ('.', '.')],
#  [('Refcorp', 'NNP'),
#   ('was', 'VBD'),
#   ('created', 'VBN'),
#   ('to', 'TO'),
#   ('help', 'VB'),
#   ('fund', 'VB'),
#   ('the', 'DT'),
#   ('thrift', 'NN'),
#   ('bailout', 'NN'),
#   ('.', '.')],
#  [('Another', 'DT'),
#   ('agency', 'NN'),
#   ('issue', 'NN'),
#   ('came', 'VBD'),
#   ('to', 'TO'),
#   ('market', 'NN'),
#   ('yesterday', 'NN'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('Office', 'NNP'),
#   ('of', 'IN'),
#   ('Finance', 'NNP'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('Federal', 'NNP'),
#   ('Home', 'NNP'),
#   ('Loan', 'NNP'),
#   ('Banks', 'NNP'),
#   ('said', 'VBD'),
#   ('it', 'PRP'),
#   ('priced', 'VBN'),
#   ('a', 'DT'),
#   ('four-part', 'JJ'),
#   ('$', '$'),
#   ('2.27', 'CD'),
#   ('billion', 'CD'),
#   ('bond', 'NN'),
#   ('offering', 'NN'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('banks', 'NNS'),
#   ('to', 'TO'),
#   ('yield', 'VB'),
#   ('from', 'IN'),
#   ('8.125', 'CD'),
#   ('%', 'NN'),
#   ('to', 'TO'),
#   ('8.375', 'CD'),
#   ('%', 'NN'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('release', 'NN'),
#   ('of', 'IN'),
#   ('several', 'JJ'),
#   ('economic', 'JJ'),
#   ('reports', 'NNS'),
#   ('had', 'VBD'),
#   ('little', 'JJ'),
#   ('impact', 'NN'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('market', 'NN'),
#   (',', ','),
#   ('including', 'VBG'),
#   ('a', 'DT'),
#   ('report', 'NN'),
#   ('that', 'IN'),
#   ('the', 'DT'),
#   ('U.S.', 'NNP'),
#   ('trade', 'NN'),
#   ('deficit', 'NN'),
#   ('expanded', 'VBN'),
#   ('to', 'TO'),
#   ('a', 'DT'),
#   ('surprisingly', 'RB'),
#   ('wide', 'JJ'),
#   ('$', '$'),
#   ('10.77', 'CD'),
#   ('billion', 'CD'),
#   ('in', 'IN'),
#   ('August', 'NNP'),
#   (',', ','),
#   ('up', 'IN'),
#   ('from', 'IN'),
#   ('a', 'DT'),
#   ('revised', 'VBN'),
#   ('$', '$'),
#   ('8.24', 'CD'),
#   ('billion', 'CD'),
#   ('in', 'IN'),
#   ('July', 'NNP'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('August', 'NNP'),
#   ('gap', 'NN'),
#   ('was', 'VBD'),
#   ('expected', 'VBN'),
#   ('to', 'TO'),
#   ('have', 'VB'),
#   ('expanded', 'VBN'),
#   ('to', 'TO'),
#   ('$', '$'),
#   ('9.1', 'CD'),
#   ('billion', 'CD'),
#   ('.', '.')],
#  [('Treasury', 'NNP'), ('Securities', 'NNPS')],
#  [('Treasury', 'NNP'),
#   ('securities', 'NNS'),
#   ('were', 'VBD'),
#   ('essentially', 'RB'),
#   ('flat', 'JJ'),
#   ('to', 'TO'),
#   ('about', 'IN'),
#   ('1\\/2', 'CD'),
#   ('point', 'NN'),
#   ('lower', 'JJR'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('benchmark', 'NN'),
#   ('30-year', 'JJ'),
#   ('bond', 'NN'),
#   ('was', 'VBD'),
#   ('quoted', 'VBN'),
#   ('late', 'RB'),
#   ('at', 'IN'),
#   ('100', 'CD'),
#   ('28\\/32', 'CD'),
#   ('to', 'TO'),
#   ('yield', 'VB'),
#   ('8.04', 'CD'),
#   ('%', 'NN'),
#   (',', ','),
#   ('compared', 'VBN'),
#   ('with', 'IN'),
#   ('101', 'CD'),
#   ('19\\/32', 'CD'),
#   ('to', 'TO'),
#   ('yield', 'VB'),
#   ('7.97', 'CD'),
#   ('%', 'NN'),
#   ('Monday', 'NNP'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('latest', 'JJS'),
#   ('10-year', 'JJ'),
#   ('notes', 'NNS'),
#   ('were', 'VBD'),
#   ('quoted', 'VBN'),
#   ('late', 'RB'),
#   ('at', 'IN'),
#   ('99', 'CD'),
#   ('25\\/32', 'CD'),
#   ('to', 'TO'),
#   ('yield', 'VB'),
#   ('8.01', 'CD'),
#   ('%', 'NN'),
#   (',', ','),
#   ('compared', 'VBN'),
#   ('with', 'IN'),
#   ('100', 'CD'),
#   ('1\\/32', 'CD'),
#   ('to', 'TO'),
#   ('yield', 'VB'),
#   ('7.97', 'CD'),
#   ('%', 'NN'),
#   ('.', '.')],
#  [('Short-term', 'JJ'), ('rates', 'NNS'), ('increased', 'VBN'), ('.', '.')],
#  [('The', 'DT'),
#   ('discount', 'NN'),
#   ('rate', 'NN'),
#   ('on', 'IN'),
#   ('three-month', 'JJ'),
#   ('bills', 'NNS'),
#   ('rose', 'VBD'),
#   ('to', 'TO'),
#   ('7.52', 'CD'),
#   ('%', 'NN'),
#   ('for', 'IN'),
#   ('a', 'DT'),
#   ('bond-equivalent', 'JJ'),
#   ('yield', 'NN'),
#   ('of', 'IN'),
#   ('7.75', 'CD'),
#   ('%', 'NN'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('rate', 'NN'),
#   ('on', 'IN'),
#   ('six-month', 'JJ'),
#   ('bills', 'NNS'),
#   ('rose', 'VBD'),
#   ('to', 'TO'),
#   ('7.53', 'CD'),
#   ('%', 'NN'),
#   ('for', 'IN'),
#   ('a', 'DT'),
#   ('bond-equivalent', 'JJ'),
#   ('yield', 'NN'),
#   ('of', 'IN'),
#   ('7.92', 'CD'),
#   ('%', 'NN'),
#   ('.', '.')],
#  [('Corporate', 'JJ'), (',', ','), ('Other', 'JJ'), ('Issues', 'NNS')],
#  [('Investment-grade', 'JJ'),
#   ('corporate', 'JJ'),
#   ('bonds', 'NNS'),
#   ('ended', 'VBD'),
#   ('1\\/4', 'CD'),
#   ('to', 'TO'),
#   ('1\\/2', 'CD'),
#   ('point', 'NN'),
#   ('lower', 'JJR'),
#   (',', ','),
#   ('while', 'IN'),
#   ('most', 'RBS'),
#   ('junk', 'NN'),
#   ('bonds', 'NNS'),
#   ('ended', 'VBD'),
#   ('unchanged', 'JJ'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('TVA', 'NNP'),
#   ("'s", 'POS'),
#   ('huge', 'JJ'),
#   ('$', '$'),
#   ('4', 'CD'),
#   ('billion', 'CD'),
#   ('offering', 'NN'),
#   ('dominated', 'VBN'),
#   ('attention', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('new-issue', 'JJ'),
#   ('market', 'NN'),
#   ('.', '.')],
#  [('TVA', 'NNP'),
#   ('offered', 'VBD'),
#   ('$', '$'),
#   ('2', 'CD'),
#   ('billion', 'CD'),
#   ('of', 'IN'),
#   ('30-year', 'JJ'),
#   ('bonds', 'NNS'),
#   ('priced', 'VBN'),
#   ('to', 'TO'),
#   ('yield', 'VB'),
#   ('9.06', 'CD'),
#   ('%', 'NN'),
#   (';', ':'),
#   ('$', '$'),
#   ('1', 'CD'),
#   ('billion', 'CD'),
#   ('in', 'IN'),
#   ('10-year', 'JJ'),
#   ('notes', 'NNS'),
#   ('priced', 'VBN'),
#   ('to', 'TO'),
#   ('yield', 'VB'),
#   ('8.42', 'CD'),
#   ('%', 'NN'),
#   (';', ':'),
#   ('and', 'CC'),
#   ('$', '$'),
#   ('1', 'CD'),
#   ('billion', 'CD'),
#   ('in', 'IN'),
#   ('five-year', 'JJ'),
#   ('notes', 'NNS'),
#   ('priced', 'VBN'),
#   ('to', 'TO'),
#   ('yield', 'VB'),
#   ('8.33', 'CD'),
#   ('%', 'NN'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('TVA', 'NNP'),
#   (',', ','),
#   ('which', 'WDT'),
#   ('operates', 'VBZ'),
#   ('one', 'CD'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('nation', 'NN'),
#   ("'s", 'POS'),
#   ('largest', 'JJS'),
#   ('electric', 'NN'),
#   ('power', 'NN'),
#   ('systems', 'NNS'),
#   (',', ','),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('corporation', 'NN'),
#   ('wholly', 'RB'),
#   ('owned', 'VBN'),
#   ('by', 'IN'),
#   ('the', 'DT'),
#   ('U.S.', 'NNP'),
#   ('government', 'NN'),
#   ('.', '.')],
#  [('Yesterday', 'NN'),
#   ("'s", 'POS'),
#   ('bond', 'NN'),
#   ('sale', 'NN'),
#   ('was', 'VBD'),
#   ('part', 'NN'),
#   ('of', 'IN'),
#   ('a', 'DT'),
#   ('$', '$'),
#   ('6.7', 'CD'),
#   ('billion', 'CD'),
#   ('refinancing', 'NN'),
#   ('plan', 'NN'),
#   ('to', 'TO'),
#   ('pay', 'VB'),
#   ('off', 'IN'),
#   ('high-interest', 'JJ'),
#   ('debt', 'NN'),
#   ('the', 'DT'),
#   ('TVA', 'NNP'),
#   ('owes', 'VBZ'),
#   ('the', 'DT'),
#   ('Federal', 'NNP'),
#   ('Financing', 'NNP'),
#   ('Bank', 'NNP'),
#   (',', ','),
#   ('an', 'DT'),
#   ('arm', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('Treasury', 'NNP'),
#   ('.', '.')],
#  [('Meanwhile', 'RB'),
#   (',', ','),
#   ('Lockheed', 'NNP'),
#   ('Corp.', 'NNP'),
#   ('priced', 'VBN'),
#   ('a', 'DT'),
#   ('$', '$'),
#   ('300', 'CD'),
#   ('million', 'CD'),
#   ('note', 'NN'),
#   ('offering', 'NN'),
#   ('to', 'TO'),
#   ('yield', 'VB'),
#   ('9.39', 'CD'),
#   ('%', 'NN'),
#   ('.', '.')],
#  [('Mortgage-Backed', 'JJ'), ('Securities', 'NNPS')],
#  [('The', 'DT'),
#   ('derivative', 'JJ'),
#   ('mortgage-backed', 'JJ'),
#   ('market', 'NN'),
#   ('revived', 'VBN'),
#   ('after', 'IN'),
#   ('a', 'DT'),
#   ('brief', 'JJ'),
#   ('hiatus', 'NN'),
#   ('as', 'IN'),
#   ('two', 'CD'),
#   ('new', 'JJ'),
#   ('Remics', 'NNS'),
#   ('totaling', 'VBG'),
#   ('$', '$'),
#   ('850', 'CD'),
#   ('million', 'CD'),
#   ('were', 'VBD'),
#   ('offered', 'VBN'),
#   ('and', 'CC'),
#   ('talk', 'VB'),
#   ('circulated', 'VBD'),
#   ('about', 'IN'),
#   ('two', 'CD'),
#   ('more', 'JJR'),
#   ('issues', 'NNS'),
#   ('that', 'WDT'),
#   ('could', 'MD'),
#   ('be', 'VB'),
#   ('priced', 'VBN'),
#   ('today', 'NN'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('revival', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('real', 'JJ'),
#   ('estate', 'NN'),
#   ('mortgage', 'NN'),
#   ('investment', 'NN'),
#   ('conduit', 'NN'),
#   ('market', 'NN'),
#   ('reflected', 'VBD'),
#   ('the', 'DT'),
#   ('relative', 'JJ'),
#   ('calm', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('mortgage', 'NN'),
#   ('market', 'NN'),
#   ('after', 'IN'),
#   ('two', 'CD'),
#   ('days', 'NNS'),
#   ('of', 'IN'),
#   ('volatile', 'JJ'),
#   ('trading', 'NN'),
#   ('.', '.')],
#  [('Dealers', 'NNS'),
#   ('noted', 'VBD'),
#   ('that', 'IN'),
#   ('it', 'PRP'),
#   ("'s", 'VBZ'),
#   ('difficult', 'JJ'),
#   ('to', 'TO'),
#   ('structure', 'VB'),
#   ('new', 'JJ'),
#   ('Remics', 'NNS'),
#   ('when', 'WRB'),
#   ('prices', 'NNS'),
#   ('are', 'VBP'),
#   ('moving', 'VBG'),
#   ('widely', 'RB'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('two', 'CD'),
#   ('Remics', 'NNS'),
#   ('priced', 'VBN'),
#   ('were', 'VBD'),
#   ('a', 'DT'),
#   ('$', '$'),
#   ('500', 'CD'),
#   ('million', 'CD'),
#   ('Federal', 'NNP'),
#   ('Home', 'NNP'),
#   ('Loan', 'NNP'),
#   ('Mortgage', 'NNP'),
#   ('Corp.', 'NNP'),
#   ('issue', 'NN'),
#   ('underwritten', 'VBN'),
#   ('by', 'IN'),
#   ('Salomon', 'NNP'),
#   ('Brothers', 'NNP'),
#   ('Inc.', 'NNP'),
#   ('and', 'CC'),
#   ('a', 'DT'),
#   ('$', '$'),
#   ('350', 'CD'),
#   ('million', 'CD'),
#   ('Federal', 'NNP'),
#   ('National', 'NNP'),
#   ('Mortgage', 'NNP'),
#   ('Association', 'NNP'),
#   ('deal', 'NN'),
#   ('underwritten', 'VBN'),
#   ('by', 'IN'),
#   ('Greenwich', 'NNP'),
#   ('Capital', 'NNP'),
#   ('Markets', 'NNPS'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('Remic', 'NNP'),
#   ('issuance', 'NN'),
#   ('supported', 'VBD'),
#   ('prices', 'NNS'),
#   ('of', 'IN'),
#   ('Freddie', 'NNP'),
#   ('Mac', 'NNP'),
#   ('and', 'CC'),
#   ('Fannie', 'NNP'),
#   ('Mae', 'NNP'),
#   ('securities', 'NNS'),
#   (',', ','),
#   ('which', 'WDT'),
#   ('held', 'VBD'),
#   ('up', 'IN'),
#   ('better', 'JJR'),
#   ('than', 'IN'),
#   ('Government', 'NNP'),
#   ('National', 'NNP'),
#   ('Mortgage', 'NNP'),
#   ('Association', 'NNP'),
#   ('securities', 'NNS'),
#   ('during', 'IN'),
#   ('an', 'DT'),
#   ('afternoon', 'NN'),
#   ('sell-off', 'NN'),
#   ('.', '.')],
#  [('Ginnie', 'NNP'),
#   ('Mae', 'NNP'),
#   ('9', 'CD'),
#   ('%', 'NN'),
#   ('securities', 'NNS'),
#   ('for', 'IN'),
#   ('November', 'NNP'),
#   ('delivery', 'NN'),
#   ('ended', 'VBD'),
#   ('at', 'IN'),
#   ('97', 'CD'),
#   ('29\\/32', 'CD'),
#   (',', ','),
#   ('down', 'RB'),
#   ('7\\/32', 'CD'),
#   (';', ':'),
#   ('9', 'CD'),
#   ('1\\/2', 'CD'),
#   ('%', 'NN'),
#   ('securities', 'NNS'),
#   ('at', 'IN'),
#   ('99', 'CD'),
#   ('31\\/32', 'CD'),
#   (',', ','),
#   ('down', 'RB'),
#   ('6\\/32', 'CD'),
#   (';', ':'),
#   ('and', 'CC'),
#   ('10', 'CD'),
#   ('%', 'NN'),
#   ('securities', 'NNS'),
#   ('at', 'IN'),
#   ('101', 'CD'),
#   ('29\\/32', 'CD'),
#   (',', ','),
#   ('down', 'RB'),
#   ('5\\/32', 'CD'),
#   ('.', '.')],
#  [('Freddie', 'NNP'),
#   ('Mac', 'NNP'),
#   ('9', 'CD'),
#   ('%', 'NN'),
#   ('securities', 'NNS'),
#   ('were', 'VBD'),
#   ('at', 'IN'),
#   ('97', 'CD'),
#   ('5\\/32', 'CD'),
#   (',', ','),
#   ('down', 'RB'),
#   ('3\\/32', 'CD'),
#   ('.', '.')],
#  ...]

# %%
nb_correct_perceptron=0
nb_mots = 0
for i in range(len(alldocsT)):
    doc_true= alldocsT[i]
    doc_pred_perceptron=all_tagged_docs_perceptron[i]
    for j in range(len(doc_true)):
        nb_mots +=1
        if(doc_true[j][1]==doc_pred_perceptron[j][1]) :
            nb_correct_perceptron+= 1

print("Nombre de tags corrects: ", nb_correct_perceptron)
print("Accuracy: ", nb_correct_perceptron/nb_mots)
# Out:
# Nombre de tags corrects:  46042
# Accuracy:  0.9718217700572007

# %% [markdown]
# Check: 1737 bonnes réponses

# %% [markdown]
# # Going further
#
# - We test the application for PoS, we can run similar experiments for chunking (see parsing indication, very simple to load data)
# - Run  experiement on the larger dataset. This dataset is still largely used in research. This work can thus be included in your resume :)
# - Work will be purshed with word embeddings (next practical), and for [NER](https://www.clips.uantwerpen.be/conll2003/ner/) with RNNs (X. Tannier)
# - [State-of-the-art resources](https://github.com/stanfordnlp/stanza/)
